# %% [markdown]
# ## Importar Modulos y Bibliotecas

# %%
import requests 
import hashlib
import json

# %% [markdown]
# ## 1. Descargar documento y extraer en una lista

# %%
docs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

# %% [markdown]
# ## Función para Gererar Id utilizando hash md5

# %%
def generate_document_id(doc):
    # combined = f"{doc['course']}-{doc['question']}"
    combined = f"{doc['course']}-{doc['question']}-{doc['text'][:10]}"
    hash_object = hashlib.md5(combined.encode())
    hash_hex = hash_object.hexdigest()
    document_id = hash_hex[:8]
    return document_id

# %% [markdown]
# ## Generar Id unico para cada documento en la lista

# %%
for doc in documents:
    doc['id'] = generate_document_id(doc)

# %%
documents[3]
# Out:
# {'text': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#  'section': 'General course-related questions',
#  'question': 'Course - I have registered for the Data Engineering Bootcamp. When can I expect to receive the confirmation email?',
#  'course': 'data-engineering-zoomcamp',
#  'id': '0bbf41ec'}

# %% [markdown]
# ## Veririfcar si algún Id se repite

# %%
from collections import defaultdict

hashes = defaultdict(list)

for doc in documents:
    hashes[doc['id']].append(doc)

print(f"cantidad de Id: {len(hashes)}, Cantidad de documentos {len(documents)}")

if len(hashes) != len(documents):
    print("Hay Ids duplicados ......")
    duplicates = [k for k, v in hashes.items() if len(v) > 1]
    for k in duplicates:
        print(f"Duplicate ID: {k} Count: {len(hashes[k])}")
        print("-"*80)
        print(json.dumps(hashes[k], indent=2, ensure_ascii=False))
        print("-"*80)
        print("\n")
else:  
    print("No hay Ids duplicados")
# Out:
# cantidad de Id: 947, Cantidad de documentos 948
# Hay Ids duplicados ......
# Duplicate ID: 593f7569 Count: 2
# --------------------------------------------------------------------------------
# [
#   {
#     "text": "They both do the same, it's just less typing from the script.\nAsked by Andrew Katoch, Added by Edidiong Esu",
#     "section": "6. Decision Trees and Ensemble Learning",
#     "question": "Does it matter if we let the Python file create the server or if we run gunicorn directly?",
#     "course": "machine-learning-zoomcamp",
#     "id": "593f7569"
#   },
#   {
#     "text": "They both do the same, it's just less typing from the script.",
#     "section": "6. Decision Trees and Ensemble Learning",
#     "question": "Does it matter if we let the Python file create the server or if we run gunicorn directly?",
#     "course": "machine-learning-zoomcamp",
#     "id": "593f7569"
#   }
# ]
# --------------------------------------------------------------------------------

# %%
with open('documents-with-ids.json', 'wt') as f_out:
    json.dump(documents, f_out, indent=2)

# %%
# !head documents-with-ids.json
# Out:
# [
#   {
#     "text": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  \u201cOffice Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon\u2019t forget to register in DataTalks.Club's Slack and join the channel.",
#     "section": "General course-related questions",
#     "question": "Course - When will the course start?",
#     "course": "data-engineering-zoomcamp",
#     "id": "c02e79ef"
#   },
#   {
#     "text": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",

# %% [markdown]
# ## Creación de Prompt Template

# %%
prompt_template = """
You emulate a student who's taking our course.
Formulate 5 questions this student might ask based on a FAQ record. The record
should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as fewer words as possible from the record. 

The record:

section: {section}
question: {question}
answer: {text}

Provide the output in parsable JSON without using code blocks:

["question1", "question2", ..., "question5"]
""".strip()

# %%
from deepseek_client import MODEL, client

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)

    response = client.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content
    return json_response

# %%
from tqdm.auto import tqdm

# %%
results = {}

# %%
for doc in tqdm(documents): 
    doc_id = doc['id']
    if doc_id in results:
        continue

    questions = generate_questions(doc)
    results[doc_id] = questions
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]

# %%
import pickle

# %%
import json
import re

def limpiar_json_llm(texto):
    # Eliminar bloques de código JSON con triple backtick
    texto = re.sub(r'```json\s*|\s*```', '', texto, flags=re.DOTALL)

    # Eliminar comentarios de una línea (// ...) y de bloque (/* ... */), si existen
    texto = re.sub(r'//.*?$|/\*.*?\*/', '', texto, flags=re.DOTALL | re.MULTILINE)

    # Eliminar espacios extras y limpiar la cadena
    texto = texto.strip()

    # Reemplazar tildes o caracteres mal codificados (opcional, si sabes que pueden estar mal)
    # Esto es solo un ejemplo, ajusta según sea necesario
    reemplazos = {
        'á': 'a', 'é': 'e', 'í': 'i', 'ó': 'o', 'ú': 'u',
        'Á': 'A', 'É': 'E', 'Í': 'I', 'Ó': 'O', 'Ú': 'U',
        'ñ': 'n', 'Ñ': 'N',
        # puedes añadir más reemplazos según tu caso
    }
    for antiguo, nuevo in reemplazos.items():
        texto = texto.replace(antiguo, nuevo)

    return texto

# Ejemplo de uso:

# %%
# Función para limpiar cada valor
def limpiar_valor(valor):
    # Eliminar bloques de código JSON con triple backtick
    valor = re.sub(r'```json\s*|\s*```', '', valor, flags=re.DOTALL)

    # Eliminar comentarios de una línea y de bloque
    valor = re.sub(r'//.*?$|/\*.*?\*/', '', valor, flags=re.DOTALL | re.MULTILINE)

    # Reemplazar comillas simples por dobles
    valor = valor.replace("'", '"')

    # Corregir escapes mal formados
    valor = re.sub(r'\\([^\"]|$)', r'\\"', valor)

    # Corregir casos como "don"t" -> "don't"
    valor = re.sub(r'(\w+)"(\w+)', r"\1'\2", valor)

    # Eliminar espacios extra y limpiar
    valor = re.sub(r'\s+', ' ', valor)

    # Limpiar espacios iniciales y finales
    valor = valor.strip()

    return valor

# Función para convertir el diccionario completo
def convertir_dict_a_json_valido(diccionario):
    nuevo_dict = {}
    for clave, valor in diccionario.items():
        try:
            valor_limpio = limpiar_valor(valor)
            nuevo_valor = json.loads(valor_limpio)
            nuevo_dict[clave] = nuevo_valor
        except json.JSONDecodeError as e:
            valor_fallado = valor
            print(f"❌ Error decodificando JSON para clave {clave}: {e}")
            nuevo_dict[clave] = None  # o puedes usar [] si prefieres una lista vacía
    return nuevo_dict

# %%
results['f43f5fe7']
# Out:
# '```json\n["How can I open the Run command window on a Windows machine to access the registry editor?", "Where exactly in the Registry Editor do I need to modify the \'Autorun\' value for GCP VM connection issues?", "What specific change should I make to the \'Autorun\' registry value to resolve the VSCode-GCP VM connection problem?", "Is there an alternative solution to modifying the registry, such as dealing with the known_hosts file?", "Where is the known_hosts file located on a Windows system if I want to delete the fingerprint manually?"]\n```'

# %%
# Aplicar la limpieza a todo el diccionario
dict_json = convertir_dict_a_json_valido(results)

# Mostrar el resultado
from pprint import pprint
pprint(dict_json)
# Out:
# ❌ Error decodificando JSON para clave f43f5fe7: Expecting ',' delimiter: line 1 column 158 (char 157)
# ❌ Error decodificando JSON para clave eb9d376f: Expecting ',' delimiter: line 1 column 26 (char 25)
# ❌ Error decodificando JSON para clave a1e59afc: Expecting ',' delimiter: line 1 column 328 (char 327)
# ❌ Error decodificando JSON para clave 7ec0f9b0: Expecting ',' delimiter: line 1 column 22 (char 21)
# ❌ Error decodificando JSON para clave bb1ba786: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave d407d65b: Unterminated string starting at: line 1 column 2 (char 1)
# ❌ Error decodificando JSON para clave c9375c56: Expecting ',' delimiter: line 1 column 384 (char 383)
# ❌ Error decodificando JSON para clave e866156b: Expecting ',' delimiter: line 1 column 20 (char 19)
# ❌ Error decodificando JSON para clave fb930700: Expecting ',' delimiter: line 1 column 28 (char 27)
# ❌ Error decodificando JSON para clave aa187680: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave e3106e07: Expecting ',' delimiter: line 1 column 64 (char 63)
# ❌ Error decodificando JSON para clave 72229da5: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 58c9f99f: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave bc42139a: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave a146e3ee: Expecting ',' delimiter: line 1 column 23 (char 22)
# ❌ Error decodificando JSON para clave 593a85ba: Expecting ',' delimiter: line 1 column 17 (char 16)
# ❌ Error decodificando JSON para clave 50bd1a71: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave f409f751: Expecting ',' delimiter: line 1 column 122 (char 121)
# ❌ Error decodificando JSON para clave 09081824: Expecting ',' delimiter: line 1 column 73 (char 72)
# ❌ Error decodificando JSON para clave 4df80c55: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave a02f2039: Expecting ',' delimiter: line 1 column 397 (char 396)
# ❌ Error decodificando JSON para clave f476a606: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave e41b100c: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave cd0f9300: Expecting ',' delimiter: line 1 column 117 (char 116)
# ❌ Error decodificando JSON para clave 32e8450c: Expecting ',' delimiter: line 1 column 54 (char 53)
# ❌ Error decodificando JSON para clave 96606db2: Expecting ',' delimiter: line 1 column 234 (char 233)
# ❌ Error decodificando JSON para clave 0882bfac: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave f09ea61e: Expecting ',' delimiter: line 1 column 53 (char 52)
# ❌ Error decodificando JSON para clave fbd3d2bb: Expecting ',' delimiter: line 1 column 327 (char 326)
# ❌ Error decodificando JSON para clave 0b014d0c: Expecting ',' delimiter: line 1 column 112 (char 111)
# ❌ Error decodificando JSON para clave d21bff1d: Expecting ',' delimiter: line 1 column 271 (char 270)
# ❌ Error decodificando JSON para clave b51c3b82: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 326af690: Expecting ',' delimiter: line 1 column 285 (char 284)
# ❌ Error decodificando JSON para clave c2ec9047: Expecting ',' delimiter: line 1 column 112 (char 111)
# ❌ Error decodificando JSON para clave 3b711e73: Expecting ',' delimiter: line 1 column 26 (char 25)
# ❌ Error decodificando JSON para clave acf42bb8: Expecting ',' delimiter: line 1 column 16 (char 15)
# ❌ Error decodificando JSON para clave 3e5d1e9b: Expecting ',' delimiter: line 1 column 19 (char 18)
# ❌ Error decodificando JSON para clave 78833f32: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 63823f21: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave b36ea564: Expecting ',' delimiter: line 1 column 215 (char 214)
# ❌ Error decodificando JSON para clave e2a46ce5: Expecting ',' delimiter: line 1 column 30 (char 29)
# ❌ Error decodificando JSON para clave c91ad8f2: Expecting ',' delimiter: line 1 column 73 (char 72)
# ❌ Error decodificando JSON para clave 23524e6d: Expecting ',' delimiter: line 1 column 50 (char 49)
# ❌ Error decodificando JSON para clave 9211bbd6: Expecting ',' delimiter: line 1 column 53 (char 52)
# ❌ Error decodificando JSON para clave 5db86809: Expecting ',' delimiter: line 1 column 48 (char 47)
# ❌ Error decodificando JSON para clave 20c604dd: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 1ea7680e: Expecting ',' delimiter: line 1 column 144 (char 143)
# ❌ Error decodificando JSON para clave 752e8452: Expecting value: line 1 column 1 (char 0)
# ❌ Error decodificando JSON para clave aa6f52b8: Expecting ',' delimiter: line 1 column 108 (char 107)
# ❌ Error decodificando JSON para clave 8b71a398: Expecting ',' delimiter: line 1 column 163 (char 162)
# ❌ Error decodificando JSON para clave aa244fa0: Expecting ',' delimiter: line 1 column 77 (char 76)
# ❌ Error decodificando JSON para clave eac816d7: Expecting ',' delimiter: line 1 column 59 (char 58)
# ❌ Error decodificando JSON para clave d44d1c77: Expecting ',' delimiter: line 1 column 41 (char 40)
# ❌ Error decodificando JSON para clave ed34766a: Expecting ',' delimiter: line 1 column 63 (char 62)
# ❌ Error decodificando JSON para clave 9de2c3e9: Expecting ',' delimiter: line 1 column 57 (char 56)
# ❌ Error decodificando JSON para clave 827dd4af: Expecting ',' delimiter: line 1 column 47 (char 46)
# ❌ Error decodificando JSON para clave c4e9bc60: Expecting ',' delimiter: line 1 column 166 (char 165)
# ❌ Error decodificando JSON para clave f10b49be: Expecting ',' delimiter: line 1 column 170 (char 169)
# ❌ Error decodificando JSON para clave 8bea4d53: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave 86d11cc0: Expecting ',' delimiter: line 1 column 128 (char 127)
# ❌ Error decodificando JSON para clave 9523c813: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave 20a01fd0: Expecting ',' delimiter: line 1 column 131 (char 130)
# ❌ Error decodificando JSON para clave 5a712a20: Expecting ',' delimiter: line 1 column 118 (char 117)
# ❌ Error decodificando JSON para clave 1093daf5: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 947213b1: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave e2095203: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 22a2b9f2: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave 5d7588f0: Expecting ',' delimiter: line 1 column 153 (char 152)
# ❌ Error decodificando JSON para clave 5276a695: Expecting ',' delimiter: line 1 column 38 (char 37)
# ❌ Error decodificando JSON para clave 70c159df: Expecting ',' delimiter: line 1 column 41 (char 40)
# ❌ Error decodificando JSON para clave f55efcf0: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave 2b7a8512: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 1cd746c4: Expecting ',' delimiter: line 1 column 11 (char 10)
# ❌ Error decodificando JSON para clave 6d367222: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave 84e601e1: Expecting ',' delimiter: line 1 column 201 (char 200)
# ❌ Error decodificando JSON para clave 4cf83cc2: Expecting ',' delimiter: line 1 column 156 (char 155)
# ❌ Error decodificando JSON para clave f9d6f8bd: Expecting ',' delimiter: line 1 column 55 (char 54)
# ❌ Error decodificando JSON para clave f3adb937: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave eb3d6d36: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave a76e1f4d: Expecting ',' delimiter: line 1 column 19 (char 18)
# ❌ Error decodificando JSON para clave 934facf8: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave a2c7b59f: Expecting ',' delimiter: line 1 column 394 (char 393)
# ❌ Error decodificando JSON para clave 997d4aaa: Expecting ',' delimiter: line 1 column 229 (char 228)
# ❌ Error decodificando JSON para clave 10ea342e: Expecting ',' delimiter: line 1 column 59 (char 58)
# ❌ Error decodificando JSON para clave 4bd23594: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave b0d48cd7: Expecting ',' delimiter: line 1 column 65 (char 64)
# ❌ Error decodificando JSON para clave 54c6db2f: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave c5b998f3: Expecting ',' delimiter: line 1 column 55 (char 54)
# ❌ Error decodificando JSON para clave eec29536: Expecting ',' delimiter: line 1 column 396 (char 395)
# ❌ Error decodificando JSON para clave dde58c8f: Expecting ',' delimiter: line 1 column 40 (char 39)
# ❌ Error decodificando JSON para clave c46a2e9e: Expecting ',' delimiter: line 1 column 159 (char 158)
# ❌ Error decodificando JSON para clave 0513ab8a: Expecting ',' delimiter: line 1 column 234 (char 233)
# ❌ Error decodificando JSON para clave c30468c0: Expecting ',' delimiter: line 1 column 230 (char 229)
# ❌ Error decodificando JSON para clave 0952abde: Expecting ',' delimiter: line 1 column 139 (char 138)
# ❌ Error decodificando JSON para clave 7c4326eb: Expecting ',' delimiter: line 1 column 61 (char 60)
# ❌ Error decodificando JSON para clave a1fc1a14: Expecting ',' delimiter: line 1 column 135 (char 134)
# ❌ Error decodificando JSON para clave 155aa868: Expecting ',' delimiter: line 1 column 47 (char 46)
# ❌ Error decodificando JSON para clave fac138a7: Expecting ',' delimiter: line 1 column 128 (char 127)
# ❌ Error decodificando JSON para clave 2d6536d3: Expecting ',' delimiter: line 1 column 208 (char 207)
# ❌ Error decodificando JSON para clave f83d9435: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave c489266b: Expecting ',' delimiter: line 1 column 275 (char 274)
# ❌ Error decodificando JSON para clave 47a43bb0: Expecting ',' delimiter: line 1 column 52 (char 51)
# ❌ Error decodificando JSON para clave f3f13def: Expecting ',' delimiter: line 1 column 33 (char 32)
# ❌ Error decodificando JSON para clave 4fd37712: Expecting ',' delimiter: line 1 column 37 (char 36)
# ❌ Error decodificando JSON para clave 8abeca36: Expecting ',' delimiter: line 1 column 283 (char 282)
# ❌ Error decodificando JSON para clave 16c16ff9: Expecting ',' delimiter: line 1 column 163 (char 162)
# ❌ Error decodificando JSON para clave c65d8fd9: Expecting ',' delimiter: line 1 column 63 (char 62)
# ❌ Error decodificando JSON para clave c1a95536: Expecting ',' delimiter: line 1 column 82 (char 81)
# ❌ Error decodificando JSON para clave a2120335: Expecting ',' delimiter: line 1 column 33 (char 32)
# ❌ Error decodificando JSON para clave a4ba2478: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 74c361fe: Expecting ',' delimiter: line 1 column 129 (char 128)
# ❌ Error decodificando JSON para clave b9b3ef9f: Expecting ',' delimiter: line 1 column 33 (char 32)
# ❌ Error decodificando JSON para clave 009ac612: Expecting ',' delimiter: line 1 column 52 (char 51)
# ❌ Error decodificando JSON para clave c8ad08b3: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave d68b433f: Expecting ',' delimiter: line 1 column 33 (char 32)
# ❌ Error decodificando JSON para clave e265ee5a: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 0e7dfddc: Expecting ',' delimiter: line 1 column 61 (char 60)
# ❌ Error decodificando JSON para clave 0a059700: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 1f519b1a: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave 43c454c7: Expecting ',' delimiter: line 1 column 249 (char 248)
# ❌ Error decodificando JSON para clave d7ad69da: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 9c85f3aa: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 63026349: Expecting ',' delimiter: line 1 column 16 (char 15)
# ❌ Error decodificando JSON para clave 14a876ea: Expecting ',' delimiter: line 1 column 34 (char 33)
# ❌ Error decodificando JSON para clave 1cf5be74: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 33db7dc7: Expecting ',' delimiter: line 1 column 106 (char 105)
# ❌ Error decodificando JSON para clave 67ef8f87: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 6acf2e77: Expecting ',' delimiter: line 1 column 127 (char 126)
# ❌ Error decodificando JSON para clave 18430f10: Expecting ',' delimiter: line 1 column 53 (char 52)
# ❌ Error decodificando JSON para clave de426d2f: Expecting ',' delimiter: line 1 column 233 (char 232)
# ❌ Error decodificando JSON para clave 6528c6ae: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave c599b3a0: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 179df18d: Expecting ',' delimiter: line 1 column 90 (char 89)
# ❌ Error decodificando JSON para clave 1ce1a275: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave b529b0bc: Expecting ',' delimiter: line 1 column 105 (char 104)
# ❌ Error decodificando JSON para clave 6e1a0834: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave de06929d: Expecting ',' delimiter: line 1 column 40 (char 39)
# ❌ Error decodificando JSON para clave 3c41892d: Expecting ',' delimiter: line 1 column 36 (char 35)
# ❌ Error decodificando JSON para clave 4842f3e8: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave e2d2bc58: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 137aab88: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave a260e651: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave da8d9fcc: Expecting ',' delimiter: line 1 column 98 (char 97)
# ❌ Error decodificando JSON para clave 52cccade: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 0a0cc4c3: Expecting ',' delimiter: line 1 column 143 (char 142)
# ❌ Error decodificando JSON para clave cb912983: Expecting ',' delimiter: line 1 column 49 (char 48)
# ❌ Error decodificando JSON para clave 2d4e434f: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave bb6655b9: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave fc2eb036: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 25daead9: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 2221d75e: Expecting ',' delimiter: line 1 column 57 (char 56)
# ❌ Error decodificando JSON para clave 94524a9d: Expecting ',' delimiter: line 1 column 115 (char 114)
# ❌ Error decodificando JSON para clave c5af32ab: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 67217f4c: Expecting ',' delimiter: line 1 column 144 (char 143)
# ❌ Error decodificando JSON para clave 95e302f7: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave d17e30c6: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 1520b5bc: Expecting ',' delimiter: line 1 column 127 (char 126)
# ❌ Error decodificando JSON para clave e86ca928: Expecting ',' delimiter: line 1 column 133 (char 132)
# ❌ Error decodificando JSON para clave 3b5b4eb3: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave 59381b15: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave 220b1cf3: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave d970a0da: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave e5270303: Expecting ',' delimiter: line 1 column 41 (char 40)
# ❌ Error decodificando JSON para clave e3c0f777: Expecting ',' delimiter: line 1 column 138 (char 137)
# ❌ Error decodificando JSON para clave 0fe0c76a: Expecting ',' delimiter: line 1 column 136 (char 135)
# ❌ Error decodificando JSON para clave 59e86b40: Expecting ',' delimiter: line 1 column 48 (char 47)
# ❌ Error decodificando JSON para clave 1ac3ea8f: Expecting ',' delimiter: line 1 column 63 (char 62)
# ❌ Error decodificando JSON para clave a602a7f8: Expecting ',' delimiter: line 1 column 123 (char 122)
# ❌ Error decodificando JSON para clave 9336ce2c: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave 13dad632: Expecting ',' delimiter: line 1 column 49 (char 48)
# ❌ Error decodificando JSON para clave 33dd4516: Expecting ',' delimiter: line 1 column 47 (char 46)
# ❌ Error decodificando JSON para clave 504b8570: Expecting ',' delimiter: line 1 column 206 (char 205)
# ❌ Error decodificando JSON para clave 42e933c5: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave fe9240b0: Expecting ',' delimiter: line 1 column 33 (char 32)
# ❌ Error decodificando JSON para clave f41ef231: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave 80125745: Expecting ',' delimiter: line 1 column 19 (char 18)
# ❌ Error decodificando JSON para clave 06014eec: Expecting ',' delimiter: line 1 column 67 (char 66)
# ❌ Error decodificando JSON para clave 54653ca9: Expecting ',' delimiter: line 1 column 43 (char 42)
# ❌ Error decodificando JSON para clave 5cb7f597: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 70ac8e80: Expecting ',' delimiter: line 1 column 29 (char 28)
# ❌ Error decodificando JSON para clave f6551ffb: Expecting ',' delimiter: line 1 column 23 (char 22)
# ❌ Error decodificando JSON para clave 1edd4630: Expecting ',' delimiter: line 1 column 48 (char 47)
# ❌ Error decodificando JSON para clave 4664ae28: Expecting ',' delimiter: line 1 column 59 (char 58)
# ❌ Error decodificando JSON para clave f1284c1f: Expecting ',' delimiter: line 1 column 53 (char 52)
# ❌ Error decodificando JSON para clave 196cb0f2: Expecting ',' delimiter: line 1 column 138 (char 137)
# ❌ Error decodificando JSON para clave 1e50eab7: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave a7a6d0d7: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave 0996213a: Expecting ',' delimiter: line 1 column 47 (char 46)
# ❌ Error decodificando JSON para clave f9b673cf: Expecting ',' delimiter: line 1 column 22 (char 21)
# ❌ Error decodificando JSON para clave 947c07a6: Expecting ',' delimiter: line 1 column 22 (char 21)
# ❌ Error decodificando JSON para clave 343864f5: Expecting ',' delimiter: line 1 column 47 (char 46)
# ❌ Error decodificando JSON para clave 6cb3b4a9: Expecting ',' delimiter: line 1 column 187 (char 186)
# ❌ Error decodificando JSON para clave 74f412c4: Expecting ',' delimiter: line 1 column 211 (char 210)
# ❌ Error decodificando JSON para clave 8e74f943: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 154d7705: Expecting ',' delimiter: line 1 column 95 (char 94)
# ❌ Error decodificando JSON para clave 0728ca67: Expecting ',' delimiter: line 1 column 53 (char 52)
# ❌ Error decodificando JSON para clave 49a51e24: Expecting ',' delimiter: line 1 column 47 (char 46)
# ❌ Error decodificando JSON para clave f0d552a7: Expecting ',' delimiter: line 1 column 46 (char 45)
# ❌ Error decodificando JSON para clave 9c750080: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave accb7285: Expecting ',' delimiter: line 1 column 64 (char 63)
# ❌ Error decodificando JSON para clave 78fce6ad: Expecting ',' delimiter: line 1 column 298 (char 297)
# ❌ Error decodificando JSON para clave 71b1984b: Expecting ',' delimiter: line 1 column 392 (char 391)
# ❌ Error decodificando JSON para clave ffbf3311: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 4930aa19: Expecting ',' delimiter: line 1 column 238 (char 237)
# ❌ Error decodificando JSON para clave 49f9bda9: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave d44de7d1: Expecting ',' delimiter: line 1 column 167 (char 166)
# ❌ Error decodificando JSON para clave 98cff602: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave f81f4ecb: Expecting ',' delimiter: line 1 column 30 (char 29)
# ❌ Error decodificando JSON para clave be760b92: Expecting ',' delimiter: line 1 column 214 (char 213)
# ❌ Error decodificando JSON para clave a2cfa1c9: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 7b907071: Expecting ',' delimiter: line 1 column 204 (char 203)
# ❌ Error decodificando JSON para clave fc2e0a61: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 32bc0538: Expecting ',' delimiter: line 1 column 133 (char 132)
# ❌ Error decodificando JSON para clave b6730228: Expecting value: line 1 column 1 (char 0)
# ❌ Error decodificando JSON para clave 4e584d06: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave b8ca1cd3: Expecting ',' delimiter: line 1 column 63 (char 62)
# ❌ Error decodificando JSON para clave efdb235f: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 355348f0: Expecting ',' delimiter: line 1 column 219 (char 218)
# ❌ Error decodificando JSON para clave bbc0fca3: Expecting ',' delimiter: line 1 column 49 (char 48)
# ❌ Error decodificando JSON para clave 6f3bdd20: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 8fe56032: Expecting ',' delimiter: line 1 column 265 (char 264)
# ❌ Error decodificando JSON para clave af833e0a: Expecting ',' delimiter: line 1 column 393 (char 392)
# ❌ Error decodificando JSON para clave 91fc573d: Expecting ',' delimiter: line 1 column 57 (char 56)
# ❌ Error decodificando JSON para clave f488ce85: Expecting ',' delimiter: line 1 column 166 (char 165)
# ❌ Error decodificando JSON para clave 01cd3b35: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 5551c92e: Expecting ',' delimiter: line 1 column 122 (char 121)
# ❌ Error decodificando JSON para clave 94f928d2: Expecting ',' delimiter: line 1 column 18 (char 17)
# ❌ Error decodificando JSON para clave e1f93d10: Expecting ',' delimiter: line 1 column 259 (char 258)
# ❌ Error decodificando JSON para clave 225506b9: Expecting ',' delimiter: line 1 column 200 (char 199)
# ❌ Error decodificando JSON para clave 1091b10f: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave 44d22817: Expecting ',' delimiter: line 1 column 510 (char 509)
# ❌ Error decodificando JSON para clave 467e0cec: Expecting ',' delimiter: line 1 column 492 (char 491)
# ❌ Error decodificando JSON para clave b69f32f6: Expecting ',' delimiter: line 1 column 49 (char 48)
# ❌ Error decodificando JSON para clave 683495d2: Expecting ',' delimiter: line 1 column 47 (char 46)
# ❌ Error decodificando JSON para clave dc1897b5: Expecting ',' delimiter: line 1 column 282 (char 281)
# ❌ Error decodificando JSON para clave 821dfc08: Expecting ',' delimiter: line 1 column 106 (char 105)
# ❌ Error decodificando JSON para clave c5fdeba9: Expecting ',' delimiter: line 1 column 268 (char 267)
# ❌ Error decodificando JSON para clave 7d40f6f6: Expecting ',' delimiter: line 1 column 198 (char 197)
# ❌ Error decodificando JSON para clave 8eca9f73: Expecting ',' delimiter: line 1 column 37 (char 36)
# ❌ Error decodificando JSON para clave e4dd91cf: Expecting ',' delimiter: line 1 column 174 (char 173)
# ❌ Error decodificando JSON para clave 185096ad: Expecting ',' delimiter: line 1 column 85 (char 84)
# ❌ Error decodificando JSON para clave ec88d101: Expecting ',' delimiter: line 1 column 128 (char 127)
# ❌ Error decodificando JSON para clave 4b2a3181: Expecting ',' delimiter: line 1 column 38 (char 37)
# ❌ Error decodificando JSON para clave 73bd7fa1: Expecting ',' delimiter: line 1 column 26 (char 25)
# ❌ Error decodificando JSON para clave a4d3b1e5: Expecting ',' delimiter: line 1 column 22 (char 21)
# ❌ Error decodificando JSON para clave 366d7563: Expecting ',' delimiter: line 1 column 267 (char 266)
# ❌ Error decodificando JSON para clave b632d2ea: Expecting ',' delimiter: line 1 column 110 (char 109)
# ❌ Error decodificando JSON para clave 047f57fb: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 11f7371c: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave 9dd8efd2: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave 9531dc92: Expecting ',' delimiter: line 1 column 60 (char 59)
# ❌ Error decodificando JSON para clave 6189375f: Expecting ',' delimiter: line 1 column 72 (char 71)
# ❌ Error decodificando JSON para clave 3419ee27: Expecting ',' delimiter: line 1 column 184 (char 183)
# ❌ Error decodificando JSON para clave f7b38587: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave be86b333: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave a5b3296b: Expecting ',' delimiter: line 1 column 124 (char 123)
# ❌ Error decodificando JSON para clave a23b276a: Expecting ',' delimiter: line 1 column 117 (char 116)
# ❌ Error decodificando JSON para clave 3a98b6b7: Expecting ',' delimiter: line 1 column 16 (char 15)
# ❌ Error decodificando JSON para clave d42eb923: Expecting ',' delimiter: line 1 column 27 (char 26)
# ❌ Error decodificando JSON para clave c13d811f: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave d04e77f8: Expecting ',' delimiter: line 1 column 61 (char 60)
# ❌ Error decodificando JSON para clave 451c067f: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave bf563b1f: Expecting ',' delimiter: line 1 column 28 (char 27)
# ❌ Error decodificando JSON para clave eac70ce3: Expecting ',' delimiter: line 1 column 123 (char 122)
# ❌ Error decodificando JSON para clave 5f91f8ca: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave a6e384fe: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave 6cb56405: Expecting ',' delimiter: line 1 column 50 (char 49)
# ❌ Error decodificando JSON para clave 6a245a05: Expecting ',' delimiter: line 1 column 62 (char 61)
# ❌ Error decodificando JSON para clave 346e799a: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave a114ad55: Expecting ',' delimiter: line 1 column 422 (char 421)
# ❌ Error decodificando JSON para clave dd3c8000: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 34b0ebfc: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave b3997e6f: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave f20a3479: Expecting ',' delimiter: line 1 column 20 (char 19)
# ❌ Error decodificando JSON para clave 2023a9dc: Expecting ',' delimiter: line 1 column 104 (char 103)
# ❌ Error decodificando JSON para clave 62722d72: Expecting ',' delimiter: line 1 column 49 (char 48)
# ❌ Error decodificando JSON para clave d1419be1: Expecting ',' delimiter: line 1 column 64 (char 63)
# ❌ Error decodificando JSON para clave a5f6f439: Expecting ',' delimiter: line 1 column 93 (char 92)
# ❌ Error decodificando JSON para clave 53f3ee10: Expecting ',' delimiter: line 1 column 48 (char 47)
# ❌ Error decodificando JSON para clave 0edeb016: Expecting ',' delimiter: line 1 column 37 (char 36)
# ❌ Error decodificando JSON para clave ba186de6: Expecting ',' delimiter: line 1 column 38 (char 37)
# ❌ Error decodificando JSON para clave da2f1cf4: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 7fd648ca: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave d6d534fc: Expecting ',' delimiter: line 1 column 464 (char 463)
# ❌ Error decodificando JSON para clave b2c0c554: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 819afebc: Expecting ',' delimiter: line 1 column 438 (char 437)
# ❌ Error decodificando JSON para clave e5fe9efe: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave af0739da: Expecting ',' delimiter: line 1 column 59 (char 58)
# ❌ Error decodificando JSON para clave ea2e7458: Expecting ',' delimiter: line 1 column 107 (char 106)
# ❌ Error decodificando JSON para clave 29311ef5: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 1e0dc11c: Expecting ',' delimiter: line 1 column 229 (char 228)
# ❌ Error decodificando JSON para clave 7daaca73: Expecting ',' delimiter: line 1 column 37 (char 36)
# ❌ Error decodificando JSON para clave 1460fb65: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave d4f9efdc: Expecting ',' delimiter: line 1 column 337 (char 336)
# ❌ Error decodificando JSON para clave a64aed6b: Expecting ',' delimiter: line 1 column 37 (char 36)
# ❌ Error decodificando JSON para clave 85d4901d: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave df023a13: Expecting ',' delimiter: line 1 column 35 (char 34)
# ❌ Error decodificando JSON para clave 1685cae4: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 4fb7b21e: Expecting ',' delimiter: line 1 column 38 (char 37)
# ❌ Error decodificando JSON para clave c5cde96c: Expecting ',' delimiter: line 1 column 296 (char 295)
# ❌ Error decodificando JSON para clave 59823c72: Expecting ',' delimiter: line 1 column 18 (char 17)
# ❌ Error decodificando JSON para clave 665f7b27: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 0a406fe0: Expecting ',' delimiter: line 1 column 50 (char 49)
# ❌ Error decodificando JSON para clave d6d483ce: Expecting ',' delimiter: line 1 column 40 (char 39)
# ❌ Error decodificando JSON para clave f9711723: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 5bda3b94: Expecting ',' delimiter: line 1 column 202 (char 201)
# ❌ Error decodificando JSON para clave cccd31cf: Expecting ',' delimiter: line 1 column 20 (char 19)
# ❌ Error decodificando JSON para clave 57f49999: Expecting ',' delimiter: line 1 column 173 (char 172)
# ❌ Error decodificando JSON para clave de650b41: Expecting ',' delimiter: line 1 column 307 (char 306)
# ❌ Error decodificando JSON para clave 9a7c26e0: Expecting ',' delimiter: line 1 column 425 (char 424)
# ❌ Error decodificando JSON para clave 1fd83eb9: Expecting ',' delimiter: line 1 column 174 (char 173)
# ❌ Error decodificando JSON para clave fbaa5b20: Expecting ',' delimiter: line 1 column 416 (char 415)
# ❌ Error decodificando JSON para clave 57754faf: Expecting ',' delimiter: line 1 column 284 (char 283)
# ❌ Error decodificando JSON para clave 6979c5d1: Expecting ',' delimiter: line 1 column 280 (char 279)
# ❌ Error decodificando JSON para clave fcd86c8f: Expecting ',' delimiter: line 1 column 19 (char 18)
# ❌ Error decodificando JSON para clave 236864c2: Expecting ',' delimiter: line 1 column 57 (char 56)
# ❌ Error decodificando JSON para clave 15f361b7: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 70d89fdf: Expecting ',' delimiter: line 1 column 38 (char 37)
# ❌ Error decodificando JSON para clave 8c7f089f: Expecting ',' delimiter: line 1 column 38 (char 37)
# ❌ Error decodificando JSON para clave 4603e4e5: Expecting ',' delimiter: line 1 column 133 (char 132)
# ❌ Error decodificando JSON para clave cc60f7bc: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave 7a69cccf: Expecting ',' delimiter: line 1 column 434 (char 433)
# ❌ Error decodificando JSON para clave f2cd48b6: Expecting ',' delimiter: line 1 column 250 (char 249)
# ❌ Error decodificando JSON para clave 387093cc: Expecting ',' delimiter: line 1 column 137 (char 136)
# ❌ Error decodificando JSON para clave c6a22665: Expecting ',' delimiter: line 1 column 396 (char 395)
# ❌ Error decodificando JSON para clave 7297b7fc: Expecting ',' delimiter: line 1 column 288 (char 287)
# ❌ Error decodificando JSON para clave 0f1ddc9e: Expecting ',' delimiter: line 1 column 20 (char 19)
# ❌ Error decodificando JSON para clave 01f61154: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave d43c32ba: Expecting ',' delimiter: line 1 column 215 (char 214)
# ❌ Error decodificando JSON para clave af22c52a: Expecting ',' delimiter: line 1 column 428 (char 427)
# ❌ Error decodificando JSON para clave 9d15c9e9: Expecting ',' delimiter: line 1 column 37 (char 36)
# ❌ Error decodificando JSON para clave d5eab395: Expecting ',' delimiter: line 1 column 255 (char 254)
# ❌ Error decodificando JSON para clave c91b6b57: Expecting ',' delimiter: line 1 column 330 (char 329)
# ❌ Error decodificando JSON para clave 782e1723: Expecting ',' delimiter: line 1 column 232 (char 231)
# ❌ Error decodificando JSON para clave 4e08c86a: Expecting ',' delimiter: line 1 column 412 (char 411)
# ❌ Error decodificando JSON para clave 34bcad27: Expecting ',' delimiter: line 1 column 122 (char 121)
# ❌ Error decodificando JSON para clave bf006ff9: Expecting ',' delimiter: line 1 column 131 (char 130)
# ❌ Error decodificando JSON para clave b80401a2: Expecting ',' delimiter: line 1 column 373 (char 372)
# ❌ Error decodificando JSON para clave 88002d35: Expecting ',' delimiter: line 1 column 40 (char 39)
# ❌ Error decodificando JSON para clave b9adeb39: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 80554fc2: Expecting ',' delimiter: line 1 column 440 (char 439)
# ❌ Error decodificando JSON para clave b8d3c55e: Expecting ',' delimiter: line 1 column 65 (char 64)
# ❌ Error decodificando JSON para clave 336f5e36: Expecting ',' delimiter: line 1 column 48 (char 47)
# ❌ Error decodificando JSON para clave 75cd9b7a: Expecting ',' delimiter: line 1 column 61 (char 60)
# ❌ Error decodificando JSON para clave 51c99586: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave 67d343f2: Expecting ',' delimiter: line 1 column 39 (char 38)
# ❌ Error decodificando JSON para clave 6de95c2a: Expecting ',' delimiter: line 1 column 61 (char 60)
# ❌ Error decodificando JSON para clave 2ff28e5b: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave bd09df94: Expecting ',' delimiter: line 1 column 37 (char 36)
# ❌ Error decodificando JSON para clave af887c59: Expecting ',' delimiter: line 1 column 374 (char 373)
# ❌ Error decodificando JSON para clave e223524c: Expecting ',' delimiter: line 1 column 18 (char 17)
# ❌ Error decodificando JSON para clave 0f08bec7: Expecting ',' delimiter: line 1 column 96 (char 95)
# ❌ Error decodificando JSON para clave a1b68c52: Expecting ',' delimiter: line 1 column 221 (char 220)
# ❌ Error decodificando JSON para clave 483e7d61: Expecting ',' delimiter: line 1 column 144 (char 143)
# ❌ Error decodificando JSON para clave 39861d6e: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 32686722: Expecting ',' delimiter: line 1 column 60 (char 59)
# ❌ Error decodificando JSON para clave 22521751: Expecting ',' delimiter: line 1 column 325 (char 324)
# ❌ Error decodificando JSON para clave 81ad4784: Expecting ',' delimiter: line 1 column 47 (char 46)
# ❌ Error decodificando JSON para clave 668f1ad9: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 7a6f23eb: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave e44ec04a: Expecting ',' delimiter: line 1 column 24 (char 23)
# ❌ Error decodificando JSON para clave 55fdb8b9: Expecting ',' delimiter: line 1 column 64 (char 63)
# ❌ Error decodificando JSON para clave 76d8892e: Expecting ',' delimiter: line 1 column 108 (char 107)
# ❌ Error decodificando JSON para clave 82b6c143: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave 77d9a742: Expecting ',' delimiter: line 1 column 53 (char 52)
# ❌ Error decodificando JSON para clave 1667e95d: Expecting ',' delimiter: line 1 column 61 (char 60)
# ❌ Error decodificando JSON para clave a3aa3a7d: Expecting ',' delimiter: line 1 column 37 (char 36)
# ❌ Error decodificando JSON para clave 30b8e8e6: Expecting ',' delimiter: line 1 column 20 (char 19)
# ❌ Error decodificando JSON para clave f33fc6e9: Expecting ',' delimiter: line 1 column 48 (char 47)
# ❌ Error decodificando JSON para clave d828de2a: Expecting ',' delimiter: line 1 column 118 (char 117)
# ❌ Error decodificando JSON para clave 03f20ec1: Expecting ',' delimiter: line 1 column 128 (char 127)
# ❌ Error decodificando JSON para clave 249726fe: Expecting ',' delimiter: line 1 column 133 (char 132)
# ❌ Error decodificando JSON para clave 4e492af0: Expecting ',' delimiter: line 1 column 43 (char 42)
# ❌ Error decodificando JSON para clave 2b8cb640: Expecting ',' delimiter: line 1 column 270 (char 269)
# ❌ Error decodificando JSON para clave d4ceab0b: Expecting ',' delimiter: line 1 column 72 (char 71)
# ❌ Error decodificando JSON para clave 482e575f: Expecting ',' delimiter: line 1 column 38 (char 37)
# ❌ Error decodificando JSON para clave 33e775eb: Expecting ',' delimiter: line 1 column 120 (char 119)
# ❌ Error decodificando JSON para clave 55c68f23: Expecting ',' delimiter: line 1 column 32 (char 31)
# ❌ Error decodificando JSON para clave 54020f0a: Expecting ',' delimiter: line 1 column 25 (char 24)
# ❌ Error decodificando JSON para clave b6249d2c: Expecting ',' delimiter: line 1 column 31 (char 30)
# ❌ Error decodificando JSON para clave 31543d95: Expecting ',' delimiter: line 1 column 31 (char 30)
# ❌ Error decodificando JSON para clave f6979915: Expecting ',' delimiter: line 1 column 153 (char 152)
# ❌ Error decodificando JSON para clave 1076a121: Expecting ',' delimiter: line 1 column 48 (char 47)
# ❌ Error decodificando JSON para clave aa203ca7: Expecting ',' delimiter: line 1 column 20 (char 19)
# ❌ Error decodificando JSON para clave 8b04605d: Expecting ',' delimiter: line 1 column 24 (char 23)
# {'0002ab8b': ['What steps are needed to set up a dbt-core project in Google '
#               'Cloud Composer with Airflow?',
#               'How do I configure the profiles.yml file for service account '
#               'authentication in dbt on Cloud Composer?',
#               'Which package should I install to integrate dbt-core with '
#               'Airflow in Google Cloud Composer?',
#               'Where should I place my dbt-core project files in the Composer '
#               'environment?',
#               'How can I visualize my dbt lineage graph as tasks in an Airflow '
#               'Task Group?'],
#  '002d4943': ['Is it necessary to create multiple service accounts for '
#               'different Terraform resources in this course?',
#               'Can I use a single service account for all the services covered '
#               'in Module 1?',
#               'What steps do I need to take after obtaining the credentials '
#               'file for Terraform?',
#               'Do I need to configure any environment variables after setting '
#               'up the service account?',
#               'Will one service account suffice for all the Terraform '
#               'operations in this course?'],
#  '00882c83': ['What version of the AWS CLI is required to work with eksctl in '
#               'this course?',
#               'How can I verify which AWS CLI version I currently have '
#               'installed?',
#               'Is AWS CLI v1 supported for Kubernetes and TensorFlow Serving '
#               'tasks?',
#               'Where can I find instructions to upgrade to AWS CLI v2 if '
#               'needed?',
#               'Why is AWS CLI v2 specifically recommended for eksctl in this '
#               'section?'],
#  '009ac612': None,
#  '016d46a1': ['How can I find out what my display name is on the leaderboard?',
#               "Why don't I see my name on the leaderboard after setting up my "
#               'account?',
#               'Where do I go to change my display name for the course?',
#               'Is it possible to customize my display name on the leaderboard?',
#               'What steps do I need to follow to view or update my profile in '
#               'the course?'],
#  '0174dde5': ['What precautions should I take when using BigQuery to avoid '
#               'unexpected charges?',
#               "How can I ensure I don't get billed after my GCP free trial "
#               'ends?',
#               'What steps should I follow to manage BigQuery datasets '
#               'responsibly?',
#               'Why is it important to monitor billing daily when using '
#               'BigQuery or VMs?',
#               'What are the best practices for using BigQuery within free '
#               'credits?'],
#  '01cd3b35': None,
#  '01f61154': None,
#  '02007b7c': ["Why isn't Jupyter Notebook or SparkUI loading correctly after "
#               'setting up port forwarding from VS Code?',
#               'How can I forward ports manually using SSH instead of relying '
#               'on VS Code?',
#               'What should I do if my Spark session fails to run on port 4040 '
#               'and switches to 4041?',
#               'How can I ensure my localhost ports remain accessible after '
#               'logging out from the SSH session?',
#               'Is there a way to automate port forwarding for multiple ports '
#               'like 8888, 8080, and 4040 in my SSH configuration?'],
#  '0227b872': ['How can I register for the Machine Learning Zoomcamp course?',
#               'Where can I find the sign-up link for the course?',
#               'Is there a structured FAQ document for this course like the '
#               'Data Engineering Zoomcamp?',
#               'What is the purpose of the FAQ document provided in the course '
#               'materials?',
#               'Can you share the direct link to the course registration form?'],
#  '0282578d': ['Is it necessary to remove my Google Cloud instance after '
#               'completing the lecture?',
#               'What happens if I delete my GCP instance following the '
#               'demonstration?',
#               'Why does Alexey delete his instance in Google Cloud during the '
#               'lecture?',
#               'Will deleting my instance in Google Cloud affect my progress in '
#               'Week 1?',
#               'Should I keep my Google Cloud instance running even after the '
#               'lecture ends?'],
#  '02cf2317': ['How can I execute a Kafka producer written in Java from the '
#               'terminal?',
#               'What is the command to run a Kafka consumer application in the '
#               'terminal?',
#               'How do I start a KStreams application using the terminal?',
#               'What is the correct way to launch a Kafka Java application from '
#               'the command line?',
#               'Where can I find the exact command to run a Kafka '
#               'producer/consumer in the terminal?'],
#  '0315aa96': ['How can I fix out of memory errors when running TensorFlow on '
#               'an Nvidia GPU?',
#               'Is there a way to prevent TensorFlow from consuming all GPU '
#               'memory at once?',
#               'What should I do if TensorFlow throws an OOM error during model '
#               'training?',
#               "Can I limit TensorFlow's GPU memory usage to avoid crashes?",
#               'How do I enable memory growth for TensorFlow to prevent out of '
#               'memory issues?'],
#  '03b5fc59': ['How do I install kind on my Windows machine using Chocolatey?',
#               'What are the steps to set up Chocolatey before installing kind?',
#               'Can you explain the PowerShell command needed to install '
#               'Chocolatey?',
#               'Why do I need administrator privileges to install kind via '
#               'Chocolatey?',
#               'Is there an alternative method to install kind if Chocolatey is '
#               'not available?'],
#  '03f20ec1': None,
#  '03fdb780': ['Why did my dbt Cloud run get cancelled and how can I fix it?',
#               'What should I do if dbt Cloud says a valid dbt project was not '
#               'found?',
#               'How do I ensure my dbt_project.yml file is properly configured '
#               'in dbt Cloud?',
#               'Where do I specify the subdirectory location of my dbt project '
#               'in dbt Cloud?',
#               'What steps should I take if my dbt build fails due to a missing '
#               'dbt project?'],
#  '04656af5': ['Why am I getting an invalid timestamp error when trying to load '
#               'data from an external table into a materialized table in '
#               'BigQuery?',
#               'How can I identify which rows have invalid timestamp data when '
#               'importing from an external table in BigQuery?',
#               'What is the recommended approach to handle invalid timestamp '
#               'data during data loading in BigQuery?',
#               'Can I still query the data in an external table if the '
#               'timestamp column has invalid entries?',
#               'How do I filter out invalid timestamp rows before importing '
#               'them into a materialized table in BigQuery?'],
#  '047baefe': ['How can I verify that the model file is present inside the '
#               'Docker container after building the image?',
#               'What is the correct command to list the contents of the /app '
#               'directory in the Docker container?',
#               'Do I need to rebuild the Docker image every time I make changes '
#               'to the Dockerfile?',
#               'What is the difference between RUN and CMD in a Dockerfile when '
#               'trying to execute commands?',
#               'Can I automatically run a script inside the container when it '
#               'starts instead of manually listing files?'],
#  '047f57fb': None,
#  '04aa4897': ['How can I access the live stream for Office Hour or workshop '
#               'sessions?',
#               'Where is the YouTube Live link shared before the Office Hour '
#               'starts?',
#               "Why shouldn't I post questions in the YouTube chat during "
#               'Office Hours?',
#               'How do I submit questions during the Office Hour sessions?',
#               'Can I participate in Office Hours via Zoom, or is it only '
#               'through YouTube Live?'],
#  '0513ab8a': None,
#  '0516ccbe': ['Why do my datetime columns from Pandas appear as integers in '
#               'BigQuery after exporting to Parquet?',
#               'How can I ensure datetime columns in Parquet files are '
#               'correctly interpreted as timestamps in BigQuery?',
#               'What is the solution in Mage to fix datetime column conversion '
#               'issues when exporting to BigQuery?',
#               'Can I specify a schema in PyArrow to enforce correct timestamp '
#               'types in Parquet for BigQuery?',
#               'What are the steps to configure PyArrow in Mage to avoid '
#               'datetime-to-integer conversion in BigQuery?'],
#  '0560e827': ['What is the recommended format for asking questions in the '
#               'course FAQ?',
#               'Where can I find inspiration for structuring my questions and '
#               'answers in the FAQ?',
# ...
#               'on Windows with WSL?',
#               'Can I use Docker with Windows 10/11 Home Edition, and if so, '
#               'how?',
#               'What should I do if Docker gets stuck even after setting up '
#               'WSL2 or Hyper-V correctly?',
#               'Is it better to run Docker commands from the Windows file '
#               'system or the WSL Linux file system?',
#               "Are there any troubleshooting steps if Docker doesn't work "
#               'properly after WSL2 setup?'],
#  'f3adb937': None,
#  'f3f13def': None,
#  'f409f751': None,
#  'f41ef231': None,
#  'f43f5fe7': None,
#  'f476a606': None,
#  'f488ce85': None,
#  'f4b82056': ['Why am I getting a Protobuf error when trying to run MLflow '
#               'after installing the required libraries?',
#               'How can I resolve the Protobuf version conflict that occurs '
#               'when running MLflow?',
#               'What specific version of Protobuf should I install to avoid '
#               'errors with MLflow?',
#               'After installing MLflow dependencies, why does the terminal '
#               'show a Protobuf-related error?',
#               'What steps should I take if MLflow fails to run due to a '
#               'Protobuf compatibility issue?'],
#  'f55efcf0': None,
#  'f5dc446c': ['Which dataset is required for calculating the evaluation '
#               'metrics mentioned in Question 3?',
#               'Can I use a different dataset other than `dt_val` for computing '
#               'the metrics in Question 3?',
#               'Why is the `dt_val` dataset specified for evaluating the '
#               'metrics in Question 3?',
#               'Is the `dt_val` dataset the same one used in Question 2 for '
#               'computing metrics?',
#               'What happens if I use the wrong dataset to compute the metrics '
#               'for Question 3?'],
#  'f625307b': ['What steps should I take if my Ridge regression model is not '
#               'converging during training?',
#               'How can I normalize numerical features to prevent convergence '
#               'issues in Ridge regression?',
#               'What is the best way to handle categorical features when '
#               'training a Ridge regression model?',
#               'Why is OneHotEncoder recommended for encoding categorical '
#               'features in Ridge regression?',
#               'How do I combine normalized numerical and encoded categorical '
#               'features for Ridge regression training?'],
#  'f6551ffb': None,
#  'f6979915': None,
#  'f69fb077': ['Why is my max_depth parameter not being recognized even after '
#               'using mlflow.log_params in my code?',
#               "What should I do if mlflow.log_params doesn't seem to log my "
#               'hyperparameters correctly?',
#               'How can I ensure that new parameters are properly logged when '
#               'running the hpo.py script multiple times?',
#               'Why are my previous runs affecting the logging of parameters in '
#               'my current mlflow experiment?',
#               'What steps can I take to resolve issues with parameter logging '
#               'when re-running the same mlflow experiment?'],
#  'f721d54b': ['Is it necessary to connect my Saturn Cloud GPU to a GitHub '
#               'repository, or are there simpler alternatives?',
#               'What are the steps to generate and add SSH keys for GitHub '
#               'authentication from Saturn Cloud?',
#               "How can I use Saturn Cloud's default public keys to "
#               'authenticate with GitHub instead of creating new ones?',
#               'Where do I find the default SSH keys in Saturn Cloud to link '
#               'with my GitHub repository?',
#               'After setting up SSH keys, how do I verify that my Saturn Cloud '
#               'terminal is successfully authenticated with GitHub?'],
#  'f7252f17': ['Why am I getting a type mismatch error between BigQuery and '
#               'Parquet data for location ID columns?',
#               'How can I resolve the INT64 and DOUBLE type conflict when '
#               'loading Parquet data into BigQuery?',
#               'What is the best way to handle missing values in location ID '
#               'columns before loading to BigQuery?',
#               'Why does Pandas change the data type of my location ID columns '
#               'when there are missing values?',
#               'How can I ensure consistent data types between my Parquet files '
#               'and BigQuery schema?'],
#  'f7b38587': None,
#  'f7bc2f65': ['How should I format and submit links to my public learning '
#               'posts for the course assignments?',
#               'Is there a limit to how many points I can earn by sharing my '
#               'learning publicly on social media?',
#               'Can I post the same content on multiple social platforms and '
#               'still receive full points?',
#               'Are the points for sharing learning in public adjusted for '
#               'midterm or capstone projects?',
#               'What happens if I submit more than the allowed number of '
#               'learning in public links for an assignment?'],
#  'f7c5d8da': ['Why does PGCLI require quotation marks around column names with '
#               'capital letters?',
#               "What happens if I don't use quotes around a column like "
#               'PULocationID in PGCLI?',
#               'How does PGCLI handle case sensitivity for column names without '
#               'quotations?',
#               'Where can I find documentation about case sensitivity rules in '
#               'PGCLI?',
#               'Is there a way to avoid using quotes for columns with capital '
#               'letters in PGCLI?'],
#  'f81f4ecb': None,
#  'f826cba4': ['What is the location of the model we need to use for the '
#               'assignments in week 9?',
#               'How do we access the deep learning models for the serverless '
#               'week?',
#               'Where can I find the model files required for the week 9 '
#               'exercises?',
#               "Why isn't the original link for the week 9 models working, and "
#               'where are they now?',
#               'Can you provide the updated source for downloading the models '
#               'used in the serverless deep learning section?'],
#  'f83d9435': None,
#  'f95304db': ['Why am I getting a Python version mismatch error when running '
#               'PySpark, and how can I resolve it?',
#               'What environment variables do I need to set to fix the PySpark '
#               'version conflict between worker and driver?',
#               'How can I ensure both PySpark worker and driver use the same '
#               'Python version?',
#               'Where can I find the pricing details for running PySpark on '
#               'Google Dataproc?',
#               'What is the correct way to configure PYSPARK_PYTHON and '
#               'PYSPARK_DRIVER_PYTHON to avoid version errors?'],
#  'f96517d9': ['What additional packages are required to run the starter '
#               "Jupyter Notebook if I'm using a new Codespace or Virtual "
#               'Environment?',
#               'Do I need to install any extra dependencies for the Workshop 1 '
#               '- dlthub Jupyter Notebook?',
#               'If I set up a fresh environment, what command should I run to '
#               'ensure the starter notebook works?',
#               'Are there any unlisted packages necessary for the Workshop 1 '
#               'Jupyter Notebook?',
#               "What pip installation is required to execute the teacher's "
#               'provided Jupyter Notebook in a new environment?'],
#  'f9711723': None,
#  'f9b673cf': None,
#  'f9d6f8bd': None,
#  'fac138a7': None,
#  'fb3c4150': ['Why is the pre-commit command failing when using isort in my '
#               'repository?',
#               'What specific version of isort should I use to resolve the '
#               'pre-commit issue?',
#               'How can I fix the isort pre-commit failure in Module 6?',
#               'Who provided the solution for the isort pre-commit problem?',
#               'What was the exact solution to the isort pre-commit error '
#               'mentioned in the FAQ?'],
#  'fb930700': None,
#  'fb9a45d8': ["In the test_train_split question for week 3's homework, should "
#               'we set the random_state to 42 for both splits or just the first '
#               'one?',
#               'Is it necessary to use the same random seed (42) for both '
#               'training and test splits in HW3?',
#               'For the classification homework in week 3, does the '
#               'random_state parameter need to be 42 in both splits?',
#               'Why is the random seed 42 specified for both splits in the '
#               'test_train_split question of HW3?',
#               'Can we use different random_state values for the two splits in '
#               "week 3's homework, or must both be set to 42?"],
#  'fbaa5b20': None,
#  'fbd3d2bb': None,
#  'fbda1f40': ['What is the purpose of calculating mutual information score in '
#               'classification tasks?',
#               'How do I binarize the price variable for calculating mutual '
#               'information?',
#               'Why is ocean_proximity the only categorical variable used in '
#               'this calculation?',
#               'Can mutual information score be used for numerical variables as '
#               'well?',
#               'What does a high mutual information score indicate about the '
#               'relationship between variables?'],
#  'fc2e0a61': None,
#  'fc2eb036': None,
#  'fc60bf3b': ['What happens if I submit my assignment after the deadline?',
#               'Will my late submission be graded if the submission form is '
#               'still accessible?',
#               'Is there any chance for evaluation if I miss the assignment '
#               'deadline but the form is open?',
#               'How does the course handle assignments that are submitted past '
#               'the due date?',
#               'Can I still get credit for my work if I submit it late but '
#               'before the form closes?'],
#  'fcd86c8f': None,
#  'fd2b9972': ['Why am I getting a warning message when using '
#               'mlflow.xgboost.autolog() for my XGBoost model?',
#               'Does the warning message during mlflow.xgboost.autolog() mean '
#               'my model failed to track in MLflow?',
#               'How can I verify if my XGBoost model was successfully logged '
#               'despite the autolog warning?',
#               'Are there any specific filters or settings I should check in '
#               'MLflow UI after seeing the autolog warning?',
#               'Is the mlflow.xgboost.autolog() warning a known issue, and does '
#               'it affect model tracking functionality?'],
#  'fd714677': ['How can I resolve the issue of the Google Cloud SDK PATH not '
#               'being added automatically on Windows?',
#               'What steps should I follow to add GitBash to my Windows PATH if '
#               'the Google Cloud SDK installer fails?',
#               'Why is it necessary to install Anaconda Navigator to fix the '
#               'PATH issue with Google Cloud SDK on Windows?',
#               'How do I configure GitBash to be my default terminal in Windows '
#               'after installing it?',
#               'What specific settings should I check during GitBash '
#               'installation to ensure it works properly with the Google Cloud '
#               'SDK?'],
#  'fe3139f6': ["Why doesn't linear regression perfectly match the training data "
#               'even after optimization?',
#               'Is it possible for any model, including linear regression, to '
#               'achieve a 100% fit on the training data?',
#               'What are the drawbacks of forcing a model to fit all training '
#               'data points exactly?',
#               'How does the simplicity of linear regression limit its ability '
#               'to fit complex data patterns?',
#               'Can you explain why a perfect fit on training data might lead '
#               'to poor performance on unseen data?'],
#  'fe61aa5b': ['How can I identify and stop the process currently using port '
#               '5000 on my Mac?',
#               'What command can I use to terminate all processes running on '
#               'port 5000 in one step?',
#               'Is there a way to change the port number for MLflow to avoid '
#               'conflicts with existing processes?',
#               'How do I find the process ID of a gunicorn instance running on '
#               'my system?',
#               "What is the quickest method to free up port 5000 if it's "
#               'already in use?'],
#  'fe9240b0': None,
#  'feca7402': ['How can I download a compressed CSV file from a URL using '
#               'Prefect?',
#               'What is the correct way to define a task in Prefect for '
#               'downloading files?',
#               'Can you show an example of a Prefect flow that extracts data '
#               'from a web source?',
#               'How do I handle file downloads in a Prefect environment with '
#               'proper error handling?',
#               'What are the best practices for writing reusable download tasks '
#               'in Prefect?'],
#  'ff352621': ['What should I do if I encounter an error about credentials when '
#               'running docker-compose up -d?',
#               'How can I resolve the Docker-Compose credential error mentioned '
#               'in Module 1?',
#               'After running docker-compose up -d, I get an error related to '
#               'credentials. What is the solution?',
#               'Where can I find more information about fixing the '
#               'Docker-Compose credential error?',
#               'Which package do I need to install to fix the Docker-Compose '
#               'credential issue?'],
#  'ff40f83b': {'questions': ["What are the key steps to begin Week 8's material "
#                             'on Neural Networks and Deep Learning?',
#                             'Where can I find the resources or tutorials to '
#                             "help me start Week 8's content?",
#                             'Are there any prerequisites I should review '
#                             "before diving into Week 8's Neural Networks "
#                             'topic?',
#                             'What practical exercises or projects are '
#                             'recommended for Week 8 to reinforce the concepts?',
#                             'How much time should I allocate each day to '
#                             "comfortably complete Week 8's workload?"]},
#  'ff4da2b6': ['How can I efficiently filter columns in a DataFrame based on '
#               'their data type?',
#               'What is the best way to extract only numeric columns from a '
#               'large dataset?',
#               'How do I retrieve all columns containing object (string) data '
#               'in a pandas DataFrame?',
#               'Is there a concise method to list columns by their dtype '
#               'without manually checking each one?',
#               'Can you explain how to use select_dtypes to filter columns in a '
#               'DataFrame?'],
#  'ff93b86e': ['What is the correct method to obtain feature importance from an '
#               'XGBoost model when using xgb.train?',
#               'Why do I get an AttributeError when trying to use '
#               'feature_importances_ with my XGBoost model?',
#               'How can I retrieve feature importance scores if my XGBoost '
#               'model is trained with xgb.train?',
#               'What alternative should I use instead of feature_importances_ '
#               'for an XGBoost Booster object?',
#               'Is there a different function to access feature importance if '
#               'the model is initialized with xgb.train?'],
#  'ffbf3311': None}

# %%
# Tu ejemplo
valor = '[\n    "What is the exact start date and time for the course?",\n    "How can I stay updated with the course schedule and important announcements?",\n    "Where do I need to register before the course begins?",\n    "Is there a specific platform or channel for course-related communication?",\n    "What should I do to ensure I don\'t miss the beginning of the course?"\n]'

valor_limpio = limpiar_valor(valor)
print("Valor limpio:", valor_limpio)

try:
    parsed = json.loads(valor_limpio)
    print("✅ JSON válido:", parsed)
except json.JSONDecodeError as e:
    print("❌ Error:", e)
# Out:
# Valor limpio: [ "What is the exact start date and time for the course?", "How can I stay updated with the course schedule and important announcements?", "Where do I need to register before the course begins?", "Is there a specific platform or channel for course-related communication?", "What should I do to ensure I don't miss the beginning of the course?" ]
# ✅ JSON válido: ['What is the exact start date and time for the course?', 'How can I stay updated with the course schedule and important announcements?', 'Where do I need to register before the course begins?', 'Is there a specific platform or channel for course-related communication?', "What should I do to ensure I don't miss the beginning of the course?"]

# %%
valor = results['c02e79ef']
valor_limpio = limpiar_valor(valor)
print("Valor original:", valor)
print("Valor limpio:", valor_limpio)
# Out:
# Valor original: [
#     "What is the exact start date and time for the course?",
#     "How can I stay updated with the course schedule and important announcements?",
#     "Where do I need to register before the course begins?",
#     "Is there a specific platform or channel for course-related communication?",
#     "What should I do to ensure I don't miss the beginning of the course?"
# ]
# Valor limpio: [ "What is the exact start date and time for the course?", "How can I stay updated with the course schedule and important announcements?", "Where do I need to register before the course begins?", "Is there a specific platform or channel for course-related communication?", "What should I do to ensure I don"t miss the beginning of the course?" ]

# %%
for item in results.items():
    limpiar_json_llm(item)[2]

# %%
results
# Out:
# {'c02e79ef': '[\n    "What is the exact start date and time for the course?",\n    "How can I stay updated with the course schedule and important announcements?",\n    "Where do I need to register before the course begins?",\n    "Is there a specific platform or channel for course-related communication?",\n    "What should I do to ensure I don\'t miss the beginning of the course?"\n]',
#  '1f6520ca': '[\n    "What background knowledge or skills do I need before enrolling in this course?",\n    "Are there any specific technical requirements I should meet to take this course?",\n    "Do I need prior experience with data engineering tools to join this course?",\n    "What are the recommended prerequisites to ensure I can follow the course material effectively?",\n    "Is there a list of required skills or tools I should be familiar with before starting the course?"\n]',
#  '7842b56a': '```json\n[\n  "Is it possible to enroll in the course after it has already begun?",\n  "What happens if I don\'t formally register but still want to participate?",\n  "Are there any deadlines I should be aware of if I join late?",\n  "Can I submit assignments if I join the course after the start date?",\n  "Will there be penalties for submitting the final project close to the deadline?"\n]\n```',
#  '0bbf41ec': '[\n    "If I haven\'t received a confirmation email after registering for the Data Engineering Bootcamp, does that mean I\'m not accepted?",\n    "Can I begin working on the course material and submitting assignments before receiving any confirmation?",\n    "Is registration mandatory to participate in the Data Engineering Bootcamp, or can I join without it?",\n    "How does the registration process for the Data Engineering Bootcamp work if it doesn\'t affect participation?",\n    "Will my homework submissions be checked if I haven\'t officially registered for the course?"\n]',
#  '63394d91': '[\n    "What are the recommended preparations I should complete before the course begins?",\n    "Which software tools and accounts do I need to set up prior to the course start date?",\n    "How can I ensure I meet the prerequisites for this course?",\n    "Is there a list of dependencies I should install before the course starts?",\n    "Where can I find the syllabus to review the topics covered in the course?"\n]',
#  '2ed9b986': '[\n    "How many Zoomcamp sessions are offered each year for the Data-Engineering course?",\n    "Can I enroll in the MLOps Zoomcamp outside of the May-August timeframe if I don\'t need certification?",\n    "Is the Machine Learning Zoomcamp the only one that runs into the next calendar year?",\n    "If I miss the live Data-Engineering cohort, can I still complete the course for certification later?",\n    "Are the schedules for each Zoomcamp cohort consistent from year to year?"\n]',
#  '93e2c8ed': '[\n    "How does the current cohort differ from the previous one in terms of tools and content?",\n    "What changes have been made to the course materials for the 2024 edition?",\n    "Why was Mage AI chosen over Prefect for the current cohort?",\n    "Were there any updates to the Terraform section compared to last year?",\n    "Can you explain the shift from Airflow to Prefect in the 2023 cohort?"\n]',
#  'a482086d': '[\n    "Will the course materials remain accessible once the course has ended?",\n    "Is it possible to complete assignments after the official course completion date?",\n    "Can I still work on the capstone project if I join after the course finishes?",\n    "Are there any limitations to accessing the content post-course?",\n    "How can I prepare for future cohorts using the current course materials?"\n]',
#  'eb56ae98': '[\n    "Is there any support available for students taking the self-paced version of the course?",\n    "How can I get help if I\'m stuck while studying at my own pace?",\n    "Are there any resources I should check before asking for assistance in the Slack channel?",\n    "Can I use the ZoomcampQABot to find answers to my questions in the Slack channel?",\n    "How reliable are the answers provided by the ZoomcampQABot when searching for solutions?"\n]',
#  '4292531b': '[\n    "What is the main YouTube playlist I should follow for the course videos?",\n    "Are there any additional playlists for specific years or office hours videos?",\n    "Where can I find the link to the main DATA ENGINEERING playlist?",\n    "Is the GitHub repository updated with direct links to the YouTube videos?",\n    "Where in the Slack channel can I find the pinned playlist for easy access?"\n]',
#  'ea739c65': '[\n  "How much weekly time commitment should I anticipate for this course based on my prior knowledge?",\n  "Can you provide guidance on estimating the weekly study hours needed for this course?",\n  "What factors influence the amount of time I\'ll need to dedicate to this course each week?",\n  "Is there a way to calculate the expected weekly workload for this course myself?",\n  "Where can I find resources to help me determine my personal time investment for this course?"\n]',
#  'cb257ee5': '[\n    "Is it possible to receive a course certificate if I complete the material at my own pace?",\n    "Why are certificates only awarded for the live cohort and not the self-paced version?",\n    "What is the reason behind requiring peer reviews for capstone projects to earn a certificate?",\n    "Can I still access the course content if I choose the self-paced mode without aiming for a certificate?",\n    "Are there any exceptions where a certificate might be granted for self-paced completion?"\n]',
#  '04aa4897': '[\n  "How can I access the live stream for Office Hour or workshop sessions?",\n  "Where is the YouTube Live link shared before the Office Hour starts?",\n  "Why shouldn\'t I post questions in the YouTube chat during Office Hours?",\n  "How do I submit questions during the Office Hour sessions?",\n  "Can I participate in Office Hours via Zoom, or is it only through YouTube Live?"\n]',
#  '9681be3b': '```json\n[\n    "Will the Office Hours sessions be available for viewing after the live session ends?",\n    "If I miss the live Office Hours, can I still access the recording later?",\n    "Are the Office Hours recordings posted immediately after the session concludes?",\n    "Is there a delay between the end of the live Office Hours and when the recording is available?",\n    "Can I rewatch the Office Hours sessions multiple times if needed?"\n]\n```',
#  'a1daf537': '```json\n[\n    "Where can I find the current deadlines for homework and projects in this course?",\n    "How will I be notified if there are any changes to the homework or project deadlines?",\n    "Is there a specific platform or link where all assignment deadlines are listed?",\n    "Who should I follow for updates regarding deadline extensions or other course announcements?",\n    "What should I do if the deadline shown in the course materials differs from the one announced by the instructor?"\n]\n```',
#  'be5bfee4': '[\n    "Is it possible to submit homework after the deadline if the submission form is still open?",\n    "What happens if I try to submit my homework late?",\n    "How can I verify that my homework submission was on time?",\n    "Are there any exceptions to the late submission policy for homework?",\n    "Where can I check the exact deadline for homework submissions?"\n]',
#  '0e424a44': '[\n    "Where can I find the homework assignments for this course?",\n    "Is there a specific platform we should use to submit our homework?",\n    "Can I use any version control system for my homework submissions?",\n    "What should be included in my homework submission to meet the requirements?",\n    "How do I ensure my homework is accessible and correctly submitted for grading?"\n]',
#  '29865466': '[\n    "How are homework assignments graded in the course management platform?",\n    "Where can I see the total points I\'ve earned for all my submissions?",\n    "What types of activities contribute to the points displayed on the leaderboard?",\n    "How many points do I receive for submitting a question to the FAQ section?",\n    "Is there a difference in points awarded for homework, FAQ submissions, and Learning in Public posts?"\n]',
#  '016d46a1': '[\n    "How can I find out what my display name is on the leaderboard?",\n    "Why don\'t I see my name on the leaderboard after setting up my account?",\n    "Where do I go to change my display name for the course?",\n    "Is it possible to customize my display name on the leaderboard?",\n    "What steps do I need to follow to view or update my profile in the course?"\n]',
#  '47972cb1': '```json\n["Is Python 3.9 still the best version to use for this course in 2024, or should I upgrade to a newer version?", "Will using Python 3.10 or 3.11 cause any issues with the course materials?", "Why does the course recommend sticking with Python 3.9 instead of the latest version?", "Are there any specific advantages to using Python 3.9 over newer versions for this course?", "If I encounter problems with a newer Python version, will troubleshooting support be provided?"]\n```',
#  'ddf6c1b3': '["What are the pros and cons of setting up the environment on my local machine versus using a virtual machine?", "Can I switch between using my local machine and GitHub Codespaces during the course, or do I need to stick to one option?", "Are there any specific challenges Windows users might face when setting up the environment locally?", "Is there a recommended approach for students who want to work across multiple devices, like home and office computers?", "Do I need prior experience with Docker to set up the environment locally, or will the course guide me through it?"]',
#  'ac25d3af': '[\n    "Can I use GitHub Codespaces instead of CLI tools like git bash for data ingestion and Docker file creation?",\n    "What are the advantages of using GitHub Codespaces over local CLI tools for this course?",\n    "Does GitHub Codespaces come with Docker and other necessary tools pre-installed?",\n    "Is it possible to directly open a GitHub repository in GitHub Codespaces for this course?",\n    "Are the computing resources provided by GitHub Codespaces sufficient for the course\'s Docker and data tasks?"\n]',
#  '251218fc': '["Is it mandatory to use GitHub Codespaces for the course, or can I use my local setup with PostgreSQL and Docker?", "Can I complete the course using my own laptop instead of GitHub Codespaces or GCP VM?", "Are there any advantages to using GitHub Codespaces over my existing local environment with Docker and PostgreSQL?", "What are the recommended environment options for the course if I don’t want to use GitHub Codespaces?", "If I already have Docker and PostgreSQL installed, do I still need to set up GitHub Codespaces for the coursework?"]',
#  '3c0114ce': '[\n  "Is it necessary to use both GitHub Codespaces and GCP for the course, or can I choose one?",\n  "Will BigQuery be required for the course, and if so, should I prioritize learning GCP?",\n  "Can I complete the course using only a local environment instead of cloud services?",\n  "What are the advantages of using GCP over GitHub Codespaces for this course?",\n  "If I prefer GitHub Codespaces, will I miss out on any critical course content?"  \n]',
#  'f43f5fe7': '```json\n["How can I open the Run command window on a Windows machine to access the registry editor?", "Where exactly in the Registry Editor do I need to modify the \'Autorun\' value for GCP VM connection issues?", "What specific change should I make to the \'Autorun\' registry value to resolve the VSCode-GCP VM connection problem?", "Is there an alternative solution to modifying the registry, such as dealing with the known_hosts file?", "Where is the known_hosts file located on a Windows system if I want to delete the fingerprint manually?"]\n```',
#  'd061525d': '[\n    "Why is GCP the recommended cloud platform for this course instead of alternatives like AWS or Azure?",\n    "Am I allowed to use a different cloud provider like AWS if I\'m more familiar with it?",\n    "What are the benefits of using GCP for this course, especially for students?",\n    "Do I need a credit card to sign up for the GCP free trial mentioned in the course?",\n    "Is BigQuery a mandatory tool for the course, and does it require a GCP account?"\n]',
#  '1cd01b2c': '["Is there any cost associated with using cloud services for this course?", "Do I need to pay for Google Cloud Platform during the course?", "Are there any free options available for cloud services in this course?", "Will the course cover how to use GCP\'s free trial?", "Is financial assistance available for cloud service usage in this course?"]',
#  'e4a7c3b0': '```json\n["Is it possible to complete the course without using cloud providers like GCP?", "Are there local alternatives for all the tools used in the course?", "Will the course provide instructions for setting up a home lab environment?", "Can I run BigQuery locally or is there a substitute for it?", "What limitations should I expect if I choose to do the course entirely locally?"]\n```',
#  '7cd1912e': '[\n    "Can I use AWS for all the course projects and assignments?",\n    "What are the potential challenges of using AWS instead of the recommended platform?",\n    "Will using AWS affect how my final capstone project is evaluated?",\n    "How can I get help if I encounter issues while using AWS for the course?",\n    "Are there any specific adjustments I need to make when using AWS instead of the default platform?"\n]',
#  '52393fb3': '["Are there any additional live Zoom sessions scheduled apart from the Office Hours?", "Will there be any live calls during the Capstone project phase?", "How will we be informed about any extra live Zoom meetings?", "Can we expect any surprise live sessions, or will they all be announced beforehand?", "Is the Capstone period the only time when extra live calls might happen?"]',
#  '10515af5': '[\n    "Is the NYC Trip dataset for January 2021 still the one we\'re working with this year, or has it been updated to 2022?",\n    "Will there be any changes to the project requirements compared to last year\'s course?",\n    "Where can I access the dataset required for the project?",\n    "Are we expected to use the same methodology as last year\'s students for this project?",\n    "Is there any additional data we should incorporate beyond the provided NYC Trip dataset?"\n]',
#  'cdb86a97': '[\n    "Is the repository for the 2022 course materials still available?",\n    "Where can I find the content from the 2022 version of the course?",\n    "Has the 2022 course material been removed or relocated?",\n    "Can I still access the previous year\'s (2022) course resources?",\n    "What happened to the 2022 course repository? Is it no longer accessible?"\n]',
#  '3e0114ad': '["Is it acceptable to utilize a different tool like Airflow for the final project submission?", "Are there any restrictions on the tools we can choose for our final project?", "Would using a tool other than the ones taught in the course be allowed for the project?", "Can students select their preferred software or platform for the final assignment?", "Is Airflow an approved tool for completing the course\'s final project requirements?"]',
#  'b2799574': '[\n    "Can I use a different data orchestration tool like Airflow or Prefect instead of Mage for the course projects?",\n    "Are we allowed to substitute AWS or Snowflake for the GCP products mentioned in the course materials?",\n    "If I prefer Tableau over Metabase or Google Data Studio, can I use it for visualization assignments?",\n    "What are the implications of choosing an alternative tool stack that differs from the ones covered in the course?",\n    "Will the instructors provide support if I decide to use a different set of tools than those recommended in the course?"\n]',
#  '2f19301f': '["How can I help improve the course materials?", "What are the ways to support this course?", "Is there a way to suggest changes to the repository?", "Can I share this course with others if I find it helpful?", "What contributions are welcome for this course?"]',
#  '7c700adb': '["Is the course compatible with Windows, macOS, and Linux operating systems?", "Do I need a specific operating system to successfully complete the course?", "Are there any advantages to using Linux over other operating systems for this course?", "Have students previously used different operating systems without issues in this course?", "Will using a non-Linux OS put me at a disadvantage in the course?"]',
#  '44b14808': '["What should Windows users do if they encounter issues with shell scripts in the course modules?", "Why is WSL recommended for Windows users in this course?", "Are there any known workarounds for Windows users who can\'t use WSL with shell scripts?", "Which specific modules in the course are problematic for Windows users without WSL?", "How have past cohorts handled the shell script challenges on Windows?"]',
#  '76e4baf6': '["Are there any recommended books or materials to supplement the course content?",  \n"Can you suggest additional resources to enhance my understanding of the course topics?",  \n"Where can I find a list of recommended readings for this course?",  \n"Do you have any external resources or books that align with the course curriculum?",  \n"Is there a compilation of suggested materials to further explore data engineering concepts?"]',
#  '48b533a8': '[\n    "What are the differences between Project Attempt #1 and Project Attempt #2?",\n    "Can I submit my project after the first deadline if I missed it?",\n    "If I fail the first project submission, do I get another opportunity to submit it?",\n    "How many chances do I have to complete the project successfully?",\n    "Is there a penalty for submitting the project during the second attempt?"\n]',
#  '954044d1': '```json\n[\n    "What should I do first when I encounter a technical issue in the course?",\n    "How can I effectively search for solutions to errors or problems I encounter?",\n    "What information should I include when asking for help in Slack or other forums?",\n    "Why is it discouraged to tag instructors directly when asking for help?",\n    "What should I do if none of the troubleshooting steps resolve my issue?"\n]\n```',
#  'a820b9b3': '```json\n[\n    "What should I do if the troubleshooting guide doesn\'t resolve my issue?",\n    "What details should I include when asking for help with a coding problem?",\n    "Why is it important to mention what I\'ve already tried when seeking assistance?",\n    "How can I ensure my question gets a helpful response from the course staff?",\n    "Where can I find guidance on how to properly ask questions in this course?"\n]\n```',
#  'f2945cd2': '[\n  "What steps should I follow to set up Git and GitHub for this course?",\n  "How can I clone the course repository to my local machine?",\n  "Are there any specific files or data types I should avoid including in my GitHub repositories?",\n  "Where can I find tutorials or resources for creating and managing my own repositories?",\n  "Is it safe to store sensitive information like passwords or keys in a private GitHub repository?"\n]',
#  'eb9d376f': '[\n    "Why am I getting the \'missing separator\' error in my Makefile and how can I fix it?",\n    "How do I change VS Code settings to use tabs instead of spaces for indentation?",\n    "What should I do when my Makefile fails with a separator error?",\n    "Can you explain why tabs are required in Makefiles and how to ensure they\'re used?",\n    "Where can I find guidance on converting spaces to tabs in VS Code for Makefile compatibility?"\n]',
#  '72f25f6d': '```json\n[\n    "How can I open an HTML file in a Windows browser when using Linux on WSL?",\n    "What command should I use to view an HTML file from WSL in my default Windows browser?",\n    "Is it possible to specify a different browser to open HTML files from WSL on Windows?",\n    "How do I set up WSL to open HTML files directly in a Windows browser?",\n    "Can I customize which browser opens HTML files from WSL, and if so, how?"\n]\n```',
#  'a1e59afc': '```json\n[\n    "How can I set up Chrome Remote Desktop on a Debian Linux VM in Compute Engine?",\n    "What should I do if I encounter an ERROR 403 when downloading Yellow Taxi Trip Records from the TLC website?",\n    "Is there a backup source available for the 2021 Yellow Taxi Trip data if the original link fails?",\n    "How do I properly unzip the \'gz\' file for the Yellow Taxi Trip data?",\n    "Can you explain the purpose of using Chrome Remote Desktop for accessing applications on a Linux VM?"\n]\n```',
#  '71c10610': '["How should I name the taxi data file to ensure it stores correctly in the course exercise?",  \n"What is the correct way to handle the file extension when working with the provided taxi data URL?",  \n"Can I use the original .csv.gz file extension when reading the taxi data with pandas, or do I need to change it?",  \n"How can I extract the file name from the taxi data URL to use it in my code?",  \n"Why does the course recommend changing the file name from .csv.gz to .csv, and is it necessary for pandas?"]',
#  '17a5aea1': '```json\n[\n    "Where can I find the data dictionary for the Yellow Taxi trip records in Module 1?",\n    "Is there a separate data dictionary available for the Green Taxi trips in the NY Taxi dataset?",\n    "What is the official source for the data dictionaries of the NY Taxi trip records?",\n    "Can you provide links to the documentation for the Yellow and Green Taxi data in Module 1?",\n    "Are the data dictionaries for the NY Taxi datasets provided in PDF format?"\n]\n```',
#  '5a275db7': '[\n    "How can I unzip the downloaded parquet file for the taxi data using the command line?",\n    "What is the command to convert the gzipped parquet file into a CSV file?",\n    "How do I modify the ingest_data.py script to directly use parquet files instead of CSV?",\n    "What changes should I make in the main function to handle parquet file downloads and conversions?",\n    "Can you explain how to convert a parquet file to a CSV file within a Python script using pandas?"\n]',
#  '7ec0f9b0': '```json\n[\n  "How do I fix the \'wget is not recognized as an internal or external command\' error on Ubuntu?",\n  "What is the easiest way to install wget on a MacOS system?",\n  "Can you guide me through installing wget on Windows using Chocolatey?",\n  "Is there an alternative method to install wget on Windows without using Chocolatey?",\n  "Are there Python-based alternatives to using the wget command for downloading files?"\n]\n```',
#  'bb1ba786': '```json\n[\n    "How can I resolve the \'cannot verify website certificate\' error when using wget on MacOS?",\n    "What should I do if wget fails to verify a certificate in a Jupyter Notebook?",\n    "Are there alternative methods to download files using wget if certificate verification fails?",\n    "Can I bypass certificate checks when running wget from the command line?",\n    "What is the correct syntax for using wget with the --no-check-certificate flag?"\n]\n```',
#  '2f83dbe7': '```json\n[\n    "How can I configure Git Bash on Windows to treat backslash as an escape character?",\n    "What command should I use in Git Bash for Windows to enable backslash escaping?",\n    "Is it necessary to modify the .bashrc file to use backslash as an escape character in Git Bash?",\n    "Can you explain the correct syntax for setting the escape character in Git Bash for Windows?",\n    "Why might someone prefer using backslash as an escape character in Git Bash, and how can they enable it?"\n]\n```',
#  '543ff080': '[\n    "How can I securely store and access secrets within GitHub Codespaces for my projects?",\n    "What is the recommended method to manage account-specific secrets in GitHub Codespaces?",\n    "Where can I find detailed instructions for handling secrets in GitHub Codespaces?",\n    "Is there a specific documentation resource for managing secrets in GitHub Codespaces?",\n    "Can you explain the process of making secrets available in GitHub Codespaces?"\n]',
#  'd407d65b': '["What should I do if I encounter an error saying Docker daemon is not running when trying to connect to unix:///var/run/docker.sock?", "How can I ensure the Docker daemon is properly started before attempting to connect?", "What steps should I take if I receive a connection error to the Docker daemon on my system?", "Is there a specific command I need to run to update WSL before resolving Docker daemon issues?", "Why am I unable to connect to the Docker daemon, and what troubleshooting steps should I follow?"]',
#  'c9375c56': '```json\n[\n    "Why do I get an error saying the Docker client must be run with elevated privileges on Windows?",\n    "How can I enable Hyper-V for Docker on Windows 10 Pro or 11 Pro?",\n    "What should I do if I\'m using Windows Home edition and can\'t use Hyper-V for Docker?",\n    "Where can I find detailed instructions to set up WSL2 for Docker on Windows?",\n    "What steps should I take if I encounter the \'WslRegisterDistribution failed with error: 0x800701bc\' issue?"\n]\n```',
#  'e866156b': '```json\n[\n    "Why do I get a \'repository does not exist\' error when pulling a Docker image, and how can I fix it?",\n    "Do I need to log in to Docker Hub to pull the images used in the Data Engineering Zoomcamp?",\n    "What should I do if I encounter a \'permission denied\' error while mounting a volume in a PostgreSQL Docker container on macOS M1?",\n    "Is it necessary to use Docker Desktop instead of Rancher Desktop for the course exercises?",\n    "How can I verify if a Docker image name is correct before pulling it to avoid errors?"\n]\n```',
#  '16370470': '["Why can\'t I delete a local folder that was mounted as a Docker volume?",  \n"How do I remove a Docker-created folder that has restricted permissions?",  \n"What command should I use to force-delete a protected folder created by Docker?",  \n"Why does Obsidian fail to start due to a folder access error related to Docker?",  \n"How can I change the ownership or permissions of a folder created by a Docker container?"]',
#  '316df755': '["What should I do if Docker is stuck on the starting screen in Windows 10 or 11?",  \n"How can I switch between container types if Docker is not starting properly?",  \n"Where can I download the latest version of Docker for Windows if the in-app upgrade fails?",  \n"Do I need to enable Hyper-V to run Docker on Windows 10/11 Pro, and how do I do it?",  \n"What are the steps to configure WSL2 as the backend for Docker on Windows?"]',
#  'f3aa9252': '[\n    "What is the recommended file system for running Docker commands on Windows with WSL?",\n    "Can I use Docker with Windows 10/11 Home Edition, and if so, how?",\n    "What should I do if Docker gets stuck even after setting up WSL2 or Hyper-V correctly?",\n    "Is it better to run Docker commands from the Windows file system or the WSL Linux file system?",\n    "Are there any troubleshooting steps if Docker doesn\'t work properly after WSL2 setup?"\n]',
#  'a4abe7a5': '```json\n[\n    "What is the recommended way to store code for optimal file system performance when using Docker on Windows 10/11 Home?",\n    "Does Docker on WSL2 backend have specific requirements for code storage to ensure performance?",\n    "Where can I find detailed guidelines on best practices for Docker file system performance?",\n    "Is there a preferred location to store code when running Docker with WSL2 on Windows Home editions?",\n    "How does the default Linux distro in Docker impact file system performance for Windows users?"\n]\n```',
#  'fb930700': '```json\n[\n  "Why do I get the error \'the input device is not a TTY\' when running Docker on Windows?",\n  "How can I fix the \'input device is not a TTY\' issue in Docker for Windows?",\n  "What is the solution for the TTY error when using Docker with mintty on Windows?",\n  "Can I create an alias to avoid typing \'winpty\' before every Docker command?",\n  "Where should I add the alias to make \'winpty docker\' the default on Windows?"\n]\n```',
#  'aa187680': '```json\n[\n    "Why am I getting a \'Temporary failure in name resolution\' error when trying to pip install inside a Docker container on Windows?",\n    "How can I resolve the pip installation failure due to DNS issues in a Docker container?",\n    "What is the correct Docker run command to fix pip install errors related to name resolution?",\n    "Why does my Docker container fail to connect to the internet when running pip install on Windows?",\n    "What DNS settings should I use in Docker to avoid pip install connection problems on Windows?"\n]\n```',
#  'b000e899': '[\n    "Why is the ny_taxi_postgres_data folder empty in VS Code after running the Docker script?",\n    "What specific command should I use to resolve the empty folder issue in Docker for Windows?",\n    "How do I properly set the volume path in Docker to ensure data appears in ny_taxi_postgres_data?",\n    "Are there any environment variables I need to configure to fix the empty folder problem in Docker?",\n    "What could be causing the data not to appear in the ny_taxi_postgres_data folder despite running the script correctly?"\n]',
#  '9c66759f': '[\n  "What is the recommended method for setting up Docker on a Mac?",\n  "Is the traditional method of installing Docker on macOS still reliable?",\n  "Where can I find the most up-to-date Docker installation for Mac?",\n  "Why might the older Docker setup method for Mac not work properly?",\n  "Has Docker\'s licensing change affected the installation process on macOS?"\n]',
#  'e3106e07': '[\n    "When running a PostgreSQL container, I get an error saying \'could not change permissions of directory \\"/var/lib/postgresql/data\\": Operation not permitted\'. How can I resolve this?",\n    "What is the correct way to map a local volume to the PostgreSQL data directory in Docker to avoid permission issues?",\n    "How do I create and use a Docker volume for PostgreSQL data instead of a local directory to prevent permission errors?",\n    "After running the Docker command for PostgreSQL, how can I verify that the volume was created successfully?",\n    "I encountered another error stating \'directory \\"/var/lib/postgresql/data\\" exists but is not empty\'. What should I do in this case?"\n]',
#  '72229da5': '["Why am I getting an \'invalid reference format\' error when trying to mount Docker volumes on Windows?",  \n"What are some alternative ways to format the volume mapping command to avoid issues on Windows?",  \n"How can I fix the problem where Docker creates an incorrect folder name when mounting volumes?",  \n"Are there any specific syntax changes needed for Mac users when mounting volumes in Docker?",  \n"What should I do if none of the suggested volume mapping options work on my system?"]',
#  '58c9f99f': '```json\n[\n    "How can I resolve the \'invalid mode\' error when mounting a volume in Docker on Windows?",\n    "What should I do if Docker gives an error about the mounting path being invalid?",\n    "Why does Docker complain about the mode when I try to mount a volume in Windows?",\n    "What is the correct way to specify a volume mount path in Docker for Windows to avoid errors?",\n    "Can you explain how to fix the mounting path issue in Docker when using Git Bash on Windows?"\n]\n```',
#  'bc42139a': '[\n    "Why am I getting the error \'Error response from daemon: error while creating buildmount source path\' when running my Docker container a second time?",\n    "How can I resolve the issue where Docker fails to mount a volume on subsequent runs of the same container?",\n    "What changes should I make to my Docker command to avoid the \'file exists\' error when re-running a container with a mounted volume?",\n    "Is it necessary to mount the volume every time I run the same Docker container, or can I skip it after the first run?",\n    "What is the correct way to run a PostgreSQL container in Docker after the initial setup to avoid mounting conflicts?"\n]',
#  'a146e3ee': '["Why am I getting a \'can\\\\\'t stat\' error when trying to build my Docker image for the taxi ingest project?",  \n"How can I resolve permission issues when Docker can\\\\\'t access a directory during the build process?",  \n"What files are strictly necessary to include when running the \'docker build\' command for this project?",  \n"Are there different solutions for fixing directory permission issues on Ubuntu versus Windows for Docker builds?",  \n"Where can I find a more detailed explanation for troubleshooting Docker build context errors?"]',
#  '593a85ba': '```json\n["Why do I get \'ERRO[0000] error waiting for container: context canceled\' when using Docker?", "How can I check if Docker was installed via snap?", "What should I do if \'snap status docker\' returns an unknown command error?", "Why does Docker fail to bind to port 0.0.0.0:5432?", "What is the recommended way to install Docker to avoid these issues?"]\n```',
#  '50bd1a71': '```json\n[\n    "Why am I getting a \'can’t stat\' error when trying to build a Docker image in PopOS Linux?",\n    "What could be causing the Docker build context to fail with a permissions issue in my project folder?",\n    "How do I resolve the \'can’t stat\' error related to folder permissions in Docker on PopOS?",\n    "Why does my host folder appear empty in Docker even though it contains files?",\n    "What command should I use to grant Docker the necessary permissions to access a folder in PopOS?"\n]\n```',
#  'f409f751': '["Why do I get a permission denied error when trying to rebuild my Docker container on Ubuntu?",  \n"How can I resolve the \'failed to solve with frontend dockerfile.v0\' error in Docker?",  \n"What does the error \'error from sender: open ny_taxi_postgres_data: permission denied\' mean in Docker?",  \n"Which permission settings should I use for the ny_taxi_postgres_data folder to fix Docker build issues?",  \n"Is it safe to use chmod 777 for the ny_taxi_postgres_data folder when facing Docker permission problems?"]',
#  '7d217da3': '```json\n[\n    "How can I find out the name of a Docker network in Module 1?",\n    "What command should I use to list all Docker networks in this module?",\n    "Where can I locate the Docker network name as mentioned in Module 1?",\n    "Is there a specific Docker command to retrieve network names in Module 1?",\n    "How do I check the available Docker networks for the exercises in Module 1?"\n]\n```',
#  '09081824': '```json\n[\n    "What should I do when Docker shows an error that the container name \'pg-database\' is already in use?",\n    "How can I resolve the conflict when Docker says a container name is already taken by another container?",\n    "Why does Docker give a \'Conflict\' error when trying to reuse a container name, and how do I fix it?",\n    "What steps should I follow to remove or rename a Docker container that\'s causing a naming conflict?",\n    "Can I restart a Docker container without removing it if the name is already in use, and how?"\n]\n```',
#  '4df80c55': '["What does the error \'could not translate host name \\"pgdatabase\\" to address\' mean when using docker-compose?",  \n"How can I resolve the host name translation error in Docker when running an ingestion script?",  \n"Which network should I use in the ingestion script if the default \'pg-network\' isn\'t working?",  \n"Why does the database host name change when running \'docker-compose up -d\', and how do I find the correct one?",  \n"What adjustments are needed in the ingestion script if the Docker network or database name differs from the default?"]',
#  '3aee7261': '```json\n[\n    "What should I do if I can\'t install Docker on a MacOS or Windows 11 VM running on Linux due to nested virtualization issues?",\n    "Are there specific commands I need to run before starting my VM to resolve Docker installation problems on a Linux-hosted VM?",\n    "How do I enable nested virtualization for Docker installation on an Intel CPU-based system?",\n    "What steps are required to configure nested virtualization for Docker on an AMD CPU when using a Linux-hosted VM?",\n    "Why does Docker fail to install on my MacOS/Windows 11 VM running on Linux, and how can I fix it?"\n]\n```',
#  '6497b659': '```json\n[\n    "How can I manage Docker containers and images directly from VS Code?",\n    "What is the process for connecting VS Code to Docker running on WSL2?",\n    "Which extension should I install in VS Code to work with Docker?",\n    "What command should I use to stop a running Docker container?",\n    "Can VS Code interact with Docker Compose projects, and if so, how?"\n]\n```',
#  'a02f2039': '```json\n[\n    "Why does my PostgreSQL container show a message about the database directory containing a database but the system is shut down?",\n    "What does it mean when the server terminates abnormally while processing a request in a PostgreSQL container?",\n    "How can I resolve the issue where my Dockerized PostgreSQL container is not accepting any connections?",\n    "What should I do if I encounter the error \'connection failed: server closed the connection unexpectedly\' in my PostgreSQL container?",\n    "Why do I need to delete the mapped data directory and restart the container when my PostgreSQL database fails to start?"\n]\n```',
#  'c6db65aa': '["Why can\'t I install Docker on my Ubuntu system using the standard package manager?", "What alternative method can I use to install Docker if the traditional approach fails on Ubuntu?", "Is there a specific command I should run to install Docker via snap on Ubuntu?", "Are there certain Ubuntu versions where Docker installation through apt doesn\'t work?", "How do I resolve Docker installation issues on Ubuntu when the conventional method isn\'t available?"]',
#  'f476a606': '[\n    "Why am I getting a \'could not change permissions\' error when mounting a directory in Docker-Compose for Postgres?",\n    "How do I properly configure a named volume in Docker-Compose to avoid mounting issues?",\n    "What steps should I take if Docker-Compose creates a new volume instead of using the existing one?",\n    "How can I check the mount location of a Docker volume to troubleshoot permission errors?",\n    "What is the correct way to rename or adjust Docker volumes to resolve mounting conflicts in Docker-Compose?"\n]',
#  'e41b100c': '```json\n[\n    "Why am I getting the error \'Couldn’t translate host name to address\' when using Docker-Compose?",\n    "How do I start the PostgreSQL database and pgAdmin containers in detached mode?",\n    "What command should I use to check if my containers are running after starting them?",\n    "How can I view the logs for a specific container to troubleshoot issues?",\n    "What should I do if the PostgreSQL container is not listed when I run \'docker ps\'?"\n]\n```',
#  'cd0f9300': '```json\n[\n    "Why does my Docker-Compose setup lose database data after running `docker-compose up`?",\n    "How can I resolve the \'could not translate host name pg-database\' error in my Ingestion script?",\n    "What should I do if Docker-Compose creates an unexpected default network?",\n    "Where can I find the network name that Docker-Compose generates for my containers?",\n    "Are there alternative tools like pgcli that I can use if issues persist with database connections?"\n]\n```',
#  '7f845a1c': '["Why am I getting an error that the hostname does not resolve when using Docker-Compose?",  \n"What steps should I take if Docker-Compose cannot find the network for my containers?",  \n"How can I fix the issue where my localhost server cannot connect to the PostgreSQL database due to hostname resolution?",  \n"What naming conventions should I follow for hostnames in Docker-Compose to avoid resolution errors?",  \n"How do I properly configure networks in docker-compose.yml to ensure containers can communicate with each other?"]',
#  '36e54439': '```json\n["How can I persist PGAdmin data when using Docker-Compose on GCP?", "Why isn\'t my specified volume path working for PGAdmin in Docker-Compose?", "What is the alternative to using a local path for PGAdmin volumes in Docker-Compose?", "How do I configure Docker Volumes to ensure PGAdmin data persistence on GCP?", "Can you explain the correct way to set up volumes for PGAdmin in a Docker-Compose file?"]\n```',
#  '32e8450c': '[\n    "Why does Docker Engine keep crashing and showing \'failed to fetch extensions\' errors repeatedly?",\n    "What should I do if restarting Docker doesn\'t resolve the continuous crashing issue?",\n    "How can I fix the persistent \'failed to fetch extensions\' pop-up errors in Docker?",\n    "Is updating Docker to the latest version a solution for the crashing and extension errors?",\n    "If updating Docker doesn\'t work, what is the final step to resolve the crashing and extension fetch issues?"\n]',
#  '96606db2': '```json\n[\n    "How can I persist pgAdmin configuration settings like server names in Docker-Compose?",\n    "What is the correct way to mount a volume for pgAdmin session data in a Docker-Compose file?",\n    "Why do I need to adjust permissions for the \'pgAdmin_data\' folder before running docker-compose up?",\n    "Which environment variables are required for pgAdmin in Docker-Compose to set up default credentials?",\n    "What are the UID and GID of the user running the pgAdmin container, and why are they important for volume permissions?"\n]\n```',
#  '0882bfac': '[\n    "How can I resolve the \'permission denied\' error when trying to connect to Docker\'s socket in Docker-Compose?",\n    "What steps should I follow to ensure my user has the correct permissions to run Docker commands without sudo?",\n    "Why does pgAdmin forget my database connection settings every time I restart the containers, and how can I fix this?",\n    "What changes do I need to make in my docker-compose.yaml file to persist pgAdmin\'s connection settings?",\n    "Where can I find detailed instructions for setting up Docker to avoid permission issues and maintain pgAdmin state?"\n]',
#  '7d067f5c': '["Why is docker-compose not working even after updating my .bashrc file?", "How can I fix the issue where docker-compose command is not recognized after installation?", "What should I do if the downloaded docker-compose file has a different name than expected?", "Why am I unable to use the docker-compose command despite following the installation steps?", "How do I rename the docker-compose file to make the command work properly?"]',
#  'ff352621': '["What should I do if I encounter an error about credentials when running docker-compose up -d?",  \n"How can I resolve the Docker-Compose credential error mentioned in Module 1?",  \n"After running docker-compose up -d, I get an error related to credentials. What is the solution?",  \n"Where can I find more information about fixing the Docker-Compose credential error?",  \n"Which package do I need to install to fix the Docker-Compose credential issue?"]',
#  '2d653208': '[\n    "What should I do if I encounter errors with my docker-compose.yml file while setting up pgadmin?",\n    "How can I resolve issues related to data ingestion when using Docker-Compose with PostgreSQL?",\n    "What steps should I follow to ensure proper execution of the Docker-Compose setup for this module?",\n    "Why is it important to set low_memory=False when importing CSV files in this Docker setup?",\n    "How do I configure pgadmin to connect to the PostgreSQL database created by Docker-Compose?"\n]',
#  'f09ea61e': '["What should I do if I encounter an error stating \'docker-credential-desktop\' executable file not found when running \'docker compose up -d\'?",  \n"Where can I find the Docker config.json file to fix the credential store error?",  \n"How do I modify the Docker configuration to resolve the \'executable file not found\' issue?",  \n"What is the difference between \'credsStore\' and \'credStore\' in Docker\'s config.json file?",  \n"After fixing the config.json file, do I need to restart Docker or just re-run the command?"]',
#  'fbd3d2bb': '```json\n[\n    "How do I determine the correct docker-compose binary to download for WSL?",\n    "What commands should I run to check my system before downloading docker-compose?",\n    "Where can I find the appropriate docker-compose binary for my WSL setup?",\n    "Is there a direct command to download and install docker-compose for WSL?",\n    "What do \'uname -s\' and \'uname -m\' outputs indicate when setting up docker-compose?"\n]\n```',
#  '0b014d0c': '["Why am I getting an undefined volume error when running Docker-Compose in Windows/WSL?",  \n"How can I fix the \'invalid compose project\' error related to the pgdatabase service in my docker-compose.yaml?",  \n"What changes do I need to make in my docker-compose file to resolve the undefined volume issue?",  \n"Where exactly should I place the volumes section in my docker-compose.yaml to avoid errors?",  \n"Can you explain why my Docker-Compose setup fails with a volume-related error even though I followed the video instructions?"]',
#  'd21bff1d': '["Why do I encounter a directory permissions error when using Docker with WSL?",  \n"How can I resolve permission conflicts between WSL and Windows in Docker?",  \n"What is the recommended way to handle persistent data storage in Docker to avoid permission issues?",  \n"Is the \'user\' field necessary in docker-compose.yaml when using Docker volumes?",  \n"Can you explain the difference between using Docker volumes and local file system storage for PostgreSQL in Docker?"]',
#  '6afb7b55': '["What should I do if pgadmin is not working for querying in Postgres?", "Why does pgadmin fail to work easily on git bash or VM in Windows?", "What libraries are required for pgadmin to work, and what if the error persists?", "How can I use psql instead of pgadmin for querying in Postgres?", "What is the command to install psycopg2 for using psql?"]',
#  'b51c3b82': '["Why am I getting an \'Insufficient system resources\' error when using WSL?", "How can I resolve the \'Insufficient system resources\' issue in WSL?", "What steps should I take to update Windows Terminal to fix WSL errors?", "Are there specific Windows updates needed to address WSL resource problems?", "After updating Windows Terminal and security updates, do I need to restart my system?"]',
#  '326af690': '["Why does my WSL integration with Ubuntu suddenly stop with exit code 1, and how can I fix it?",  \n"What should I do if restarting Docker doesn\'t resolve the WSL integration issue?",  \n"How can I fix DNS-related problems causing WSL to crash unexpectedly on Windows?",  \n"Why am I seeing \'conda: command not found\' in my terminal, and how do I resolve it?",  \n"What does \'Database is uninitialized and superuser password is not specified\' mean, and how do I address it?"]',
#  'c2ec9047': '["Why am I getting a permissions error when trying to SSH into the GPC VM from WSL2?", "How can I resolve the \'Permissions too open\' issue when using SSH in WSL2?", "What steps should I take if running \'ssh -i gpc\' fails due to permission problems?", "Is there a way to fix SSH key permissions in WSL2 without using sudo?", "How do I properly set up the .ssh folder in WSL2 to avoid SSH key permission errors?"]',
# ...
#  'd2719204': '["What are the default login credentials for Grafana when accessing it through localhost?", "Why am I being prompted for a username and password when I try to access Grafana after running docker-compose up?", "How can I change the default password after logging into Grafana for the first time?", "Is there a specific video or resource that demonstrates how to resolve the Grafana login issue?", "Where can I find additional help if the default credentials don\'t work for Grafana?"]',
#  '30b8e8e6': '["Why do I get an \'unknown flag: --build\' error when trying to start monitoring services in Linux?",  \n"What is the correct command to start monitoring services in Linux if \'docker compose up --build\' doesn\'t work?",  \n"Can you explain the difference between \'docker compose\' and \'docker-compose\' in Linux?",  \n"How do I resolve the issue where the monitoring services fail to start in Module 5?",  \n"Is there a specific reason why \'docker compose up --build\' doesn\'t work in Linux but \'docker-compose up --build\' does?"]',
#  'f33fc6e9': '```json\n{\n  "questions": [\n    "Why am I getting a KeyError \'content-length\' when running prepare.py?",\n    "What is the solution for the KeyError \'content-length\' issue in prepare.py?",\n    "The link in prepare.py for downloading taxi data doesn\'t work—how can I fix it?",\n    "How do I modify the URL in prepare.py to resolve the KeyError?",\n    "Can you provide the updated URL for downloading taxi data in prepare.py?"\n  ]\n}\n```',
#  'd828de2a': '["What does it mean when the Evidently service exits with code 2 during docker-compose up?",  \n"How can I resolve the \'Max retries exceeded with url: /api\' error when running the real-time prediction service?",  \n"Why does the Evidently service fail to import \'pyarrow\' in app.py, and how can I fix it?",  \n"What are the possible solutions if the Evidently service crashes due to a missing pyarrow module?",  \n"Is it safe to comment out the pyarrow import in app.py if the other solutions don\'t work?"]',
#  '03f20ec1': '```json\n[\n  "Why am I getting a ValueError about an incorrect item when passing a metric to Report in evidently?",\n  "What does the error \'ValueError: Incorrect item instead of a metric or metric preset was passed to Report\' mean in Module 5?",\n  "How can I fix the ValueError when using evidently to generate a report?",\n  "I encountered an error saying I passed an incorrect item to Report in evidently—what did I do wrong?",\n  "When using evidently, what is the common mistake that leads to the \'Incorrect item instead of a metric\' error?"\n]\n```',
#  '249726fe': '```json\n{\n  "questions": [\n    "What should I do if I encounter an error when using the RegressionQualityMetric() function?",\n    "Why is the target=\'duration_min\' parameter necessary for RegressionQualityMetric()?",\n    "How do I properly set up the current_data[\'duration_min\'] for RegressionQualityMetric()?",\n    "What are the specific requirements for using RegressionQualityMetric() in Module 5?",\n    "Can you explain the role of \'duration_min\' in the RegressionQualityMetric() function?"\n  ]\n}\n```',
#  '4e492af0': '```json\n[\n  "Why am I getting a ValueError stating \'Found array with 0 sample(s)\' when running LinearRegression?",\n  "What causes the training dataset to be empty in Module 5?",\n  "How can I resolve the issue of having 0 samples in my dataset?",\n  "What specific adjustment should I make to the \'begin\' date to avoid this error?",\n  "Who added the solution for the \'Found array with 0 sample(s)\' error in the FAQ?"\n]\n```',
#  '10011dc1': '[\n    "What should I do if I encounter errors about missing target or prediction columns after adding a new metric?",\n    "How can I determine whether a metric requires specific parameters when adding it to my monitoring setup?",\n    "Why did I not need to specify any parameters when adding DatasetCorrelationsMetric?",\n    "Where can I find detailed information about the requirements for adding different metrics in Module 5?",\n    "What steps should I take to troubleshoot errors related to metric configuration in monitoring?"\n]',
#  '92fb909a': '["Why am I unable to log in to Grafana using the default admin credentials?", "What should I do if Grafana shows an error when I try to log in with the standard username and password?", "How can I resolve the login issue in Grafana when admin/admin doesn\'t work?", "What command should I run to fix the Grafana admin password problem?", "After encountering a login error in Grafana, how do I reset the admin password?"]',
#  '2b8cb640': '```json\n[\n  "Why isn\'t my Grafana chart updating in real-time while my metric script is running?",\n  "What refresh interval should I set in Grafana to ensure my charts update frequently?",\n  "How does the timezone setting affect Grafana chart updates?",\n  "I changed my timezone from \'Europe/London\' to my local zone, but why was this necessary for updates?",\n  "Are there specific settings in Grafana or my script that could prevent chart updates?"\n]\n```',
#  'd4ceab0b': '[\n    "Why did my local Prefect server stop immediately after running the \'prefect server start\' command?",\n    "What alternative solution can I use if the Prefect server fails to run locally?",\n    "Did the issue with the local Prefect server get reported or tracked anywhere?",\n    "How can I switch to using Prefect Cloud instead of a local server for running my scripts?",\n    "What steps should I take if I encounter a similar issue with the Prefect server in the future?"\n]',
#  '482e575f': '["What should I do if I encounter a \'no disk space left\' error while running docker compose up?",  \n"How can I free up disk space when Docker is causing storage issues?",  \n"What command can I use to check Docker\'s disk usage before cleaning up?",  \n"Is there a way to remove unused Docker items to resolve disk space errors?",  \n"Can you explain how to clean up Docker system resources to fix disk space problems?"]',
#  '33e775eb': '["Why am I getting an error about failing to listen on :::8080 when running docker-compose up?",  \n"What does the error \'php_network_getaddresses: getaddrinfo failed: Address family for hostname not supported\' mean?",  \n"How can I fix the issue where Adminer fails to start due to a network address error?",  \n"Where should I add the command to resolve the 8080 listening error in the docker-compose file?",  \n"What is the correct command to specify in the yml file to make Adminer run properly on port 8080?"]',
#  '19a3d34a': '[\n    "Is there a built-in way to generate Evidently-style charts directly in Grafana without additional plugins?",\n    "How can I export Evidently report data to use in external visualization tools like Grafana?",\n    "What specific Grafana panel types would be needed to recreate Evidently dashboards?",\n    "Why might it be more practical to use Evidently directly for debugging rather than recreating its visualizations in Grafana?",\n    "What additional parameters do I need to include when exporting Evidently JSON to preserve raw data for visualizations?"\n]',
#  '55c68f23': '[\n    "Why am I getting the error \'Unable to locate credentials\' when running localstack with kinesis?",\n    "How can I resolve the \'Unable to locate credentials\' error in my localstack setup?",\n    "What environment variables do I need to add to docker-compose.yaml to fix credential issues with localstack?",\n    "Is there a quick way to configure AWS credentials for localstack without modifying docker-compose.yaml?",\n    "What values should I use for AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY when setting up localstack?"\n]',
#  '54020f0a': '[\n    "Why am I getting an \'unspecified location constraint is incompatible\' error when creating an S3 bucket with localstack and boto3?",\n    "How can I resolve the \'IllegalLocationConstraintException\' error during S3 bucket creation in a specific region?",\n    "What is the correct way to create an S3 bucket in localstack to avoid location constraint errors?",\n    "Why does the boto3 client throw an error when I try to create a bucket without specifying a location constraint?",\n    "What should I include in the \'CreateBucketConfiguration\' parameter to fix the \'unspecified location constraint\' error?"\n]',
#  'b6249d2c': '```json\n[\n  "Why am I seeing the error \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\' when running AWS CLI commands?",\n  "How can I resolve the AWS CLI error involving \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\'?",\n  "What environment variables do I need to set to fix the AWS CLI error with \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\'?",\n  "Do the values of AWS environment variables matter when fixing the \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\' error?",\n  "Is there a quick way to resolve the \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\' error in AWS CLI without complex configurations?"\n]\n```',
#  '31543d95': '["Why does pre-commit show a \'mapping values are not allowed in this context\' error during every commit?",  \n"How can I fix the issue where pre-commit hooks fail to run with a YAML-related error?",  \n"What should I check in my .pre-commit-config.yaml file to resolve indentation problems?",  \n"Are there specific formatting rules for the .pre-commit-config.yaml file to avoid errors?",  \n"Which part of the .pre-commit-config.yaml file commonly causes the \'mapping values\' error?"]',
#  'e147bbb6': '[\n    "How do I completely reset pytest configuration after switching from a previous testing folder?",\n    "What steps should I take if pytest settings from an old folder are interfering with my current setup?",\n    "Where exactly do I need to delete the .vscode folder to fix pytest reconfiguration issues?",\n    "Why can\'t I remove pytest tests directly and what\'s the alternative solution?",\n    "Is there a specific location I should clean up to ensure pytest works properly in a new folder?"\n]',
#  'dc55657f': '```json\n[\n    "Why does the get-records command return empty Records when following Module 6\'s video at 11:23?",\n    "What modification is needed for the Kinesis get-records call to resolve empty Records in LocalStack?",\n    "How can I fix the issue of empty Records when using Kinesis with LocalStack?",\n    "Is there a specific flag required for get-records to work correctly in LocalStack?",\n    "What is the solution for empty Records in Kinesis when following the steps in Module 6?"\n]\n```',
#  'f6979915': '```json\n{\n  "questions": [\n    "Why am I getting a UTF-8 encoding error when trying to commit in Git after creating a pre-commit YAML file?",\n    "How can I resolve the \'utf-8 codec can\'t decode byte 0xff\' error during a Git commit in PowerShell?",\n    "What steps should I take to set UTF-8 encoding for the pre-commit YAML file to avoid commit errors?",\n    "After creating a pre-commit-config.yaml file, Git commit fails with an encoding error—how do I fix this?",\n    "What is the correct way to create a pre-commit YAML file in PowerShell to prevent UTF-8 encoding issues?"\n  ]\n}\n```',
#  '1076a121': '[\n    "Why does my Git commit fail with the error \'PythonInfo\' object has no attribute \'version_nodot\' when using a pre-commit hook?",\n    "How can I resolve the \'version_nodot\' attribute error that occurs during a Git commit with pre-commit hooks?",\n    "What steps should I take if my pre-commit hook raises an unexpected \'PythonInfo\' object error?",\n    "Is there a way to fix the \'CalledProcessError\' and \'AttributeError\' during Git commits with pre-commit hooks?",\n    "Can clearing the virtualenv app-data help resolve pre-commit hook errors like \'version_nodot\' missing?"\n]',
#  'aa203ca7': '[\n    "Why do I get a \'module not found\' error when running pytest on my custom packages, but it works when running the test file directly?",\n    "How can I fix the \'No module named production\' error when using pytest with my project structure?",\n    "What is the difference between running pytest directly and using python -m pytest for my tests?",\n    "Why does pytest not recognize my custom modules even though the test file runs fine when executed directly?",\n    "Are there alternative solutions besides using python -m pytest to resolve module import issues in pytest?"\n]',
#  '8b04605d': '[\n    "Why am I getting a \'module not found\' error when running pytest with pre-commit hooks for custom packages?",\n    "How can I fix the \'No module named production\' error during git commit when using pytest?",\n    "What changes should I make to my pre-commit hook configuration to resolve pytest import issues?",\n    "Can you explain the solution for pytest not finding custom modules in a pre-commit hook setup?",\n    "What is the correct way to configure a pre-commit hook to run pytest with custom package imports?"\n]',
#  'a3b9af04': '["Why am I getting a Permission denied error when running a script in GitHub Actions?",  \n"How can I resolve the error code 126 in my GitHub Actions workflow?",  \n"What steps should I take to fix execution permission issues for a script in GitHub Actions?",  \n"How do I grant execute permissions to a script file before running it in a GitHub Actions workflow?",  \n"What is the correct command to add execute permissions to a script in a GitHub repository?"]',
#  'b16aae74': '["How can I efficiently manage and run only specific containers from a large docker-compose file without overloading my system?", "What is the purpose of using profiles in a docker-compose file when dealing with multiple containers?", "How do I define and assign a profile to a service in my docker-compose configuration?", "What command should I use to start only the containers associated with a specific profile in docker-compose?", "Can you explain how profiles in docker-compose help streamline the testing process by isolating relevant containers?"]',
#  '66326a87': '```json\n[\n    "Why are my integration tests failing when using Kinesis in Module 6?",\n    "How do I ensure my AWS region settings are consistent across docker-compose and local config?",\n    "What could be causing my Kinesis stream to be created in the wrong region?",\n    "Can you provide an example of matching AWS region settings between docker-compose and local config?",\n    "What steps should I take to troubleshoot region mismatch issues in Module 6?"\n]\n```',
#  'fb3c4150': '[\n    "Why is the pre-commit command failing when using isort in my repository?",\n    "What specific version of isort should I use to resolve the pre-commit issue?",\n    "How can I fix the isort pre-commit failure in Module 6?",\n    "Who provided the solution for the isort pre-commit problem?",\n    "What was the exact solution to the isort pre-commit error mentioned in the FAQ?"\n]',
#  '886d1617': '[\n    "What steps should I follow to tear down AWS infrastructure that was deployed using GitHub Actions?",\n    "Can you explain how to properly destroy resources created by the CD-Deploy Action in AWS?",\n    "Is there a specific command sequence required to remove infrastructure managed by Terraform in this module?",\n    "How do I ensure the correct state file is used when destroying the infrastructure locally?",\n    "Are there any additional variables or configurations needed when running the destroy command for this setup?"\n]'}

# %%
with open('results.bin', 'wb') as archivo:
        pickle.dump(results, archivo)

# %%
with open('results.bin', 'rb') as f_in:
    results = pickle.load(f_in)

# %%
results['1f6520ca']
# Out:
# '[\n    "What background knowledge or skills do I need before enrolling in this course?",\n    "Are there any specific technical requirements I should meet to take this course?",\n    "Do I need prior experience with data engineering tools to join this course?",\n    "What are the recommended prerequisites to ensure I can follow the course material effectively?",\n    "Is there a list of required skills or tools I should be familiar with before starting the course?"\n]'

# %%
for doc_id, json_questions in results.items():
    print(f'questions: {json_questions}')
# Out:
# questions: [
#     "What is the exact start date and time for the course?",
#     "How can I stay updated with the course schedule and important announcements?",
#     "Where do I need to register before the course begins?",
#     "Is there a specific platform or channel for course-related communication?",
#     "What should I do to ensure I don't miss the beginning of the course?"
# ]
# questions: [
#     "What background knowledge or skills do I need before enrolling in this course?",
#     "Are there any specific technical requirements I should meet to take this course?",
#     "Do I need prior experience with data engineering tools to join this course?",
#     "What are the recommended prerequisites to ensure I can follow the course material effectively?",
#     "Is there a list of required skills or tools I should be familiar with before starting the course?"
# ]
# questions: ```json
# [
#   "Is it possible to enroll in the course after it has already begun?",
#   "What happens if I don't formally register but still want to participate?",
#   "Are there any deadlines I should be aware of if I join late?",
#   "Can I submit assignments if I join the course after the start date?",
#   "Will there be penalties for submitting the final project close to the deadline?"
# ]
# ```
# questions: [
#     "If I haven't received a confirmation email after registering for the Data Engineering Bootcamp, does that mean I'm not accepted?",
#     "Can I begin working on the course material and submitting assignments before receiving any confirmation?",
#     "Is registration mandatory to participate in the Data Engineering Bootcamp, or can I join without it?",
#     "How does the registration process for the Data Engineering Bootcamp work if it doesn't affect participation?",
#     "Will my homework submissions be checked if I haven't officially registered for the course?"
# ]
# questions: [
#     "What are the recommended preparations I should complete before the course begins?",
#     "Which software tools and accounts do I need to set up prior to the course start date?",
#     "How can I ensure I meet the prerequisites for this course?",
#     "Is there a list of dependencies I should install before the course starts?",
#     "Where can I find the syllabus to review the topics covered in the course?"
# ]
# questions: [
#     "How many Zoomcamp sessions are offered each year for the Data-Engineering course?",
#     "Can I enroll in the MLOps Zoomcamp outside of the May-August timeframe if I don't need certification?",
#     "Is the Machine Learning Zoomcamp the only one that runs into the next calendar year?",
#     "If I miss the live Data-Engineering cohort, can I still complete the course for certification later?",
#     "Are the schedules for each Zoomcamp cohort consistent from year to year?"
# ]
# questions: [
#     "How does the current cohort differ from the previous one in terms of tools and content?",
#     "What changes have been made to the course materials for the 2024 edition?",
#     "Why was Mage AI chosen over Prefect for the current cohort?",
#     "Were there any updates to the Terraform section compared to last year?",
#     "Can you explain the shift from Airflow to Prefect in the 2023 cohort?"
# ]
# questions: [
#     "Will the course materials remain accessible once the course has ended?",
#     "Is it possible to complete assignments after the official course completion date?",
#     "Can I still work on the capstone project if I join after the course finishes?",
#     "Are there any limitations to accessing the content post-course?",
#     "How can I prepare for future cohorts using the current course materials?"
# ]
# questions: [
#     "Is there any support available for students taking the self-paced version of the course?",
#     "How can I get help if I'm stuck while studying at my own pace?",
#     "Are there any resources I should check before asking for assistance in the Slack channel?",
#     "Can I use the ZoomcampQABot to find answers to my questions in the Slack channel?",
#     "How reliable are the answers provided by the ZoomcampQABot when searching for solutions?"
# ]
# questions: [
#     "What is the main YouTube playlist I should follow for the course videos?",
#     "Are there any additional playlists for specific years or office hours videos?",
#     "Where can I find the link to the main DATA ENGINEERING playlist?",
#     "Is the GitHub repository updated with direct links to the YouTube videos?",
#     "Where in the Slack channel can I find the pinned playlist for easy access?"
# ]
# questions: [
#   "How much weekly time commitment should I anticipate for this course based on my prior knowledge?",
#   "Can you provide guidance on estimating the weekly study hours needed for this course?",
#   "What factors influence the amount of time I'll need to dedicate to this course each week?",
#   "Is there a way to calculate the expected weekly workload for this course myself?",
#   "Where can I find resources to help me determine my personal time investment for this course?"
# ]
# questions: [
#     "Is it possible to receive a course certificate if I complete the material at my own pace?",
#     "Why are certificates only awarded for the live cohort and not the self-paced version?",
#     "What is the reason behind requiring peer reviews for capstone projects to earn a certificate?",
#     "Can I still access the course content if I choose the self-paced mode without aiming for a certificate?",
#     "Are there any exceptions where a certificate might be granted for self-paced completion?"
# ]
# questions: [
#   "How can I access the live stream for Office Hour or workshop sessions?",
#   "Where is the YouTube Live link shared before the Office Hour starts?",
#   "Why shouldn't I post questions in the YouTube chat during Office Hours?",
#   "How do I submit questions during the Office Hour sessions?",
#   "Can I participate in Office Hours via Zoom, or is it only through YouTube Live?"
# ]
# questions: ```json
# [
#     "Will the Office Hours sessions be available for viewing after the live session ends?",
#     "If I miss the live Office Hours, can I still access the recording later?",
#     "Are the Office Hours recordings posted immediately after the session concludes?",
#     "Is there a delay between the end of the live Office Hours and when the recording is available?",
#     "Can I rewatch the Office Hours sessions multiple times if needed?"
# ]
# ```
# questions: ```json
# [
#     "Where can I find the current deadlines for homework and projects in this course?",
#     "How will I be notified if there are any changes to the homework or project deadlines?",
#     "Is there a specific platform or link where all assignment deadlines are listed?",
#     "Who should I follow for updates regarding deadline extensions or other course announcements?",
#     "What should I do if the deadline shown in the course materials differs from the one announced by the instructor?"
# ]
# ```
# questions: [
#     "Is it possible to submit homework after the deadline if the submission form is still open?",
#     "What happens if I try to submit my homework late?",
#     "How can I verify that my homework submission was on time?",
#     "Are there any exceptions to the late submission policy for homework?",
#     "Where can I check the exact deadline for homework submissions?"
# ]
# questions: [
#     "Where can I find the homework assignments for this course?",
#     "Is there a specific platform we should use to submit our homework?",
#     "Can I use any version control system for my homework submissions?",
#     "What should be included in my homework submission to meet the requirements?",
#     "How do I ensure my homework is accessible and correctly submitted for grading?"
# ]
# questions: [
#     "How are homework assignments graded in the course management platform?",
#     "Where can I see the total points I've earned for all my submissions?",
#     "What types of activities contribute to the points displayed on the leaderboard?",
#     "How many points do I receive for submitting a question to the FAQ section?",
#     "Is there a difference in points awarded for homework, FAQ submissions, and Learning in Public posts?"
# ]
# questions: [
#     "How can I find out what my display name is on the leaderboard?",
#     "Why don't I see my name on the leaderboard after setting up my account?",
#     "Where do I go to change my display name for the course?",
#     "Is it possible to customize my display name on the leaderboard?",
#     "What steps do I need to follow to view or update my profile in the course?"
# ]
# questions: ```json
# ["Is Python 3.9 still the best version to use for this course in 2024, or should I upgrade to a newer version?", "Will using Python 3.10 or 3.11 cause any issues with the course materials?", "Why does the course recommend sticking with Python 3.9 instead of the latest version?", "Are there any specific advantages to using Python 3.9 over newer versions for this course?", "If I encounter problems with a newer Python version, will troubleshooting support be provided?"]
# ```
# questions: ["What are the pros and cons of setting up the environment on my local machine versus using a virtual machine?", "Can I switch between using my local machine and GitHub Codespaces during the course, or do I need to stick to one option?", "Are there any specific challenges Windows users might face when setting up the environment locally?", "Is there a recommended approach for students who want to work across multiple devices, like home and office computers?", "Do I need prior experience with Docker to set up the environment locally, or will the course guide me through it?"]
# questions: [
#     "Can I use GitHub Codespaces instead of CLI tools like git bash for data ingestion and Docker file creation?",
#     "What are the advantages of using GitHub Codespaces over local CLI tools for this course?",
#     "Does GitHub Codespaces come with Docker and other necessary tools pre-installed?",
#     "Is it possible to directly open a GitHub repository in GitHub Codespaces for this course?",
#     "Are the computing resources provided by GitHub Codespaces sufficient for the course's Docker and data tasks?"
# ]
# questions: ["Is it mandatory to use GitHub Codespaces for the course, or can I use my local setup with PostgreSQL and Docker?", "Can I complete the course using my own laptop instead of GitHub Codespaces or GCP VM?", "Are there any advantages to using GitHub Codespaces over my existing local environment with Docker and PostgreSQL?", "What are the recommended environment options for the course if I don’t want to use GitHub Codespaces?", "If I already have Docker and PostgreSQL installed, do I still need to set up GitHub Codespaces for the coursework?"]
# questions: [
#   "Is it necessary to use both GitHub Codespaces and GCP for the course, or can I choose one?",
#   "Will BigQuery be required for the course, and if so, should I prioritize learning GCP?",
#   "Can I complete the course using only a local environment instead of cloud services?",
#   "What are the advantages of using GCP over GitHub Codespaces for this course?",
#   "If I prefer GitHub Codespaces, will I miss out on any critical course content?"
# ]
# questions: ```json
# ["How can I open the Run command window on a Windows machine to access the registry editor?", "Where exactly in the Registry Editor do I need to modify the 'Autorun' value for GCP VM connection issues?", "What specific change should I make to the 'Autorun' registry value to resolve the VSCode-GCP VM connection problem?", "Is there an alternative solution to modifying the registry, such as dealing with the known_hosts file?", "Where is the known_hosts file located on a Windows system if I want to delete the fingerprint manually?"]
# ```
# questions: [
#     "Why is GCP the recommended cloud platform for this course instead of alternatives like AWS or Azure?",
#     "Am I allowed to use a different cloud provider like AWS if I'm more familiar with it?",
#     "What are the benefits of using GCP for this course, especially for students?",
#     "Do I need a credit card to sign up for the GCP free trial mentioned in the course?",
#     "Is BigQuery a mandatory tool for the course, and does it require a GCP account?"
# ]
# questions: ["Is there any cost associated with using cloud services for this course?", "Do I need to pay for Google Cloud Platform during the course?", "Are there any free options available for cloud services in this course?", "Will the course cover how to use GCP's free trial?", "Is financial assistance available for cloud service usage in this course?"]
# questions: ```json
# ["Is it possible to complete the course without using cloud providers like GCP?", "Are there local alternatives for all the tools used in the course?", "Will the course provide instructions for setting up a home lab environment?", "Can I run BigQuery locally or is there a substitute for it?", "What limitations should I expect if I choose to do the course entirely locally?"]
# ```
# questions: [
#     "Can I use AWS for all the course projects and assignments?",
#     "What are the potential challenges of using AWS instead of the recommended platform?",
#     "Will using AWS affect how my final capstone project is evaluated?",
#     "How can I get help if I encounter issues while using AWS for the course?",
#     "Are there any specific adjustments I need to make when using AWS instead of the default platform?"
# ]
# questions: ["Are there any additional live Zoom sessions scheduled apart from the Office Hours?", "Will there be any live calls during the Capstone project phase?", "How will we be informed about any extra live Zoom meetings?", "Can we expect any surprise live sessions, or will they all be announced beforehand?", "Is the Capstone period the only time when extra live calls might happen?"]
# questions: [
#     "Is the NYC Trip dataset for January 2021 still the one we're working with this year, or has it been updated to 2022?",
#     "Will there be any changes to the project requirements compared to last year's course?",
#     "Where can I access the dataset required for the project?",
#     "Are we expected to use the same methodology as last year's students for this project?",
#     "Is there any additional data we should incorporate beyond the provided NYC Trip dataset?"
# ]
# questions: [
#     "Is the repository for the 2022 course materials still available?",
#     "Where can I find the content from the 2022 version of the course?",
#     "Has the 2022 course material been removed or relocated?",
#     "Can I still access the previous year's (2022) course resources?",
#     "What happened to the 2022 course repository? Is it no longer accessible?"
# ]
# questions: ["Is it acceptable to utilize a different tool like Airflow for the final project submission?", "Are there any restrictions on the tools we can choose for our final project?", "Would using a tool other than the ones taught in the course be allowed for the project?", "Can students select their preferred software or platform for the final assignment?", "Is Airflow an approved tool for completing the course's final project requirements?"]
# questions: [
#     "Can I use a different data orchestration tool like Airflow or Prefect instead of Mage for the course projects?",
#     "Are we allowed to substitute AWS or Snowflake for the GCP products mentioned in the course materials?",
#     "If I prefer Tableau over Metabase or Google Data Studio, can I use it for visualization assignments?",
#     "What are the implications of choosing an alternative tool stack that differs from the ones covered in the course?",
#     "Will the instructors provide support if I decide to use a different set of tools than those recommended in the course?"
# ]
# questions: ["How can I help improve the course materials?", "What are the ways to support this course?", "Is there a way to suggest changes to the repository?", "Can I share this course with others if I find it helpful?", "What contributions are welcome for this course?"]
# questions: ["Is the course compatible with Windows, macOS, and Linux operating systems?", "Do I need a specific operating system to successfully complete the course?", "Are there any advantages to using Linux over other operating systems for this course?", "Have students previously used different operating systems without issues in this course?", "Will using a non-Linux OS put me at a disadvantage in the course?"]
# questions: ["What should Windows users do if they encounter issues with shell scripts in the course modules?", "Why is WSL recommended for Windows users in this course?", "Are there any known workarounds for Windows users who can't use WSL with shell scripts?", "Which specific modules in the course are problematic for Windows users without WSL?", "How have past cohorts handled the shell script challenges on Windows?"]
# questions: ["Are there any recommended books or materials to supplement the course content?",
# "Can you suggest additional resources to enhance my understanding of the course topics?",
# "Where can I find a list of recommended readings for this course?",
# "Do you have any external resources or books that align with the course curriculum?",
# "Is there a compilation of suggested materials to further explore data engineering concepts?"]
# questions: [
#     "What are the differences between Project Attempt #1 and Project Attempt #2?",
#     "Can I submit my project after the first deadline if I missed it?",
#     "If I fail the first project submission, do I get another opportunity to submit it?",
#     "How many chances do I have to complete the project successfully?",
#     "Is there a penalty for submitting the project during the second attempt?"
# ]
# questions: ```json
# [
#     "What should I do first when I encounter a technical issue in the course?",
#     "How can I effectively search for solutions to errors or problems I encounter?",
#     "What information should I include when asking for help in Slack or other forums?",
#     "Why is it discouraged to tag instructors directly when asking for help?",
#     "What should I do if none of the troubleshooting steps resolve my issue?"
# ]
# ```
# questions: ```json
# [
#     "What should I do if the troubleshooting guide doesn't resolve my issue?",
#     "What details should I include when asking for help with a coding problem?",
#     "Why is it important to mention what I've already tried when seeking assistance?",
#     "How can I ensure my question gets a helpful response from the course staff?",
#     "Where can I find guidance on how to properly ask questions in this course?"
# ]
# ```
# questions: [
#   "What steps should I follow to set up Git and GitHub for this course?",
#   "How can I clone the course repository to my local machine?",
#   "Are there any specific files or data types I should avoid including in my GitHub repositories?",
#   "Where can I find tutorials or resources for creating and managing my own repositories?",
#   "Is it safe to store sensitive information like passwords or keys in a private GitHub repository?"
# ]
# questions: [
#     "Why am I getting the 'missing separator' error in my Makefile and how can I fix it?",
#     "How do I change VS Code settings to use tabs instead of spaces for indentation?",
#     "What should I do when my Makefile fails with a separator error?",
#     "Can you explain why tabs are required in Makefiles and how to ensure they're used?",
#     "Where can I find guidance on converting spaces to tabs in VS Code for Makefile compatibility?"
# ]
# questions: ```json
# [
#     "How can I open an HTML file in a Windows browser when using Linux on WSL?",
#     "What command should I use to view an HTML file from WSL in my default Windows browser?",
#     "Is it possible to specify a different browser to open HTML files from WSL on Windows?",
#     "How do I set up WSL to open HTML files directly in a Windows browser?",
#     "Can I customize which browser opens HTML files from WSL, and if so, how?"
# ]
# ```
# questions: ```json
# [
#     "How can I set up Chrome Remote Desktop on a Debian Linux VM in Compute Engine?",
#     "What should I do if I encounter an ERROR 403 when downloading Yellow Taxi Trip Records from the TLC website?",
#     "Is there a backup source available for the 2021 Yellow Taxi Trip data if the original link fails?",
#     "How do I properly unzip the 'gz' file for the Yellow Taxi Trip data?",
#     "Can you explain the purpose of using Chrome Remote Desktop for accessing applications on a Linux VM?"
# ]
# ```
# questions: ["How should I name the taxi data file to ensure it stores correctly in the course exercise?",
# "What is the correct way to handle the file extension when working with the provided taxi data URL?",
# "Can I use the original .csv.gz file extension when reading the taxi data with pandas, or do I need to change it?",
# "How can I extract the file name from the taxi data URL to use it in my code?",
# "Why does the course recommend changing the file name from .csv.gz to .csv, and is it necessary for pandas?"]
# questions: ```json
# [
#     "Where can I find the data dictionary for the Yellow Taxi trip records in Module 1?",
#     "Is there a separate data dictionary available for the Green Taxi trips in the NY Taxi dataset?",
#     "What is the official source for the data dictionaries of the NY Taxi trip records?",
#     "Can you provide links to the documentation for the Yellow and Green Taxi data in Module 1?",
#     "Are the data dictionaries for the NY Taxi datasets provided in PDF format?"
# ]
# ```
# questions: [
#     "How can I unzip the downloaded parquet file for the taxi data using the command line?",
#     "What is the command to convert the gzipped parquet file into a CSV file?",
#     "How do I modify the ingest_data.py script to directly use parquet files instead of CSV?",
#     "What changes should I make in the main function to handle parquet file downloads and conversions?",
#     "Can you explain how to convert a parquet file to a CSV file within a Python script using pandas?"
# ]
# questions: ```json
# [
#   "How do I fix the 'wget is not recognized as an internal or external command' error on Ubuntu?",
#   "What is the easiest way to install wget on a MacOS system?",
#   "Can you guide me through installing wget on Windows using Chocolatey?",
#   "Is there an alternative method to install wget on Windows without using Chocolatey?",
#   "Are there Python-based alternatives to using the wget command for downloading files?"
# ]
# ```
# questions: ```json
# [
#     "How can I resolve the 'cannot verify website certificate' error when using wget on MacOS?",
#     "What should I do if wget fails to verify a certificate in a Jupyter Notebook?",
#     "Are there alternative methods to download files using wget if certificate verification fails?",
#     "Can I bypass certificate checks when running wget from the command line?",
#     "What is the correct syntax for using wget with the --no-check-certificate flag?"
# ]
# ```
# questions: ```json
# [
#     "How can I configure Git Bash on Windows to treat backslash as an escape character?",
#     "What command should I use in Git Bash for Windows to enable backslash escaping?",
#     "Is it necessary to modify the .bashrc file to use backslash as an escape character in Git Bash?",
#     "Can you explain the correct syntax for setting the escape character in Git Bash for Windows?",
#     "Why might someone prefer using backslash as an escape character in Git Bash, and how can they enable it?"
# ]
# ```
# questions: [
#     "How can I securely store and access secrets within GitHub Codespaces for my projects?",
#     "What is the recommended method to manage account-specific secrets in GitHub Codespaces?",
#     "Where can I find detailed instructions for handling secrets in GitHub Codespaces?",
#     "Is there a specific documentation resource for managing secrets in GitHub Codespaces?",
#     "Can you explain the process of making secrets available in GitHub Codespaces?"
# ]
# questions: ["What should I do if I encounter an error saying Docker daemon is not running when trying to connect to unix:///var/run/docker.sock?", "How can I ensure the Docker daemon is properly started before attempting to connect?", "What steps should I take if I receive a connection error to the Docker daemon on my system?", "Is there a specific command I need to run to update WSL before resolving Docker daemon issues?", "Why am I unable to connect to the Docker daemon, and what troubleshooting steps should I follow?"]
# questions: ```json
# [
#     "Why do I get an error saying the Docker client must be run with elevated privileges on Windows?",
#     "How can I enable Hyper-V for Docker on Windows 10 Pro or 11 Pro?",
#     "What should I do if I'm using Windows Home edition and can't use Hyper-V for Docker?",
#     "Where can I find detailed instructions to set up WSL2 for Docker on Windows?",
#     "What steps should I take if I encounter the 'WslRegisterDistribution failed with error: 0x800701bc' issue?"
# ]
# ```
# questions: ```json
# [
#     "Why do I get a 'repository does not exist' error when pulling a Docker image, and how can I fix it?",
#     "Do I need to log in to Docker Hub to pull the images used in the Data Engineering Zoomcamp?",
#     "What should I do if I encounter a 'permission denied' error while mounting a volume in a PostgreSQL Docker container on macOS M1?",
#     "Is it necessary to use Docker Desktop instead of Rancher Desktop for the course exercises?",
#     "How can I verify if a Docker image name is correct before pulling it to avoid errors?"
# ]
# ```
# questions: ["Why can't I delete a local folder that was mounted as a Docker volume?",
# "How do I remove a Docker-created folder that has restricted permissions?",
# "What command should I use to force-delete a protected folder created by Docker?",
# "Why does Obsidian fail to start due to a folder access error related to Docker?",
# "How can I change the ownership or permissions of a folder created by a Docker container?"]
# questions: ["What should I do if Docker is stuck on the starting screen in Windows 10 or 11?",
# "How can I switch between container types if Docker is not starting properly?",
# "Where can I download the latest version of Docker for Windows if the in-app upgrade fails?",
# "Do I need to enable Hyper-V to run Docker on Windows 10/11 Pro, and how do I do it?",
# "What are the steps to configure WSL2 as the backend for Docker on Windows?"]
# questions: [
#     "What is the recommended file system for running Docker commands on Windows with WSL?",
#     "Can I use Docker with Windows 10/11 Home Edition, and if so, how?",
#     "What should I do if Docker gets stuck even after setting up WSL2 or Hyper-V correctly?",
#     "Is it better to run Docker commands from the Windows file system or the WSL Linux file system?",
#     "Are there any troubleshooting steps if Docker doesn't work properly after WSL2 setup?"
# ]
# questions: ```json
# [
#     "What is the recommended way to store code for optimal file system performance when using Docker on Windows 10/11 Home?",
#     "Does Docker on WSL2 backend have specific requirements for code storage to ensure performance?",
#     "Where can I find detailed guidelines on best practices for Docker file system performance?",
#     "Is there a preferred location to store code when running Docker with WSL2 on Windows Home editions?",
#     "How does the default Linux distro in Docker impact file system performance for Windows users?"
# ]
# ```
# questions: ```json
# [
#   "Why do I get the error 'the input device is not a TTY' when running Docker on Windows?",
#   "How can I fix the 'input device is not a TTY' issue in Docker for Windows?",
#   "What is the solution for the TTY error when using Docker with mintty on Windows?",
#   "Can I create an alias to avoid typing 'winpty' before every Docker command?",
#   "Where should I add the alias to make 'winpty docker' the default on Windows?"
# ]
# ```
# questions: ```json
# [
#     "Why am I getting a 'Temporary failure in name resolution' error when trying to pip install inside a Docker container on Windows?",
#     "How can I resolve the pip installation failure due to DNS issues in a Docker container?",
#     "What is the correct Docker run command to fix pip install errors related to name resolution?",
#     "Why does my Docker container fail to connect to the internet when running pip install on Windows?",
#     "What DNS settings should I use in Docker to avoid pip install connection problems on Windows?"
# ]
# ```
# questions: [
#     "Why is the ny_taxi_postgres_data folder empty in VS Code after running the Docker script?",
#     "What specific command should I use to resolve the empty folder issue in Docker for Windows?",
#     "How do I properly set the volume path in Docker to ensure data appears in ny_taxi_postgres_data?",
#     "Are there any environment variables I need to configure to fix the empty folder problem in Docker?",
#     "What could be causing the data not to appear in the ny_taxi_postgres_data folder despite running the script correctly?"
# ]
# questions: [
#   "What is the recommended method for setting up Docker on a Mac?",
#   "Is the traditional method of installing Docker on macOS still reliable?",
#   "Where can I find the most up-to-date Docker installation for Mac?",
#   "Why might the older Docker setup method for Mac not work properly?",
#   "Has Docker's licensing change affected the installation process on macOS?"
# ]
# questions: [
#     "When running a PostgreSQL container, I get an error saying 'could not change permissions of directory \"/var/lib/postgresql/data\": Operation not permitted'. How can I resolve this?",
#     "What is the correct way to map a local volume to the PostgreSQL data directory in Docker to avoid permission issues?",
#     "How do I create and use a Docker volume for PostgreSQL data instead of a local directory to prevent permission errors?",
#     "After running the Docker command for PostgreSQL, how can I verify that the volume was created successfully?",
#     "I encountered another error stating 'directory \"/var/lib/postgresql/data\" exists but is not empty'. What should I do in this case?"
# ]
# questions: ["Why am I getting an 'invalid reference format' error when trying to mount Docker volumes on Windows?",
# "What are some alternative ways to format the volume mapping command to avoid issues on Windows?",
# "How can I fix the problem where Docker creates an incorrect folder name when mounting volumes?",
# "Are there any specific syntax changes needed for Mac users when mounting volumes in Docker?",
# "What should I do if none of the suggested volume mapping options work on my system?"]
# questions: ```json
# [
#     "How can I resolve the 'invalid mode' error when mounting a volume in Docker on Windows?",
#     "What should I do if Docker gives an error about the mounting path being invalid?",
#     "Why does Docker complain about the mode when I try to mount a volume in Windows?",
#     "What is the correct way to specify a volume mount path in Docker for Windows to avoid errors?",
#     "Can you explain how to fix the mounting path issue in Docker when using Git Bash on Windows?"
# ]
# ```
# questions: [
#     "Why am I getting the error 'Error response from daemon: error while creating buildmount source path' when running my Docker container a second time?",
#     "How can I resolve the issue where Docker fails to mount a volume on subsequent runs of the same container?",
#     "What changes should I make to my Docker command to avoid the 'file exists' error when re-running a container with a mounted volume?",
#     "Is it necessary to mount the volume every time I run the same Docker container, or can I skip it after the first run?",
#     "What is the correct way to run a PostgreSQL container in Docker after the initial setup to avoid mounting conflicts?"
# ]
# questions: ["Why am I getting a 'can\\'t stat' error when trying to build my Docker image for the taxi ingest project?",
# "How can I resolve permission issues when Docker can\\'t access a directory during the build process?",
# "What files are strictly necessary to include when running the 'docker build' command for this project?",
# "Are there different solutions for fixing directory permission issues on Ubuntu versus Windows for Docker builds?",
# "Where can I find a more detailed explanation for troubleshooting Docker build context errors?"]
# questions: ```json
# ["Why do I get 'ERRO[0000] error waiting for container: context canceled' when using Docker?", "How can I check if Docker was installed via snap?", "What should I do if 'snap status docker' returns an unknown command error?", "Why does Docker fail to bind to port 0.0.0.0:5432?", "What is the recommended way to install Docker to avoid these issues?"]
# ```
# questions: ```json
# [
#     "Why am I getting a 'can’t stat' error when trying to build a Docker image in PopOS Linux?",
#     "What could be causing the Docker build context to fail with a permissions issue in my project folder?",
#     "How do I resolve the 'can’t stat' error related to folder permissions in Docker on PopOS?",
#     "Why does my host folder appear empty in Docker even though it contains files?",
#     "What command should I use to grant Docker the necessary permissions to access a folder in PopOS?"
# ]
# ```
# questions: ["Why do I get a permission denied error when trying to rebuild my Docker container on Ubuntu?",
# "How can I resolve the 'failed to solve with frontend dockerfile.v0' error in Docker?",
# "What does the error 'error from sender: open ny_taxi_postgres_data: permission denied' mean in Docker?",
# "Which permission settings should I use for the ny_taxi_postgres_data folder to fix Docker build issues?",
# "Is it safe to use chmod 777 for the ny_taxi_postgres_data folder when facing Docker permission problems?"]
# questions: ```json
# [
#     "How can I find out the name of a Docker network in Module 1?",
#     "What command should I use to list all Docker networks in this module?",
#     "Where can I locate the Docker network name as mentioned in Module 1?",
#     "Is there a specific Docker command to retrieve network names in Module 1?",
#     "How do I check the available Docker networks for the exercises in Module 1?"
# ]
# ```
# questions: ```json
# [
#     "What should I do when Docker shows an error that the container name 'pg-database' is already in use?",
#     "How can I resolve the conflict when Docker says a container name is already taken by another container?",
#     "Why does Docker give a 'Conflict' error when trying to reuse a container name, and how do I fix it?",
#     "What steps should I follow to remove or rename a Docker container that's causing a naming conflict?",
#     "Can I restart a Docker container without removing it if the name is already in use, and how?"
# ]
# ```
# questions: ["What does the error 'could not translate host name \"pgdatabase\" to address' mean when using docker-compose?",
# "How can I resolve the host name translation error in Docker when running an ingestion script?",
# "Which network should I use in the ingestion script if the default 'pg-network' isn't working?",
# "Why does the database host name change when running 'docker-compose up -d', and how do I find the correct one?",
# "What adjustments are needed in the ingestion script if the Docker network or database name differs from the default?"]
# questions: ```json
# [
#     "What should I do if I can't install Docker on a MacOS or Windows 11 VM running on Linux due to nested virtualization issues?",
#     "Are there specific commands I need to run before starting my VM to resolve Docker installation problems on a Linux-hosted VM?",
#     "How do I enable nested virtualization for Docker installation on an Intel CPU-based system?",
#     "What steps are required to configure nested virtualization for Docker on an AMD CPU when using a Linux-hosted VM?",
#     "Why does Docker fail to install on my MacOS/Windows 11 VM running on Linux, and how can I fix it?"
# ]
# ```
# questions: ```json
# [
#     "How can I manage Docker containers and images directly from VS Code?",
#     "What is the process for connecting VS Code to Docker running on WSL2?",
#     "Which extension should I install in VS Code to work with Docker?",
#     "What command should I use to stop a running Docker container?",
#     "Can VS Code interact with Docker Compose projects, and if so, how?"
# ]
# ```
# questions: ```json
# [
#     "Why does my PostgreSQL container show a message about the database directory containing a database but the system is shut down?",
#     "What does it mean when the server terminates abnormally while processing a request in a PostgreSQL container?",
#     "How can I resolve the issue where my Dockerized PostgreSQL container is not accepting any connections?",
#     "What should I do if I encounter the error 'connection failed: server closed the connection unexpectedly' in my PostgreSQL container?",
#     "Why do I need to delete the mapped data directory and restart the container when my PostgreSQL database fails to start?"
# ]
# ```
# questions: ["Why can't I install Docker on my Ubuntu system using the standard package manager?", "What alternative method can I use to install Docker if the traditional approach fails on Ubuntu?", "Is there a specific command I should run to install Docker via snap on Ubuntu?", "Are there certain Ubuntu versions where Docker installation through apt doesn't work?", "How do I resolve Docker installation issues on Ubuntu when the conventional method isn't available?"]
# questions: [
#     "Why am I getting a 'could not change permissions' error when mounting a directory in Docker-Compose for Postgres?",
#     "How do I properly configure a named volume in Docker-Compose to avoid mounting issues?",
#     "What steps should I take if Docker-Compose creates a new volume instead of using the existing one?",
#     "How can I check the mount location of a Docker volume to troubleshoot permission errors?",
#     "What is the correct way to rename or adjust Docker volumes to resolve mounting conflicts in Docker-Compose?"
# ]
# questions: ```json
# [
#     "Why am I getting the error 'Couldn’t translate host name to address' when using Docker-Compose?",
#     "How do I start the PostgreSQL database and pgAdmin containers in detached mode?",
#     "What command should I use to check if my containers are running after starting them?",
#     "How can I view the logs for a specific container to troubleshoot issues?",
#     "What should I do if the PostgreSQL container is not listed when I run 'docker ps'?"
# ]
# ```
# questions: ```json
# [
#     "Why does my Docker-Compose setup lose database data after running `docker-compose up`?",
#     "How can I resolve the 'could not translate host name pg-database' error in my Ingestion script?",
#     "What should I do if Docker-Compose creates an unexpected default network?",
#     "Where can I find the network name that Docker-Compose generates for my containers?",
#     "Are there alternative tools like pgcli that I can use if issues persist with database connections?"
# ]
# ```
# questions: ["Why am I getting an error that the hostname does not resolve when using Docker-Compose?",
# "What steps should I take if Docker-Compose cannot find the network for my containers?",
# "How can I fix the issue where my localhost server cannot connect to the PostgreSQL database due to hostname resolution?",
# "What naming conventions should I follow for hostnames in Docker-Compose to avoid resolution errors?",
# "How do I properly configure networks in docker-compose.yml to ensure containers can communicate with each other?"]
# questions: ```json
# ["How can I persist PGAdmin data when using Docker-Compose on GCP?", "Why isn't my specified volume path working for PGAdmin in Docker-Compose?", "What is the alternative to using a local path for PGAdmin volumes in Docker-Compose?", "How do I configure Docker Volumes to ensure PGAdmin data persistence on GCP?", "Can you explain the correct way to set up volumes for PGAdmin in a Docker-Compose file?"]
# ```
# questions: [
#     "Why does Docker Engine keep crashing and showing 'failed to fetch extensions' errors repeatedly?",
#     "What should I do if restarting Docker doesn't resolve the continuous crashing issue?",
#     "How can I fix the persistent 'failed to fetch extensions' pop-up errors in Docker?",
#     "Is updating Docker to the latest version a solution for the crashing and extension errors?",
#     "If updating Docker doesn't work, what is the final step to resolve the crashing and extension fetch issues?"
# ]
# questions: ```json
# [
#     "How can I persist pgAdmin configuration settings like server names in Docker-Compose?",
#     "What is the correct way to mount a volume for pgAdmin session data in a Docker-Compose file?",
#     "Why do I need to adjust permissions for the 'pgAdmin_data' folder before running docker-compose up?",
#     "Which environment variables are required for pgAdmin in Docker-Compose to set up default credentials?",
#     "What are the UID and GID of the user running the pgAdmin container, and why are they important for volume permissions?"
# ]
# ```
# questions: [
#     "How can I resolve the 'permission denied' error when trying to connect to Docker's socket in Docker-Compose?",
#     "What steps should I follow to ensure my user has the correct permissions to run Docker commands without sudo?",
#     "Why does pgAdmin forget my database connection settings every time I restart the containers, and how can I fix this?",
#     "What changes do I need to make in my docker-compose.yaml file to persist pgAdmin's connection settings?",
#     "Where can I find detailed instructions for setting up Docker to avoid permission issues and maintain pgAdmin state?"
# ]
# questions: ["Why is docker-compose not working even after updating my .bashrc file?", "How can I fix the issue where docker-compose command is not recognized after installation?", "What should I do if the downloaded docker-compose file has a different name than expected?", "Why am I unable to use the docker-compose command despite following the installation steps?", "How do I rename the docker-compose file to make the command work properly?"]
# questions: ["What should I do if I encounter an error about credentials when running docker-compose up -d?",
# "How can I resolve the Docker-Compose credential error mentioned in Module 1?",
# "After running docker-compose up -d, I get an error related to credentials. What is the solution?",
# "Where can I find more information about fixing the Docker-Compose credential error?",
# "Which package do I need to install to fix the Docker-Compose credential issue?"]
# questions: [
#     "What should I do if I encounter errors with my docker-compose.yml file while setting up pgadmin?",
#     "How can I resolve issues related to data ingestion when using Docker-Compose with PostgreSQL?",
#     "What steps should I follow to ensure proper execution of the Docker-Compose setup for this module?",
#     "Why is it important to set low_memory=False when importing CSV files in this Docker setup?",
#     "How do I configure pgadmin to connect to the PostgreSQL database created by Docker-Compose?"
# ]
# questions: ["What should I do if I encounter an error stating 'docker-credential-desktop' executable file not found when running 'docker compose up -d'?",
# "Where can I find the Docker config.json file to fix the credential store error?",
# "How do I modify the Docker configuration to resolve the 'executable file not found' issue?",
# "What is the difference between 'credsStore' and 'credStore' in Docker's config.json file?",
# "After fixing the config.json file, do I need to restart Docker or just re-run the command?"]
# questions: ```json
# [
#     "How do I determine the correct docker-compose binary to download for WSL?",
#     "What commands should I run to check my system before downloading docker-compose?",
#     "Where can I find the appropriate docker-compose binary for my WSL setup?",
#     "Is there a direct command to download and install docker-compose for WSL?",
#     "What do 'uname -s' and 'uname -m' outputs indicate when setting up docker-compose?"
# ]
# ```
# questions: ["Why am I getting an undefined volume error when running Docker-Compose in Windows/WSL?",
# "How can I fix the 'invalid compose project' error related to the pgdatabase service in my docker-compose.yaml?",
# "What changes do I need to make in my docker-compose file to resolve the undefined volume issue?",
# "Where exactly should I place the volumes section in my docker-compose.yaml to avoid errors?",
# "Can you explain why my Docker-Compose setup fails with a volume-related error even though I followed the video instructions?"]
# questions: ["Why do I encounter a directory permissions error when using Docker with WSL?",
# "How can I resolve permission conflicts between WSL and Windows in Docker?",
# "What is the recommended way to handle persistent data storage in Docker to avoid permission issues?",
# "Is the 'user' field necessary in docker-compose.yaml when using Docker volumes?",
# "Can you explain the difference between using Docker volumes and local file system storage for PostgreSQL in Docker?"]
# questions: ["What should I do if pgadmin is not working for querying in Postgres?", "Why does pgadmin fail to work easily on git bash or VM in Windows?", "What libraries are required for pgadmin to work, and what if the error persists?", "How can I use psql instead of pgadmin for querying in Postgres?", "What is the command to install psycopg2 for using psql?"]
# questions: ["Why am I getting an 'Insufficient system resources' error when using WSL?", "How can I resolve the 'Insufficient system resources' issue in WSL?", "What steps should I take to update Windows Terminal to fix WSL errors?", "Are there specific Windows updates needed to address WSL resource problems?", "After updating Windows Terminal and security updates, do I need to restart my system?"]
# questions: ["Why does my WSL integration with Ubuntu suddenly stop with exit code 1, and how can I fix it?",
# "What should I do if restarting Docker doesn't resolve the WSL integration issue?",
# "How can I fix DNS-related problems causing WSL to crash unexpectedly on Windows?",
# "Why am I seeing 'conda: command not found' in my terminal, and how do I resolve it?",
# "What does 'Database is uninitialized and superuser password is not specified' mean, and how do I address it?"]
# questions: ["Why am I getting a permissions error when trying to SSH into the GPC VM from WSL2?", "How can I resolve the 'Permissions too open' issue when using SSH in WSL2?", "What steps should I take if running 'ssh -i gpc' fails due to permission problems?", "Is there a way to fix SSH key permissions in WSL2 without using sudo?", "How do I properly set up the .ssh folder in WSL2 to avoid SSH key permission errors?"]
# questions: ["How can I resolve the 'Could not resolve host name' error in WSL2 when working with Docker and Terraform?",
# "What steps should I take if WSL2 is not referencing the correct .ssh/config path from Windows?",
# "Where should I create the .ssh/config file to fix host resolution issues in WSL2?",
# "What configuration is needed in the WSL2 .ssh/config file to connect to the GPC VM?",
# "How do I properly set up the IdentityFile path in WSL2 to avoid host resolution errors?"]
# questions: ["Why am I getting a connection refused error when trying to connect to PGCLI with the default settings?",
# "How do I properly connect to the ny_taxi database using PGCLI after encountering a connection error?",
# "What should I do if PGCLI fails to establish an SSL connection to the server?",
# "Can you provide the correct command to connect to the local PostgreSQL server on port 5432?",
# "Why does changing the connection method to a socket resolve the PGCLI connection issue?"]
# questions: ```json
# [
#     "When I run 'pgcli --help', I encounter an error. What could be the possible cause and how can I resolve it?",
#     "I'm getting an error with pgcli in Module 1. Is this related to Docker or Terraform, and how do I fix it?",
#     "Why does 'pgcli --help' not work as expected, and what steps should I take to troubleshoot this issue?",
#     "During Module 1, I faced an error with pgcli. Could this be due to incorrect installation, and how can I verify?",
#     "What should I do if 'pgcli --help' returns an error in the Docker and Terraform module?"
# ]
# ```
# ...
#     "Where can I find the correct URL format for the parquet files to avoid access issues?",
#     "Is there an updated data source URL I should use instead of the one causing the 403 error?"
# ]
# ```
# questions: ```json
# [
#     "Why am I encountering the error 'ModuleNotFoundError: No module named pipenv.patched.pip._vendor.urllib3.response' and how can I fix it?",
#     "What specific command should I run to resolve the issue with the missing 'urllib3.response' module in pipenv?",
#     "After reinstalling pipenv, I still see errors related to 'urllib3'—what additional steps should I take?",
#     "Can you explain why running 'pip install -U pip' and 'pip install requests' helps resolve this pipenv error?",
#     "Is there a way to prevent this 'ModuleNotFoundError' from occurring in future pipenv installations?"
# ]
# ```
# questions: ["What are the default login credentials for Grafana when accessing it through localhost?", "Why am I being prompted for a username and password when I try to access Grafana after running docker-compose up?", "How can I change the default password after logging into Grafana for the first time?", "Is there a specific video or resource that demonstrates how to resolve the Grafana login issue?", "Where can I find additional help if the default credentials don't work for Grafana?"]
# questions: ["Why do I get an 'unknown flag: --build' error when trying to start monitoring services in Linux?",
# "What is the correct command to start monitoring services in Linux if 'docker compose up --build' doesn't work?",
# "Can you explain the difference between 'docker compose' and 'docker-compose' in Linux?",
# "How do I resolve the issue where the monitoring services fail to start in Module 5?",
# "Is there a specific reason why 'docker compose up --build' doesn't work in Linux but 'docker-compose up --build' does?"]
# questions: ```json
# {
#   "questions": [
#     "Why am I getting a KeyError 'content-length' when running prepare.py?",
#     "What is the solution for the KeyError 'content-length' issue in prepare.py?",
#     "The link in prepare.py for downloading taxi data doesn't work—how can I fix it?",
#     "How do I modify the URL in prepare.py to resolve the KeyError?",
#     "Can you provide the updated URL for downloading taxi data in prepare.py?"
#   ]
# }
# ```
# questions: ["What does it mean when the Evidently service exits with code 2 during docker-compose up?",
# "How can I resolve the 'Max retries exceeded with url: /api' error when running the real-time prediction service?",
# "Why does the Evidently service fail to import 'pyarrow' in app.py, and how can I fix it?",
# "What are the possible solutions if the Evidently service crashes due to a missing pyarrow module?",
# "Is it safe to comment out the pyarrow import in app.py if the other solutions don't work?"]
# questions: ```json
# [
#   "Why am I getting a ValueError about an incorrect item when passing a metric to Report in evidently?",
#   "What does the error 'ValueError: Incorrect item instead of a metric or metric preset was passed to Report' mean in Module 5?",
#   "How can I fix the ValueError when using evidently to generate a report?",
#   "I encountered an error saying I passed an incorrect item to Report in evidently—what did I do wrong?",
#   "When using evidently, what is the common mistake that leads to the 'Incorrect item instead of a metric' error?"
# ]
# ```
# questions: ```json
# {
#   "questions": [
#     "What should I do if I encounter an error when using the RegressionQualityMetric() function?",
#     "Why is the target='duration_min' parameter necessary for RegressionQualityMetric()?",
#     "How do I properly set up the current_data['duration_min'] for RegressionQualityMetric()?",
#     "What are the specific requirements for using RegressionQualityMetric() in Module 5?",
#     "Can you explain the role of 'duration_min' in the RegressionQualityMetric() function?"
#   ]
# }
# ```
# questions: ```json
# [
#   "Why am I getting a ValueError stating 'Found array with 0 sample(s)' when running LinearRegression?",
#   "What causes the training dataset to be empty in Module 5?",
#   "How can I resolve the issue of having 0 samples in my dataset?",
#   "What specific adjustment should I make to the 'begin' date to avoid this error?",
#   "Who added the solution for the 'Found array with 0 sample(s)' error in the FAQ?"
# ]
# ```
# questions: [
#     "What should I do if I encounter errors about missing target or prediction columns after adding a new metric?",
#     "How can I determine whether a metric requires specific parameters when adding it to my monitoring setup?",
#     "Why did I not need to specify any parameters when adding DatasetCorrelationsMetric?",
#     "Where can I find detailed information about the requirements for adding different metrics in Module 5?",
#     "What steps should I take to troubleshoot errors related to metric configuration in monitoring?"
# ]
# questions: ["Why am I unable to log in to Grafana using the default admin credentials?", "What should I do if Grafana shows an error when I try to log in with the standard username and password?", "How can I resolve the login issue in Grafana when admin/admin doesn't work?", "What command should I run to fix the Grafana admin password problem?", "After encountering a login error in Grafana, how do I reset the admin password?"]
# questions: ```json
# [
#   "Why isn't my Grafana chart updating in real-time while my metric script is running?",
#   "What refresh interval should I set in Grafana to ensure my charts update frequently?",
#   "How does the timezone setting affect Grafana chart updates?",
#   "I changed my timezone from 'Europe/London' to my local zone, but why was this necessary for updates?",
#   "Are there specific settings in Grafana or my script that could prevent chart updates?"
# ]
# ```
# questions: [
#     "Why did my local Prefect server stop immediately after running the 'prefect server start' command?",
#     "What alternative solution can I use if the Prefect server fails to run locally?",
#     "Did the issue with the local Prefect server get reported or tracked anywhere?",
#     "How can I switch to using Prefect Cloud instead of a local server for running my scripts?",
#     "What steps should I take if I encounter a similar issue with the Prefect server in the future?"
# ]
# questions: ["What should I do if I encounter a 'no disk space left' error while running docker compose up?",
# "How can I free up disk space when Docker is causing storage issues?",
# "What command can I use to check Docker's disk usage before cleaning up?",
# "Is there a way to remove unused Docker items to resolve disk space errors?",
# "Can you explain how to clean up Docker system resources to fix disk space problems?"]
# questions: ["Why am I getting an error about failing to listen on :::8080 when running docker-compose up?",
# "What does the error 'php_network_getaddresses: getaddrinfo failed: Address family for hostname not supported' mean?",
# "How can I fix the issue where Adminer fails to start due to a network address error?",
# "Where should I add the command to resolve the 8080 listening error in the docker-compose file?",
# "What is the correct command to specify in the yml file to make Adminer run properly on port 8080?"]
# questions: [
#     "Is there a built-in way to generate Evidently-style charts directly in Grafana without additional plugins?",
#     "How can I export Evidently report data to use in external visualization tools like Grafana?",
#     "What specific Grafana panel types would be needed to recreate Evidently dashboards?",
#     "Why might it be more practical to use Evidently directly for debugging rather than recreating its visualizations in Grafana?",
#     "What additional parameters do I need to include when exporting Evidently JSON to preserve raw data for visualizations?"
# ]
# questions: [
#     "Why am I getting the error 'Unable to locate credentials' when running localstack with kinesis?",
#     "How can I resolve the 'Unable to locate credentials' error in my localstack setup?",
#     "What environment variables do I need to add to docker-compose.yaml to fix credential issues with localstack?",
#     "Is there a quick way to configure AWS credentials for localstack without modifying docker-compose.yaml?",
#     "What values should I use for AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY when setting up localstack?"
# ]
# questions: [
#     "Why am I getting an 'unspecified location constraint is incompatible' error when creating an S3 bucket with localstack and boto3?",
#     "How can I resolve the 'IllegalLocationConstraintException' error during S3 bucket creation in a specific region?",
#     "What is the correct way to create an S3 bucket in localstack to avoid location constraint errors?",
#     "Why does the boto3 client throw an error when I try to create a bucket without specifying a location constraint?",
#     "What should I include in the 'CreateBucketConfiguration' parameter to fix the 'unspecified location constraint' error?"
# ]
# questions: ```json
# [
#   "Why am I seeing the error '<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>' when running AWS CLI commands?",
#   "How can I resolve the AWS CLI error involving '<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>'?",
#   "What environment variables do I need to set to fix the AWS CLI error with '<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>'?",
#   "Do the values of AWS environment variables matter when fixing the '<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>' error?",
#   "Is there a quick way to resolve the '<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>' error in AWS CLI without complex configurations?"
# ]
# ```
# questions: ["Why does pre-commit show a 'mapping values are not allowed in this context' error during every commit?",
# "How can I fix the issue where pre-commit hooks fail to run with a YAML-related error?",
# "What should I check in my .pre-commit-config.yaml file to resolve indentation problems?",
# "Are there specific formatting rules for the .pre-commit-config.yaml file to avoid errors?",
# "Which part of the .pre-commit-config.yaml file commonly causes the 'mapping values' error?"]
# questions: [
#     "How do I completely reset pytest configuration after switching from a previous testing folder?",
#     "What steps should I take if pytest settings from an old folder are interfering with my current setup?",
#     "Where exactly do I need to delete the .vscode folder to fix pytest reconfiguration issues?",
#     "Why can't I remove pytest tests directly and what's the alternative solution?",
#     "Is there a specific location I should clean up to ensure pytest works properly in a new folder?"
# ]
# questions: ```json
# [
#     "Why does the get-records command return empty Records when following Module 6's video at 11:23?",
#     "What modification is needed for the Kinesis get-records call to resolve empty Records in LocalStack?",
#     "How can I fix the issue of empty Records when using Kinesis with LocalStack?",
#     "Is there a specific flag required for get-records to work correctly in LocalStack?",
#     "What is the solution for empty Records in Kinesis when following the steps in Module 6?"
# ]
# ```
# questions: ```json
# {
#   "questions": [
#     "Why am I getting a UTF-8 encoding error when trying to commit in Git after creating a pre-commit YAML file?",
#     "How can I resolve the 'utf-8 codec can't decode byte 0xff' error during a Git commit in PowerShell?",
#     "What steps should I take to set UTF-8 encoding for the pre-commit YAML file to avoid commit errors?",
#     "After creating a pre-commit-config.yaml file, Git commit fails with an encoding error—how do I fix this?",
#     "What is the correct way to create a pre-commit YAML file in PowerShell to prevent UTF-8 encoding issues?"
#   ]
# }
# ```
# questions: [
#     "Why does my Git commit fail with the error 'PythonInfo' object has no attribute 'version_nodot' when using a pre-commit hook?",
#     "How can I resolve the 'version_nodot' attribute error that occurs during a Git commit with pre-commit hooks?",
#     "What steps should I take if my pre-commit hook raises an unexpected 'PythonInfo' object error?",
#     "Is there a way to fix the 'CalledProcessError' and 'AttributeError' during Git commits with pre-commit hooks?",
#     "Can clearing the virtualenv app-data help resolve pre-commit hook errors like 'version_nodot' missing?"
# ]
# questions: [
#     "Why do I get a 'module not found' error when running pytest on my custom packages, but it works when running the test file directly?",
#     "How can I fix the 'No module named production' error when using pytest with my project structure?",
#     "What is the difference between running pytest directly and using python -m pytest for my tests?",
#     "Why does pytest not recognize my custom modules even though the test file runs fine when executed directly?",
#     "Are there alternative solutions besides using python -m pytest to resolve module import issues in pytest?"
# ]
# questions: [
#     "Why am I getting a 'module not found' error when running pytest with pre-commit hooks for custom packages?",
#     "How can I fix the 'No module named production' error during git commit when using pytest?",
#     "What changes should I make to my pre-commit hook configuration to resolve pytest import issues?",
#     "Can you explain the solution for pytest not finding custom modules in a pre-commit hook setup?",
#     "What is the correct way to configure a pre-commit hook to run pytest with custom package imports?"
# ]
# questions: ["Why am I getting a Permission denied error when running a script in GitHub Actions?",
# "How can I resolve the error code 126 in my GitHub Actions workflow?",
# "What steps should I take to fix execution permission issues for a script in GitHub Actions?",
# "How do I grant execute permissions to a script file before running it in a GitHub Actions workflow?",
# "What is the correct command to add execute permissions to a script in a GitHub repository?"]
# questions: ["How can I efficiently manage and run only specific containers from a large docker-compose file without overloading my system?", "What is the purpose of using profiles in a docker-compose file when dealing with multiple containers?", "How do I define and assign a profile to a service in my docker-compose configuration?", "What command should I use to start only the containers associated with a specific profile in docker-compose?", "Can you explain how profiles in docker-compose help streamline the testing process by isolating relevant containers?"]
# questions: ```json
# [
#     "Why are my integration tests failing when using Kinesis in Module 6?",
#     "How do I ensure my AWS region settings are consistent across docker-compose and local config?",
#     "What could be causing my Kinesis stream to be created in the wrong region?",
#     "Can you provide an example of matching AWS region settings between docker-compose and local config?",
#     "What steps should I take to troubleshoot region mismatch issues in Module 6?"
# ]
# ```
# questions: [
#     "Why is the pre-commit command failing when using isort in my repository?",
#     "What specific version of isort should I use to resolve the pre-commit issue?",
#     "How can I fix the isort pre-commit failure in Module 6?",
#     "Who provided the solution for the isort pre-commit problem?",
#     "What was the exact solution to the isort pre-commit error mentioned in the FAQ?"
# ]
# questions: [
#     "What steps should I follow to tear down AWS infrastructure that was deployed using GitHub Actions?",
#     "Can you explain how to properly destroy resources created by the CD-Deploy Action in AWS?",
#     "Is there a specific command sequence required to remove infrastructure managed by Terraform in this module?",
#     "How do I ensure the correct state file is used when destroying the infrastructure locally?",
#     "Are there any additional variables or configurations needed when running the destroy command for this setup?"
# ]

# %%
parsed_resulst = {}

for doc_id, json_questions in results.items():
    
    parsed_resulst[doc_id] = json.loads(json_questions)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[85], line 5
#       1 parsed_resulst = {}
#       3 for doc_id, json_questions in results.items():
# ----> 5     parsed_resulst[doc_id] = json.loads(json_questions)
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
print(json_questions)
# Out:
# ```json
# [
#   "Is it possible to enroll in the course after it has already begun?",
#   "What happens if I don't formally register but still want to participate?",
#   "Are there any deadlines I should be aware of if I join late?",
#   "Can I submit assignments if I join the course after the start date?",
#   "Will there be penalties for submitting the final project close to the deadline?"
# ]
# ```

# %%
doc_index = {d['id']: d for d in documents}

# %%
final_results = []

for doc_id, questions in parsed_resulst.items():
    course = doc_index[doc_id]['course']
    for q in questions:
        final_results.append((q, course, doc_id))

# %%
import pandas as pd

# %%
df = pd.DataFrame(final_results, columns=['question', 'course', 'document'])

# %%
df
# Out:
#                                             question  \
# 0  What is the exact start date and time for the ...
# 1  How can I stay updated with the course schedul...
# 2  Where do I need to register before the course ...
# 3  Is there a specific platform or channel for co...
# 4  What should I do to ensure I don't miss the be...
# 5  What background knowledge or skills do I need ...
# 6  Are there any specific technical requirements ...
# 7  Do I need prior experience with data engineeri...
# 8  What are the recommended prerequisites to ensu...
# 9  Is there a list of required skills or tools I ...
#
#                       course  document
# 0  data-engineering-zoomcamp  c02e79ef
# 1  data-engineering-zoomcamp  c02e79ef
# 2  data-engineering-zoomcamp  c02e79ef
# 3  data-engineering-zoomcamp  c02e79ef
# 4  data-engineering-zoomcamp  c02e79ef
# 5  data-engineering-zoomcamp  1f6520ca
# 6  data-engineering-zoomcamp  1f6520ca
# 7  data-engineering-zoomcamp  1f6520ca
# 8  data-engineering-zoomcamp  1f6520ca
# 9  data-engineering-zoomcamp  1f6520ca

# %%
df.to_csv('ground-truth-data.csv', index=False)

# %%
# !head ground-truth-data.csv
# Out:
# question,course,document
# What is the exact start date and time for the course?,data-engineering-zoomcamp,c02e79ef
# How can I stay updated with the course schedule and important announcements?,data-engineering-zoomcamp,c02e79ef
# Where do I need to register before the course begins?,data-engineering-zoomcamp,c02e79ef
# Is there a specific platform or channel for course-related communication?,data-engineering-zoomcamp,c02e79ef
# What should I do to ensure I don't miss the beginning of the course?,data-engineering-zoomcamp,c02e79ef
# What background knowledge or skills do I need before enrolling in this course?,data-engineering-zoomcamp,1f6520ca
# Are there any specific technical requirements I should meet to take this course?,data-engineering-zoomcamp,1f6520ca
# Do I need prior experience with data engineering tools to join this course?,data-engineering-zoomcamp,1f6520ca
# What are the recommended prerequisites to ensure I can follow the course material effectively?,data-engineering-zoomcamp,1f6520ca

# %% [markdown]
# ************************************************************************************************************

# %%
import csv

# Nombre del archivo
nombre_archivo_csv_fila = 'results_fila.csv'

try:
    with open(nombre_archivo_csv_fila, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = results.keys() # Las claves del diccionario serán los encabezados
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader() # Escribe los encabezados
        writer.writerow(results) # Escribe el diccionario como una fila

    print(f"Diccionario guardado exitosamente en '{nombre_archivo_csv_fila}' como una fila CSV.")
except Exception as e:
    print(f"Error al guardar el archivo CSV como una fila: {e}")
# Out:
# Diccionario guardado exitosamente en 'results_fila.csv' como una fila CSV.

# %%
prueba = results.items()

# %%
dato = results['c02e79ef']
dato_limpio = limpiar_valor(dato)
print(f"Dato limpio {dato_limpio}")
# Out:
# Dato limpio [ "What is the exact start date and time for the course?", "How can I stay updated with the course schedule and important announcements?", "Where do I need to register before the course begins?", "Is there a specific platform or channel for course-related communication?", "What should I do to ensure I don't miss the beginning of the course?" ]

# %%
for doc_id, json_questions in results.items():
    dato = json_questions
    dato_limpio = limpiar_valor(dato)
    results[doc_id] = dato_limpio

print(len(results))
# Out:
# 947

# %%
results['a3b9af04']
# Out:
# '["Why am I getting a Permission denied error when running a script in GitHub Actions?", "How can I resolve the error code 126 in my GitHub Actions workflow?", "What steps should I take to fix execution permission issues for a script in GitHub Actions?", "How do I grant execute permissions to a script file before running it in a GitHub Actions workflow?", "What is the correct command to add execute permissions to a script in a GitHub repository?"]'

# %%
for row in prueba:
    print(row)
# Out:
# ('c02e79ef', '[\n    "What is the exact start date and time for the course?",\n    "How can I stay updated with the course schedule and important announcements?",\n    "Where do I need to register before the course begins?",\n    "Is there a specific platform or channel for course-related communication?",\n    "What should I do to ensure I don\'t miss the beginning of the course?"\n]')
# ('1f6520ca', '[\n    "What background knowledge or skills do I need before enrolling in this course?",\n    "Are there any specific technical requirements I should meet to take this course?",\n    "Do I need prior experience with data engineering tools to join this course?",\n    "What are the recommended prerequisites to ensure I can follow the course material effectively?",\n    "Is there a list of required skills or tools I should be familiar with before starting the course?"\n]')
# ('7842b56a', '```json\n[\n  "Is it possible to enroll in the course after it has already begun?",\n  "What happens if I don\'t formally register but still want to participate?",\n  "Are there any deadlines I should be aware of if I join late?",\n  "Can I submit assignments if I join the course after the start date?",\n  "Will there be penalties for submitting the final project close to the deadline?"\n]\n```')
# ('0bbf41ec', '[\n    "If I haven\'t received a confirmation email after registering for the Data Engineering Bootcamp, does that mean I\'m not accepted?",\n    "Can I begin working on the course material and submitting assignments before receiving any confirmation?",\n    "Is registration mandatory to participate in the Data Engineering Bootcamp, or can I join without it?",\n    "How does the registration process for the Data Engineering Bootcamp work if it doesn\'t affect participation?",\n    "Will my homework submissions be checked if I haven\'t officially registered for the course?"\n]')
# ('63394d91', '[\n    "What are the recommended preparations I should complete before the course begins?",\n    "Which software tools and accounts do I need to set up prior to the course start date?",\n    "How can I ensure I meet the prerequisites for this course?",\n    "Is there a list of dependencies I should install before the course starts?",\n    "Where can I find the syllabus to review the topics covered in the course?"\n]')
# ('2ed9b986', '[\n    "How many Zoomcamp sessions are offered each year for the Data-Engineering course?",\n    "Can I enroll in the MLOps Zoomcamp outside of the May-August timeframe if I don\'t need certification?",\n    "Is the Machine Learning Zoomcamp the only one that runs into the next calendar year?",\n    "If I miss the live Data-Engineering cohort, can I still complete the course for certification later?",\n    "Are the schedules for each Zoomcamp cohort consistent from year to year?"\n]')
# ('93e2c8ed', '[\n    "How does the current cohort differ from the previous one in terms of tools and content?",\n    "What changes have been made to the course materials for the 2024 edition?",\n    "Why was Mage AI chosen over Prefect for the current cohort?",\n    "Were there any updates to the Terraform section compared to last year?",\n    "Can you explain the shift from Airflow to Prefect in the 2023 cohort?"\n]')
# ('a482086d', '[\n    "Will the course materials remain accessible once the course has ended?",\n    "Is it possible to complete assignments after the official course completion date?",\n    "Can I still work on the capstone project if I join after the course finishes?",\n    "Are there any limitations to accessing the content post-course?",\n    "How can I prepare for future cohorts using the current course materials?"\n]')
# ('eb56ae98', '[\n    "Is there any support available for students taking the self-paced version of the course?",\n    "How can I get help if I\'m stuck while studying at my own pace?",\n    "Are there any resources I should check before asking for assistance in the Slack channel?",\n    "Can I use the ZoomcampQABot to find answers to my questions in the Slack channel?",\n    "How reliable are the answers provided by the ZoomcampQABot when searching for solutions?"\n]')
# ('4292531b', '[\n    "What is the main YouTube playlist I should follow for the course videos?",\n    "Are there any additional playlists for specific years or office hours videos?",\n    "Where can I find the link to the main DATA ENGINEERING playlist?",\n    "Is the GitHub repository updated with direct links to the YouTube videos?",\n    "Where in the Slack channel can I find the pinned playlist for easy access?"\n]')
# ('ea739c65', '[\n  "How much weekly time commitment should I anticipate for this course based on my prior knowledge?",\n  "Can you provide guidance on estimating the weekly study hours needed for this course?",\n  "What factors influence the amount of time I\'ll need to dedicate to this course each week?",\n  "Is there a way to calculate the expected weekly workload for this course myself?",\n  "Where can I find resources to help me determine my personal time investment for this course?"\n]')
# ('cb257ee5', '[\n    "Is it possible to receive a course certificate if I complete the material at my own pace?",\n    "Why are certificates only awarded for the live cohort and not the self-paced version?",\n    "What is the reason behind requiring peer reviews for capstone projects to earn a certificate?",\n    "Can I still access the course content if I choose the self-paced mode without aiming for a certificate?",\n    "Are there any exceptions where a certificate might be granted for self-paced completion?"\n]')
# ('04aa4897', '[\n  "How can I access the live stream for Office Hour or workshop sessions?",\n  "Where is the YouTube Live link shared before the Office Hour starts?",\n  "Why shouldn\'t I post questions in the YouTube chat during Office Hours?",\n  "How do I submit questions during the Office Hour sessions?",\n  "Can I participate in Office Hours via Zoom, or is it only through YouTube Live?"\n]')
# ('9681be3b', '```json\n[\n    "Will the Office Hours sessions be available for viewing after the live session ends?",\n    "If I miss the live Office Hours, can I still access the recording later?",\n    "Are the Office Hours recordings posted immediately after the session concludes?",\n    "Is there a delay between the end of the live Office Hours and when the recording is available?",\n    "Can I rewatch the Office Hours sessions multiple times if needed?"\n]\n```')
# ('a1daf537', '```json\n[\n    "Where can I find the current deadlines for homework and projects in this course?",\n    "How will I be notified if there are any changes to the homework or project deadlines?",\n    "Is there a specific platform or link where all assignment deadlines are listed?",\n    "Who should I follow for updates regarding deadline extensions or other course announcements?",\n    "What should I do if the deadline shown in the course materials differs from the one announced by the instructor?"\n]\n```')
# ('be5bfee4', '[\n    "Is it possible to submit homework after the deadline if the submission form is still open?",\n    "What happens if I try to submit my homework late?",\n    "How can I verify that my homework submission was on time?",\n    "Are there any exceptions to the late submission policy for homework?",\n    "Where can I check the exact deadline for homework submissions?"\n]')
# ('0e424a44', '[\n    "Where can I find the homework assignments for this course?",\n    "Is there a specific platform we should use to submit our homework?",\n    "Can I use any version control system for my homework submissions?",\n    "What should be included in my homework submission to meet the requirements?",\n    "How do I ensure my homework is accessible and correctly submitted for grading?"\n]')
# ('29865466', '[\n    "How are homework assignments graded in the course management platform?",\n    "Where can I see the total points I\'ve earned for all my submissions?",\n    "What types of activities contribute to the points displayed on the leaderboard?",\n    "How many points do I receive for submitting a question to the FAQ section?",\n    "Is there a difference in points awarded for homework, FAQ submissions, and Learning in Public posts?"\n]')
# ('016d46a1', '[\n    "How can I find out what my display name is on the leaderboard?",\n    "Why don\'t I see my name on the leaderboard after setting up my account?",\n    "Where do I go to change my display name for the course?",\n    "Is it possible to customize my display name on the leaderboard?",\n    "What steps do I need to follow to view or update my profile in the course?"\n]')
# ('47972cb1', '```json\n["Is Python 3.9 still the best version to use for this course in 2024, or should I upgrade to a newer version?", "Will using Python 3.10 or 3.11 cause any issues with the course materials?", "Why does the course recommend sticking with Python 3.9 instead of the latest version?", "Are there any specific advantages to using Python 3.9 over newer versions for this course?", "If I encounter problems with a newer Python version, will troubleshooting support be provided?"]\n```')
# ('ddf6c1b3', '["What are the pros and cons of setting up the environment on my local machine versus using a virtual machine?", "Can I switch between using my local machine and GitHub Codespaces during the course, or do I need to stick to one option?", "Are there any specific challenges Windows users might face when setting up the environment locally?", "Is there a recommended approach for students who want to work across multiple devices, like home and office computers?", "Do I need prior experience with Docker to set up the environment locally, or will the course guide me through it?"]')
# ('ac25d3af', '[\n    "Can I use GitHub Codespaces instead of CLI tools like git bash for data ingestion and Docker file creation?",\n    "What are the advantages of using GitHub Codespaces over local CLI tools for this course?",\n    "Does GitHub Codespaces come with Docker and other necessary tools pre-installed?",\n    "Is it possible to directly open a GitHub repository in GitHub Codespaces for this course?",\n    "Are the computing resources provided by GitHub Codespaces sufficient for the course\'s Docker and data tasks?"\n]')
# ('251218fc', '["Is it mandatory to use GitHub Codespaces for the course, or can I use my local setup with PostgreSQL and Docker?", "Can I complete the course using my own laptop instead of GitHub Codespaces or GCP VM?", "Are there any advantages to using GitHub Codespaces over my existing local environment with Docker and PostgreSQL?", "What are the recommended environment options for the course if I don’t want to use GitHub Codespaces?", "If I already have Docker and PostgreSQL installed, do I still need to set up GitHub Codespaces for the coursework?"]')
# ('3c0114ce', '[\n  "Is it necessary to use both GitHub Codespaces and GCP for the course, or can I choose one?",\n  "Will BigQuery be required for the course, and if so, should I prioritize learning GCP?",\n  "Can I complete the course using only a local environment instead of cloud services?",\n  "What are the advantages of using GCP over GitHub Codespaces for this course?",\n  "If I prefer GitHub Codespaces, will I miss out on any critical course content?"  \n]')
# ('f43f5fe7', '```json\n["How can I open the Run command window on a Windows machine to access the registry editor?", "Where exactly in the Registry Editor do I need to modify the \'Autorun\' value for GCP VM connection issues?", "What specific change should I make to the \'Autorun\' registry value to resolve the VSCode-GCP VM connection problem?", "Is there an alternative solution to modifying the registry, such as dealing with the known_hosts file?", "Where is the known_hosts file located on a Windows system if I want to delete the fingerprint manually?"]\n```')
# ('d061525d', '[\n    "Why is GCP the recommended cloud platform for this course instead of alternatives like AWS or Azure?",\n    "Am I allowed to use a different cloud provider like AWS if I\'m more familiar with it?",\n    "What are the benefits of using GCP for this course, especially for students?",\n    "Do I need a credit card to sign up for the GCP free trial mentioned in the course?",\n    "Is BigQuery a mandatory tool for the course, and does it require a GCP account?"\n]')
# ('1cd01b2c', '["Is there any cost associated with using cloud services for this course?", "Do I need to pay for Google Cloud Platform during the course?", "Are there any free options available for cloud services in this course?", "Will the course cover how to use GCP\'s free trial?", "Is financial assistance available for cloud service usage in this course?"]')
# ('e4a7c3b0', '```json\n["Is it possible to complete the course without using cloud providers like GCP?", "Are there local alternatives for all the tools used in the course?", "Will the course provide instructions for setting up a home lab environment?", "Can I run BigQuery locally or is there a substitute for it?", "What limitations should I expect if I choose to do the course entirely locally?"]\n```')
# ('7cd1912e', '[\n    "Can I use AWS for all the course projects and assignments?",\n    "What are the potential challenges of using AWS instead of the recommended platform?",\n    "Will using AWS affect how my final capstone project is evaluated?",\n    "How can I get help if I encounter issues while using AWS for the course?",\n    "Are there any specific adjustments I need to make when using AWS instead of the default platform?"\n]')
# ('52393fb3', '["Are there any additional live Zoom sessions scheduled apart from the Office Hours?", "Will there be any live calls during the Capstone project phase?", "How will we be informed about any extra live Zoom meetings?", "Can we expect any surprise live sessions, or will they all be announced beforehand?", "Is the Capstone period the only time when extra live calls might happen?"]')
# ('10515af5', '[\n    "Is the NYC Trip dataset for January 2021 still the one we\'re working with this year, or has it been updated to 2022?",\n    "Will there be any changes to the project requirements compared to last year\'s course?",\n    "Where can I access the dataset required for the project?",\n    "Are we expected to use the same methodology as last year\'s students for this project?",\n    "Is there any additional data we should incorporate beyond the provided NYC Trip dataset?"\n]')
# ('cdb86a97', '[\n    "Is the repository for the 2022 course materials still available?",\n    "Where can I find the content from the 2022 version of the course?",\n    "Has the 2022 course material been removed or relocated?",\n    "Can I still access the previous year\'s (2022) course resources?",\n    "What happened to the 2022 course repository? Is it no longer accessible?"\n]')
# ('3e0114ad', '["Is it acceptable to utilize a different tool like Airflow for the final project submission?", "Are there any restrictions on the tools we can choose for our final project?", "Would using a tool other than the ones taught in the course be allowed for the project?", "Can students select their preferred software or platform for the final assignment?", "Is Airflow an approved tool for completing the course\'s final project requirements?"]')
# ('b2799574', '[\n    "Can I use a different data orchestration tool like Airflow or Prefect instead of Mage for the course projects?",\n    "Are we allowed to substitute AWS or Snowflake for the GCP products mentioned in the course materials?",\n    "If I prefer Tableau over Metabase or Google Data Studio, can I use it for visualization assignments?",\n    "What are the implications of choosing an alternative tool stack that differs from the ones covered in the course?",\n    "Will the instructors provide support if I decide to use a different set of tools than those recommended in the course?"\n]')
# ('2f19301f', '["How can I help improve the course materials?", "What are the ways to support this course?", "Is there a way to suggest changes to the repository?", "Can I share this course with others if I find it helpful?", "What contributions are welcome for this course?"]')
# ('7c700adb', '["Is the course compatible with Windows, macOS, and Linux operating systems?", "Do I need a specific operating system to successfully complete the course?", "Are there any advantages to using Linux over other operating systems for this course?", "Have students previously used different operating systems without issues in this course?", "Will using a non-Linux OS put me at a disadvantage in the course?"]')
# ('44b14808', '["What should Windows users do if they encounter issues with shell scripts in the course modules?", "Why is WSL recommended for Windows users in this course?", "Are there any known workarounds for Windows users who can\'t use WSL with shell scripts?", "Which specific modules in the course are problematic for Windows users without WSL?", "How have past cohorts handled the shell script challenges on Windows?"]')
# ('76e4baf6', '["Are there any recommended books or materials to supplement the course content?",  \n"Can you suggest additional resources to enhance my understanding of the course topics?",  \n"Where can I find a list of recommended readings for this course?",  \n"Do you have any external resources or books that align with the course curriculum?",  \n"Is there a compilation of suggested materials to further explore data engineering concepts?"]')
# ('48b533a8', '[\n    "What are the differences between Project Attempt #1 and Project Attempt #2?",\n    "Can I submit my project after the first deadline if I missed it?",\n    "If I fail the first project submission, do I get another opportunity to submit it?",\n    "How many chances do I have to complete the project successfully?",\n    "Is there a penalty for submitting the project during the second attempt?"\n]')
# ('954044d1', '```json\n[\n    "What should I do first when I encounter a technical issue in the course?",\n    "How can I effectively search for solutions to errors or problems I encounter?",\n    "What information should I include when asking for help in Slack or other forums?",\n    "Why is it discouraged to tag instructors directly when asking for help?",\n    "What should I do if none of the troubleshooting steps resolve my issue?"\n]\n```')
# ('a820b9b3', '```json\n[\n    "What should I do if the troubleshooting guide doesn\'t resolve my issue?",\n    "What details should I include when asking for help with a coding problem?",\n    "Why is it important to mention what I\'ve already tried when seeking assistance?",\n    "How can I ensure my question gets a helpful response from the course staff?",\n    "Where can I find guidance on how to properly ask questions in this course?"\n]\n```')
# ('f2945cd2', '[\n  "What steps should I follow to set up Git and GitHub for this course?",\n  "How can I clone the course repository to my local machine?",\n  "Are there any specific files or data types I should avoid including in my GitHub repositories?",\n  "Where can I find tutorials or resources for creating and managing my own repositories?",\n  "Is it safe to store sensitive information like passwords or keys in a private GitHub repository?"\n]')
# ('eb9d376f', '[\n    "Why am I getting the \'missing separator\' error in my Makefile and how can I fix it?",\n    "How do I change VS Code settings to use tabs instead of spaces for indentation?",\n    "What should I do when my Makefile fails with a separator error?",\n    "Can you explain why tabs are required in Makefiles and how to ensure they\'re used?",\n    "Where can I find guidance on converting spaces to tabs in VS Code for Makefile compatibility?"\n]')
# ('72f25f6d', '```json\n[\n    "How can I open an HTML file in a Windows browser when using Linux on WSL?",\n    "What command should I use to view an HTML file from WSL in my default Windows browser?",\n    "Is it possible to specify a different browser to open HTML files from WSL on Windows?",\n    "How do I set up WSL to open HTML files directly in a Windows browser?",\n    "Can I customize which browser opens HTML files from WSL, and if so, how?"\n]\n```')
# ('a1e59afc', '```json\n[\n    "How can I set up Chrome Remote Desktop on a Debian Linux VM in Compute Engine?",\n    "What should I do if I encounter an ERROR 403 when downloading Yellow Taxi Trip Records from the TLC website?",\n    "Is there a backup source available for the 2021 Yellow Taxi Trip data if the original link fails?",\n    "How do I properly unzip the \'gz\' file for the Yellow Taxi Trip data?",\n    "Can you explain the purpose of using Chrome Remote Desktop for accessing applications on a Linux VM?"\n]\n```')
# ('71c10610', '["How should I name the taxi data file to ensure it stores correctly in the course exercise?",  \n"What is the correct way to handle the file extension when working with the provided taxi data URL?",  \n"Can I use the original .csv.gz file extension when reading the taxi data with pandas, or do I need to change it?",  \n"How can I extract the file name from the taxi data URL to use it in my code?",  \n"Why does the course recommend changing the file name from .csv.gz to .csv, and is it necessary for pandas?"]')
# ('17a5aea1', '```json\n[\n    "Where can I find the data dictionary for the Yellow Taxi trip records in Module 1?",\n    "Is there a separate data dictionary available for the Green Taxi trips in the NY Taxi dataset?",\n    "What is the official source for the data dictionaries of the NY Taxi trip records?",\n    "Can you provide links to the documentation for the Yellow and Green Taxi data in Module 1?",\n    "Are the data dictionaries for the NY Taxi datasets provided in PDF format?"\n]\n```')
# ('5a275db7', '[\n    "How can I unzip the downloaded parquet file for the taxi data using the command line?",\n    "What is the command to convert the gzipped parquet file into a CSV file?",\n    "How do I modify the ingest_data.py script to directly use parquet files instead of CSV?",\n    "What changes should I make in the main function to handle parquet file downloads and conversions?",\n    "Can you explain how to convert a parquet file to a CSV file within a Python script using pandas?"\n]')
# ('7ec0f9b0', '```json\n[\n  "How do I fix the \'wget is not recognized as an internal or external command\' error on Ubuntu?",\n  "What is the easiest way to install wget on a MacOS system?",\n  "Can you guide me through installing wget on Windows using Chocolatey?",\n  "Is there an alternative method to install wget on Windows without using Chocolatey?",\n  "Are there Python-based alternatives to using the wget command for downloading files?"\n]\n```')
# ('bb1ba786', '```json\n[\n    "How can I resolve the \'cannot verify website certificate\' error when using wget on MacOS?",\n    "What should I do if wget fails to verify a certificate in a Jupyter Notebook?",\n    "Are there alternative methods to download files using wget if certificate verification fails?",\n    "Can I bypass certificate checks when running wget from the command line?",\n    "What is the correct syntax for using wget with the --no-check-certificate flag?"\n]\n```')
# ('2f83dbe7', '```json\n[\n    "How can I configure Git Bash on Windows to treat backslash as an escape character?",\n    "What command should I use in Git Bash for Windows to enable backslash escaping?",\n    "Is it necessary to modify the .bashrc file to use backslash as an escape character in Git Bash?",\n    "Can you explain the correct syntax for setting the escape character in Git Bash for Windows?",\n    "Why might someone prefer using backslash as an escape character in Git Bash, and how can they enable it?"\n]\n```')
# ('543ff080', '[\n    "How can I securely store and access secrets within GitHub Codespaces for my projects?",\n    "What is the recommended method to manage account-specific secrets in GitHub Codespaces?",\n    "Where can I find detailed instructions for handling secrets in GitHub Codespaces?",\n    "Is there a specific documentation resource for managing secrets in GitHub Codespaces?",\n    "Can you explain the process of making secrets available in GitHub Codespaces?"\n]')
# ('d407d65b', '["What should I do if I encounter an error saying Docker daemon is not running when trying to connect to unix:///var/run/docker.sock?", "How can I ensure the Docker daemon is properly started before attempting to connect?", "What steps should I take if I receive a connection error to the Docker daemon on my system?", "Is there a specific command I need to run to update WSL before resolving Docker daemon issues?", "Why am I unable to connect to the Docker daemon, and what troubleshooting steps should I follow?"]')
# ('c9375c56', '```json\n[\n    "Why do I get an error saying the Docker client must be run with elevated privileges on Windows?",\n    "How can I enable Hyper-V for Docker on Windows 10 Pro or 11 Pro?",\n    "What should I do if I\'m using Windows Home edition and can\'t use Hyper-V for Docker?",\n    "Where can I find detailed instructions to set up WSL2 for Docker on Windows?",\n    "What steps should I take if I encounter the \'WslRegisterDistribution failed with error: 0x800701bc\' issue?"\n]\n```')
# ('e866156b', '```json\n[\n    "Why do I get a \'repository does not exist\' error when pulling a Docker image, and how can I fix it?",\n    "Do I need to log in to Docker Hub to pull the images used in the Data Engineering Zoomcamp?",\n    "What should I do if I encounter a \'permission denied\' error while mounting a volume in a PostgreSQL Docker container on macOS M1?",\n    "Is it necessary to use Docker Desktop instead of Rancher Desktop for the course exercises?",\n    "How can I verify if a Docker image name is correct before pulling it to avoid errors?"\n]\n```')
# ('16370470', '["Why can\'t I delete a local folder that was mounted as a Docker volume?",  \n"How do I remove a Docker-created folder that has restricted permissions?",  \n"What command should I use to force-delete a protected folder created by Docker?",  \n"Why does Obsidian fail to start due to a folder access error related to Docker?",  \n"How can I change the ownership or permissions of a folder created by a Docker container?"]')
# ('316df755', '["What should I do if Docker is stuck on the starting screen in Windows 10 or 11?",  \n"How can I switch between container types if Docker is not starting properly?",  \n"Where can I download the latest version of Docker for Windows if the in-app upgrade fails?",  \n"Do I need to enable Hyper-V to run Docker on Windows 10/11 Pro, and how do I do it?",  \n"What are the steps to configure WSL2 as the backend for Docker on Windows?"]')
# ('f3aa9252', '[\n    "What is the recommended file system for running Docker commands on Windows with WSL?",\n    "Can I use Docker with Windows 10/11 Home Edition, and if so, how?",\n    "What should I do if Docker gets stuck even after setting up WSL2 or Hyper-V correctly?",\n    "Is it better to run Docker commands from the Windows file system or the WSL Linux file system?",\n    "Are there any troubleshooting steps if Docker doesn\'t work properly after WSL2 setup?"\n]')
# ('a4abe7a5', '```json\n[\n    "What is the recommended way to store code for optimal file system performance when using Docker on Windows 10/11 Home?",\n    "Does Docker on WSL2 backend have specific requirements for code storage to ensure performance?",\n    "Where can I find detailed guidelines on best practices for Docker file system performance?",\n    "Is there a preferred location to store code when running Docker with WSL2 on Windows Home editions?",\n    "How does the default Linux distro in Docker impact file system performance for Windows users?"\n]\n```')
# ('fb930700', '```json\n[\n  "Why do I get the error \'the input device is not a TTY\' when running Docker on Windows?",\n  "How can I fix the \'input device is not a TTY\' issue in Docker for Windows?",\n  "What is the solution for the TTY error when using Docker with mintty on Windows?",\n  "Can I create an alias to avoid typing \'winpty\' before every Docker command?",\n  "Where should I add the alias to make \'winpty docker\' the default on Windows?"\n]\n```')
# ('aa187680', '```json\n[\n    "Why am I getting a \'Temporary failure in name resolution\' error when trying to pip install inside a Docker container on Windows?",\n    "How can I resolve the pip installation failure due to DNS issues in a Docker container?",\n    "What is the correct Docker run command to fix pip install errors related to name resolution?",\n    "Why does my Docker container fail to connect to the internet when running pip install on Windows?",\n    "What DNS settings should I use in Docker to avoid pip install connection problems on Windows?"\n]\n```')
# ('b000e899', '[\n    "Why is the ny_taxi_postgres_data folder empty in VS Code after running the Docker script?",\n    "What specific command should I use to resolve the empty folder issue in Docker for Windows?",\n    "How do I properly set the volume path in Docker to ensure data appears in ny_taxi_postgres_data?",\n    "Are there any environment variables I need to configure to fix the empty folder problem in Docker?",\n    "What could be causing the data not to appear in the ny_taxi_postgres_data folder despite running the script correctly?"\n]')
# ('9c66759f', '[\n  "What is the recommended method for setting up Docker on a Mac?",\n  "Is the traditional method of installing Docker on macOS still reliable?",\n  "Where can I find the most up-to-date Docker installation for Mac?",\n  "Why might the older Docker setup method for Mac not work properly?",\n  "Has Docker\'s licensing change affected the installation process on macOS?"\n]')
# ('e3106e07', '[\n    "When running a PostgreSQL container, I get an error saying \'could not change permissions of directory \\"/var/lib/postgresql/data\\": Operation not permitted\'. How can I resolve this?",\n    "What is the correct way to map a local volume to the PostgreSQL data directory in Docker to avoid permission issues?",\n    "How do I create and use a Docker volume for PostgreSQL data instead of a local directory to prevent permission errors?",\n    "After running the Docker command for PostgreSQL, how can I verify that the volume was created successfully?",\n    "I encountered another error stating \'directory \\"/var/lib/postgresql/data\\" exists but is not empty\'. What should I do in this case?"\n]')
# ('72229da5', '["Why am I getting an \'invalid reference format\' error when trying to mount Docker volumes on Windows?",  \n"What are some alternative ways to format the volume mapping command to avoid issues on Windows?",  \n"How can I fix the problem where Docker creates an incorrect folder name when mounting volumes?",  \n"Are there any specific syntax changes needed for Mac users when mounting volumes in Docker?",  \n"What should I do if none of the suggested volume mapping options work on my system?"]')
# ('58c9f99f', '```json\n[\n    "How can I resolve the \'invalid mode\' error when mounting a volume in Docker on Windows?",\n    "What should I do if Docker gives an error about the mounting path being invalid?",\n    "Why does Docker complain about the mode when I try to mount a volume in Windows?",\n    "What is the correct way to specify a volume mount path in Docker for Windows to avoid errors?",\n    "Can you explain how to fix the mounting path issue in Docker when using Git Bash on Windows?"\n]\n```')
# ('bc42139a', '[\n    "Why am I getting the error \'Error response from daemon: error while creating buildmount source path\' when running my Docker container a second time?",\n    "How can I resolve the issue where Docker fails to mount a volume on subsequent runs of the same container?",\n    "What changes should I make to my Docker command to avoid the \'file exists\' error when re-running a container with a mounted volume?",\n    "Is it necessary to mount the volume every time I run the same Docker container, or can I skip it after the first run?",\n    "What is the correct way to run a PostgreSQL container in Docker after the initial setup to avoid mounting conflicts?"\n]')
# ('a146e3ee', '["Why am I getting a \'can\\\\\'t stat\' error when trying to build my Docker image for the taxi ingest project?",  \n"How can I resolve permission issues when Docker can\\\\\'t access a directory during the build process?",  \n"What files are strictly necessary to include when running the \'docker build\' command for this project?",  \n"Are there different solutions for fixing directory permission issues on Ubuntu versus Windows for Docker builds?",  \n"Where can I find a more detailed explanation for troubleshooting Docker build context errors?"]')
# ('593a85ba', '```json\n["Why do I get \'ERRO[0000] error waiting for container: context canceled\' when using Docker?", "How can I check if Docker was installed via snap?", "What should I do if \'snap status docker\' returns an unknown command error?", "Why does Docker fail to bind to port 0.0.0.0:5432?", "What is the recommended way to install Docker to avoid these issues?"]\n```')
# ('50bd1a71', '```json\n[\n    "Why am I getting a \'can’t stat\' error when trying to build a Docker image in PopOS Linux?",\n    "What could be causing the Docker build context to fail with a permissions issue in my project folder?",\n    "How do I resolve the \'can’t stat\' error related to folder permissions in Docker on PopOS?",\n    "Why does my host folder appear empty in Docker even though it contains files?",\n    "What command should I use to grant Docker the necessary permissions to access a folder in PopOS?"\n]\n```')
# ('f409f751', '["Why do I get a permission denied error when trying to rebuild my Docker container on Ubuntu?",  \n"How can I resolve the \'failed to solve with frontend dockerfile.v0\' error in Docker?",  \n"What does the error \'error from sender: open ny_taxi_postgres_data: permission denied\' mean in Docker?",  \n"Which permission settings should I use for the ny_taxi_postgres_data folder to fix Docker build issues?",  \n"Is it safe to use chmod 777 for the ny_taxi_postgres_data folder when facing Docker permission problems?"]')
# ('7d217da3', '```json\n[\n    "How can I find out the name of a Docker network in Module 1?",\n    "What command should I use to list all Docker networks in this module?",\n    "Where can I locate the Docker network name as mentioned in Module 1?",\n    "Is there a specific Docker command to retrieve network names in Module 1?",\n    "How do I check the available Docker networks for the exercises in Module 1?"\n]\n```')
# ('09081824', '```json\n[\n    "What should I do when Docker shows an error that the container name \'pg-database\' is already in use?",\n    "How can I resolve the conflict when Docker says a container name is already taken by another container?",\n    "Why does Docker give a \'Conflict\' error when trying to reuse a container name, and how do I fix it?",\n    "What steps should I follow to remove or rename a Docker container that\'s causing a naming conflict?",\n    "Can I restart a Docker container without removing it if the name is already in use, and how?"\n]\n```')
# ('4df80c55', '["What does the error \'could not translate host name \\"pgdatabase\\" to address\' mean when using docker-compose?",  \n"How can I resolve the host name translation error in Docker when running an ingestion script?",  \n"Which network should I use in the ingestion script if the default \'pg-network\' isn\'t working?",  \n"Why does the database host name change when running \'docker-compose up -d\', and how do I find the correct one?",  \n"What adjustments are needed in the ingestion script if the Docker network or database name differs from the default?"]')
# ('3aee7261', '```json\n[\n    "What should I do if I can\'t install Docker on a MacOS or Windows 11 VM running on Linux due to nested virtualization issues?",\n    "Are there specific commands I need to run before starting my VM to resolve Docker installation problems on a Linux-hosted VM?",\n    "How do I enable nested virtualization for Docker installation on an Intel CPU-based system?",\n    "What steps are required to configure nested virtualization for Docker on an AMD CPU when using a Linux-hosted VM?",\n    "Why does Docker fail to install on my MacOS/Windows 11 VM running on Linux, and how can I fix it?"\n]\n```')
# ('6497b659', '```json\n[\n    "How can I manage Docker containers and images directly from VS Code?",\n    "What is the process for connecting VS Code to Docker running on WSL2?",\n    "Which extension should I install in VS Code to work with Docker?",\n    "What command should I use to stop a running Docker container?",\n    "Can VS Code interact with Docker Compose projects, and if so, how?"\n]\n```')
# ('a02f2039', '```json\n[\n    "Why does my PostgreSQL container show a message about the database directory containing a database but the system is shut down?",\n    "What does it mean when the server terminates abnormally while processing a request in a PostgreSQL container?",\n    "How can I resolve the issue where my Dockerized PostgreSQL container is not accepting any connections?",\n    "What should I do if I encounter the error \'connection failed: server closed the connection unexpectedly\' in my PostgreSQL container?",\n    "Why do I need to delete the mapped data directory and restart the container when my PostgreSQL database fails to start?"\n]\n```')
# ('c6db65aa', '["Why can\'t I install Docker on my Ubuntu system using the standard package manager?", "What alternative method can I use to install Docker if the traditional approach fails on Ubuntu?", "Is there a specific command I should run to install Docker via snap on Ubuntu?", "Are there certain Ubuntu versions where Docker installation through apt doesn\'t work?", "How do I resolve Docker installation issues on Ubuntu when the conventional method isn\'t available?"]')
# ('f476a606', '[\n    "Why am I getting a \'could not change permissions\' error when mounting a directory in Docker-Compose for Postgres?",\n    "How do I properly configure a named volume in Docker-Compose to avoid mounting issues?",\n    "What steps should I take if Docker-Compose creates a new volume instead of using the existing one?",\n    "How can I check the mount location of a Docker volume to troubleshoot permission errors?",\n    "What is the correct way to rename or adjust Docker volumes to resolve mounting conflicts in Docker-Compose?"\n]')
# ('e41b100c', '```json\n[\n    "Why am I getting the error \'Couldn’t translate host name to address\' when using Docker-Compose?",\n    "How do I start the PostgreSQL database and pgAdmin containers in detached mode?",\n    "What command should I use to check if my containers are running after starting them?",\n    "How can I view the logs for a specific container to troubleshoot issues?",\n    "What should I do if the PostgreSQL container is not listed when I run \'docker ps\'?"\n]\n```')
# ('cd0f9300', '```json\n[\n    "Why does my Docker-Compose setup lose database data after running `docker-compose up`?",\n    "How can I resolve the \'could not translate host name pg-database\' error in my Ingestion script?",\n    "What should I do if Docker-Compose creates an unexpected default network?",\n    "Where can I find the network name that Docker-Compose generates for my containers?",\n    "Are there alternative tools like pgcli that I can use if issues persist with database connections?"\n]\n```')
# ('7f845a1c', '["Why am I getting an error that the hostname does not resolve when using Docker-Compose?",  \n"What steps should I take if Docker-Compose cannot find the network for my containers?",  \n"How can I fix the issue where my localhost server cannot connect to the PostgreSQL database due to hostname resolution?",  \n"What naming conventions should I follow for hostnames in Docker-Compose to avoid resolution errors?",  \n"How do I properly configure networks in docker-compose.yml to ensure containers can communicate with each other?"]')
# ('36e54439', '```json\n["How can I persist PGAdmin data when using Docker-Compose on GCP?", "Why isn\'t my specified volume path working for PGAdmin in Docker-Compose?", "What is the alternative to using a local path for PGAdmin volumes in Docker-Compose?", "How do I configure Docker Volumes to ensure PGAdmin data persistence on GCP?", "Can you explain the correct way to set up volumes for PGAdmin in a Docker-Compose file?"]\n```')
# ('32e8450c', '[\n    "Why does Docker Engine keep crashing and showing \'failed to fetch extensions\' errors repeatedly?",\n    "What should I do if restarting Docker doesn\'t resolve the continuous crashing issue?",\n    "How can I fix the persistent \'failed to fetch extensions\' pop-up errors in Docker?",\n    "Is updating Docker to the latest version a solution for the crashing and extension errors?",\n    "If updating Docker doesn\'t work, what is the final step to resolve the crashing and extension fetch issues?"\n]')
# ('96606db2', '```json\n[\n    "How can I persist pgAdmin configuration settings like server names in Docker-Compose?",\n    "What is the correct way to mount a volume for pgAdmin session data in a Docker-Compose file?",\n    "Why do I need to adjust permissions for the \'pgAdmin_data\' folder before running docker-compose up?",\n    "Which environment variables are required for pgAdmin in Docker-Compose to set up default credentials?",\n    "What are the UID and GID of the user running the pgAdmin container, and why are they important for volume permissions?"\n]\n```')
# ('0882bfac', '[\n    "How can I resolve the \'permission denied\' error when trying to connect to Docker\'s socket in Docker-Compose?",\n    "What steps should I follow to ensure my user has the correct permissions to run Docker commands without sudo?",\n    "Why does pgAdmin forget my database connection settings every time I restart the containers, and how can I fix this?",\n    "What changes do I need to make in my docker-compose.yaml file to persist pgAdmin\'s connection settings?",\n    "Where can I find detailed instructions for setting up Docker to avoid permission issues and maintain pgAdmin state?"\n]')
# ('7d067f5c', '["Why is docker-compose not working even after updating my .bashrc file?", "How can I fix the issue where docker-compose command is not recognized after installation?", "What should I do if the downloaded docker-compose file has a different name than expected?", "Why am I unable to use the docker-compose command despite following the installation steps?", "How do I rename the docker-compose file to make the command work properly?"]')
# ('ff352621', '["What should I do if I encounter an error about credentials when running docker-compose up -d?",  \n"How can I resolve the Docker-Compose credential error mentioned in Module 1?",  \n"After running docker-compose up -d, I get an error related to credentials. What is the solution?",  \n"Where can I find more information about fixing the Docker-Compose credential error?",  \n"Which package do I need to install to fix the Docker-Compose credential issue?"]')
# ('2d653208', '[\n    "What should I do if I encounter errors with my docker-compose.yml file while setting up pgadmin?",\n    "How can I resolve issues related to data ingestion when using Docker-Compose with PostgreSQL?",\n    "What steps should I follow to ensure proper execution of the Docker-Compose setup for this module?",\n    "Why is it important to set low_memory=False when importing CSV files in this Docker setup?",\n    "How do I configure pgadmin to connect to the PostgreSQL database created by Docker-Compose?"\n]')
# ('f09ea61e', '["What should I do if I encounter an error stating \'docker-credential-desktop\' executable file not found when running \'docker compose up -d\'?",  \n"Where can I find the Docker config.json file to fix the credential store error?",  \n"How do I modify the Docker configuration to resolve the \'executable file not found\' issue?",  \n"What is the difference between \'credsStore\' and \'credStore\' in Docker\'s config.json file?",  \n"After fixing the config.json file, do I need to restart Docker or just re-run the command?"]')
# ('fbd3d2bb', '```json\n[\n    "How do I determine the correct docker-compose binary to download for WSL?",\n    "What commands should I run to check my system before downloading docker-compose?",\n    "Where can I find the appropriate docker-compose binary for my WSL setup?",\n    "Is there a direct command to download and install docker-compose for WSL?",\n    "What do \'uname -s\' and \'uname -m\' outputs indicate when setting up docker-compose?"\n]\n```')
# ('0b014d0c', '["Why am I getting an undefined volume error when running Docker-Compose in Windows/WSL?",  \n"How can I fix the \'invalid compose project\' error related to the pgdatabase service in my docker-compose.yaml?",  \n"What changes do I need to make in my docker-compose file to resolve the undefined volume issue?",  \n"Where exactly should I place the volumes section in my docker-compose.yaml to avoid errors?",  \n"Can you explain why my Docker-Compose setup fails with a volume-related error even though I followed the video instructions?"]')
# ('d21bff1d', '["Why do I encounter a directory permissions error when using Docker with WSL?",  \n"How can I resolve permission conflicts between WSL and Windows in Docker?",  \n"What is the recommended way to handle persistent data storage in Docker to avoid permission issues?",  \n"Is the \'user\' field necessary in docker-compose.yaml when using Docker volumes?",  \n"Can you explain the difference between using Docker volumes and local file system storage for PostgreSQL in Docker?"]')
# ('6afb7b55', '["What should I do if pgadmin is not working for querying in Postgres?", "Why does pgadmin fail to work easily on git bash or VM in Windows?", "What libraries are required for pgadmin to work, and what if the error persists?", "How can I use psql instead of pgadmin for querying in Postgres?", "What is the command to install psycopg2 for using psql?"]')
# ('b51c3b82', '["Why am I getting an \'Insufficient system resources\' error when using WSL?", "How can I resolve the \'Insufficient system resources\' issue in WSL?", "What steps should I take to update Windows Terminal to fix WSL errors?", "Are there specific Windows updates needed to address WSL resource problems?", "After updating Windows Terminal and security updates, do I need to restart my system?"]')
# ('326af690', '["Why does my WSL integration with Ubuntu suddenly stop with exit code 1, and how can I fix it?",  \n"What should I do if restarting Docker doesn\'t resolve the WSL integration issue?",  \n"How can I fix DNS-related problems causing WSL to crash unexpectedly on Windows?",  \n"Why am I seeing \'conda: command not found\' in my terminal, and how do I resolve it?",  \n"What does \'Database is uninitialized and superuser password is not specified\' mean, and how do I address it?"]')
# ('c2ec9047', '["Why am I getting a permissions error when trying to SSH into the GPC VM from WSL2?", "How can I resolve the \'Permissions too open\' issue when using SSH in WSL2?", "What steps should I take if running \'ssh -i gpc\' fails due to permission problems?", "Is there a way to fix SSH key permissions in WSL2 without using sudo?", "How do I properly set up the .ssh folder in WSL2 to avoid SSH key permission errors?"]')
# ...
# ('d2719204', '["What are the default login credentials for Grafana when accessing it through localhost?", "Why am I being prompted for a username and password when I try to access Grafana after running docker-compose up?", "How can I change the default password after logging into Grafana for the first time?", "Is there a specific video or resource that demonstrates how to resolve the Grafana login issue?", "Where can I find additional help if the default credentials don\'t work for Grafana?"]')
# ('30b8e8e6', '["Why do I get an \'unknown flag: --build\' error when trying to start monitoring services in Linux?",  \n"What is the correct command to start monitoring services in Linux if \'docker compose up --build\' doesn\'t work?",  \n"Can you explain the difference between \'docker compose\' and \'docker-compose\' in Linux?",  \n"How do I resolve the issue where the monitoring services fail to start in Module 5?",  \n"Is there a specific reason why \'docker compose up --build\' doesn\'t work in Linux but \'docker-compose up --build\' does?"]')
# ('f33fc6e9', '```json\n{\n  "questions": [\n    "Why am I getting a KeyError \'content-length\' when running prepare.py?",\n    "What is the solution for the KeyError \'content-length\' issue in prepare.py?",\n    "The link in prepare.py for downloading taxi data doesn\'t work—how can I fix it?",\n    "How do I modify the URL in prepare.py to resolve the KeyError?",\n    "Can you provide the updated URL for downloading taxi data in prepare.py?"\n  ]\n}\n```')
# ('d828de2a', '["What does it mean when the Evidently service exits with code 2 during docker-compose up?",  \n"How can I resolve the \'Max retries exceeded with url: /api\' error when running the real-time prediction service?",  \n"Why does the Evidently service fail to import \'pyarrow\' in app.py, and how can I fix it?",  \n"What are the possible solutions if the Evidently service crashes due to a missing pyarrow module?",  \n"Is it safe to comment out the pyarrow import in app.py if the other solutions don\'t work?"]')
# ('03f20ec1', '```json\n[\n  "Why am I getting a ValueError about an incorrect item when passing a metric to Report in evidently?",\n  "What does the error \'ValueError: Incorrect item instead of a metric or metric preset was passed to Report\' mean in Module 5?",\n  "How can I fix the ValueError when using evidently to generate a report?",\n  "I encountered an error saying I passed an incorrect item to Report in evidently—what did I do wrong?",\n  "When using evidently, what is the common mistake that leads to the \'Incorrect item instead of a metric\' error?"\n]\n```')
# ('249726fe', '```json\n{\n  "questions": [\n    "What should I do if I encounter an error when using the RegressionQualityMetric() function?",\n    "Why is the target=\'duration_min\' parameter necessary for RegressionQualityMetric()?",\n    "How do I properly set up the current_data[\'duration_min\'] for RegressionQualityMetric()?",\n    "What are the specific requirements for using RegressionQualityMetric() in Module 5?",\n    "Can you explain the role of \'duration_min\' in the RegressionQualityMetric() function?"\n  ]\n}\n```')
# ('4e492af0', '```json\n[\n  "Why am I getting a ValueError stating \'Found array with 0 sample(s)\' when running LinearRegression?",\n  "What causes the training dataset to be empty in Module 5?",\n  "How can I resolve the issue of having 0 samples in my dataset?",\n  "What specific adjustment should I make to the \'begin\' date to avoid this error?",\n  "Who added the solution for the \'Found array with 0 sample(s)\' error in the FAQ?"\n]\n```')
# ('10011dc1', '[\n    "What should I do if I encounter errors about missing target or prediction columns after adding a new metric?",\n    "How can I determine whether a metric requires specific parameters when adding it to my monitoring setup?",\n    "Why did I not need to specify any parameters when adding DatasetCorrelationsMetric?",\n    "Where can I find detailed information about the requirements for adding different metrics in Module 5?",\n    "What steps should I take to troubleshoot errors related to metric configuration in monitoring?"\n]')
# ('92fb909a', '["Why am I unable to log in to Grafana using the default admin credentials?", "What should I do if Grafana shows an error when I try to log in with the standard username and password?", "How can I resolve the login issue in Grafana when admin/admin doesn\'t work?", "What command should I run to fix the Grafana admin password problem?", "After encountering a login error in Grafana, how do I reset the admin password?"]')
# ('2b8cb640', '```json\n[\n  "Why isn\'t my Grafana chart updating in real-time while my metric script is running?",\n  "What refresh interval should I set in Grafana to ensure my charts update frequently?",\n  "How does the timezone setting affect Grafana chart updates?",\n  "I changed my timezone from \'Europe/London\' to my local zone, but why was this necessary for updates?",\n  "Are there specific settings in Grafana or my script that could prevent chart updates?"\n]\n```')
# ('d4ceab0b', '[\n    "Why did my local Prefect server stop immediately after running the \'prefect server start\' command?",\n    "What alternative solution can I use if the Prefect server fails to run locally?",\n    "Did the issue with the local Prefect server get reported or tracked anywhere?",\n    "How can I switch to using Prefect Cloud instead of a local server for running my scripts?",\n    "What steps should I take if I encounter a similar issue with the Prefect server in the future?"\n]')
# ('482e575f', '["What should I do if I encounter a \'no disk space left\' error while running docker compose up?",  \n"How can I free up disk space when Docker is causing storage issues?",  \n"What command can I use to check Docker\'s disk usage before cleaning up?",  \n"Is there a way to remove unused Docker items to resolve disk space errors?",  \n"Can you explain how to clean up Docker system resources to fix disk space problems?"]')
# ('33e775eb', '["Why am I getting an error about failing to listen on :::8080 when running docker-compose up?",  \n"What does the error \'php_network_getaddresses: getaddrinfo failed: Address family for hostname not supported\' mean?",  \n"How can I fix the issue where Adminer fails to start due to a network address error?",  \n"Where should I add the command to resolve the 8080 listening error in the docker-compose file?",  \n"What is the correct command to specify in the yml file to make Adminer run properly on port 8080?"]')
# ('19a3d34a', '[\n    "Is there a built-in way to generate Evidently-style charts directly in Grafana without additional plugins?",\n    "How can I export Evidently report data to use in external visualization tools like Grafana?",\n    "What specific Grafana panel types would be needed to recreate Evidently dashboards?",\n    "Why might it be more practical to use Evidently directly for debugging rather than recreating its visualizations in Grafana?",\n    "What additional parameters do I need to include when exporting Evidently JSON to preserve raw data for visualizations?"\n]')
# ('55c68f23', '[\n    "Why am I getting the error \'Unable to locate credentials\' when running localstack with kinesis?",\n    "How can I resolve the \'Unable to locate credentials\' error in my localstack setup?",\n    "What environment variables do I need to add to docker-compose.yaml to fix credential issues with localstack?",\n    "Is there a quick way to configure AWS credentials for localstack without modifying docker-compose.yaml?",\n    "What values should I use for AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY when setting up localstack?"\n]')
# ('54020f0a', '[\n    "Why am I getting an \'unspecified location constraint is incompatible\' error when creating an S3 bucket with localstack and boto3?",\n    "How can I resolve the \'IllegalLocationConstraintException\' error during S3 bucket creation in a specific region?",\n    "What is the correct way to create an S3 bucket in localstack to avoid location constraint errors?",\n    "Why does the boto3 client throw an error when I try to create a bucket without specifying a location constraint?",\n    "What should I include in the \'CreateBucketConfiguration\' parameter to fix the \'unspecified location constraint\' error?"\n]')
# ('b6249d2c', '```json\n[\n  "Why am I seeing the error \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\' when running AWS CLI commands?",\n  "How can I resolve the AWS CLI error involving \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\'?",\n  "What environment variables do I need to set to fix the AWS CLI error with \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\'?",\n  "Do the values of AWS environment variables matter when fixing the \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\' error?",\n  "Is there a quick way to resolve the \'<botocore.awsrequest.AWSRequest object at 0x7fbaf2666280>\' error in AWS CLI without complex configurations?"\n]\n```')
# ('31543d95', '["Why does pre-commit show a \'mapping values are not allowed in this context\' error during every commit?",  \n"How can I fix the issue where pre-commit hooks fail to run with a YAML-related error?",  \n"What should I check in my .pre-commit-config.yaml file to resolve indentation problems?",  \n"Are there specific formatting rules for the .pre-commit-config.yaml file to avoid errors?",  \n"Which part of the .pre-commit-config.yaml file commonly causes the \'mapping values\' error?"]')
# ('e147bbb6', '[\n    "How do I completely reset pytest configuration after switching from a previous testing folder?",\n    "What steps should I take if pytest settings from an old folder are interfering with my current setup?",\n    "Where exactly do I need to delete the .vscode folder to fix pytest reconfiguration issues?",\n    "Why can\'t I remove pytest tests directly and what\'s the alternative solution?",\n    "Is there a specific location I should clean up to ensure pytest works properly in a new folder?"\n]')
# ('dc55657f', '```json\n[\n    "Why does the get-records command return empty Records when following Module 6\'s video at 11:23?",\n    "What modification is needed for the Kinesis get-records call to resolve empty Records in LocalStack?",\n    "How can I fix the issue of empty Records when using Kinesis with LocalStack?",\n    "Is there a specific flag required for get-records to work correctly in LocalStack?",\n    "What is the solution for empty Records in Kinesis when following the steps in Module 6?"\n]\n```')
# ('f6979915', '```json\n{\n  "questions": [\n    "Why am I getting a UTF-8 encoding error when trying to commit in Git after creating a pre-commit YAML file?",\n    "How can I resolve the \'utf-8 codec can\'t decode byte 0xff\' error during a Git commit in PowerShell?",\n    "What steps should I take to set UTF-8 encoding for the pre-commit YAML file to avoid commit errors?",\n    "After creating a pre-commit-config.yaml file, Git commit fails with an encoding error—how do I fix this?",\n    "What is the correct way to create a pre-commit YAML file in PowerShell to prevent UTF-8 encoding issues?"\n  ]\n}\n```')
# ('1076a121', '[\n    "Why does my Git commit fail with the error \'PythonInfo\' object has no attribute \'version_nodot\' when using a pre-commit hook?",\n    "How can I resolve the \'version_nodot\' attribute error that occurs during a Git commit with pre-commit hooks?",\n    "What steps should I take if my pre-commit hook raises an unexpected \'PythonInfo\' object error?",\n    "Is there a way to fix the \'CalledProcessError\' and \'AttributeError\' during Git commits with pre-commit hooks?",\n    "Can clearing the virtualenv app-data help resolve pre-commit hook errors like \'version_nodot\' missing?"\n]')
# ('aa203ca7', '[\n    "Why do I get a \'module not found\' error when running pytest on my custom packages, but it works when running the test file directly?",\n    "How can I fix the \'No module named production\' error when using pytest with my project structure?",\n    "What is the difference between running pytest directly and using python -m pytest for my tests?",\n    "Why does pytest not recognize my custom modules even though the test file runs fine when executed directly?",\n    "Are there alternative solutions besides using python -m pytest to resolve module import issues in pytest?"\n]')
# ('8b04605d', '[\n    "Why am I getting a \'module not found\' error when running pytest with pre-commit hooks for custom packages?",\n    "How can I fix the \'No module named production\' error during git commit when using pytest?",\n    "What changes should I make to my pre-commit hook configuration to resolve pytest import issues?",\n    "Can you explain the solution for pytest not finding custom modules in a pre-commit hook setup?",\n    "What is the correct way to configure a pre-commit hook to run pytest with custom package imports?"\n]')
# ('a3b9af04', '["Why am I getting a Permission denied error when running a script in GitHub Actions?",  \n"How can I resolve the error code 126 in my GitHub Actions workflow?",  \n"What steps should I take to fix execution permission issues for a script in GitHub Actions?",  \n"How do I grant execute permissions to a script file before running it in a GitHub Actions workflow?",  \n"What is the correct command to add execute permissions to a script in a GitHub repository?"]')
# ('b16aae74', '["How can I efficiently manage and run only specific containers from a large docker-compose file without overloading my system?", "What is the purpose of using profiles in a docker-compose file when dealing with multiple containers?", "How do I define and assign a profile to a service in my docker-compose configuration?", "What command should I use to start only the containers associated with a specific profile in docker-compose?", "Can you explain how profiles in docker-compose help streamline the testing process by isolating relevant containers?"]')
# ('66326a87', '```json\n[\n    "Why are my integration tests failing when using Kinesis in Module 6?",\n    "How do I ensure my AWS region settings are consistent across docker-compose and local config?",\n    "What could be causing my Kinesis stream to be created in the wrong region?",\n    "Can you provide an example of matching AWS region settings between docker-compose and local config?",\n    "What steps should I take to troubleshoot region mismatch issues in Module 6?"\n]\n```')
# ('fb3c4150', '[\n    "Why is the pre-commit command failing when using isort in my repository?",\n    "What specific version of isort should I use to resolve the pre-commit issue?",\n    "How can I fix the isort pre-commit failure in Module 6?",\n    "Who provided the solution for the isort pre-commit problem?",\n    "What was the exact solution to the isort pre-commit error mentioned in the FAQ?"\n]')
# ('886d1617', '[\n    "What steps should I follow to tear down AWS infrastructure that was deployed using GitHub Actions?",\n    "Can you explain how to properly destroy resources created by the CD-Deploy Action in AWS?",\n    "Is there a specific command sequence required to remove infrastructure managed by Terraform in this module?",\n    "How do I ensure the correct state file is used when destroying the infrastructure locally?",\n    "Are there any additional variables or configurations needed when running the destroy command for this setup?"\n]')

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# ## Video 3.3 --> Evaluation of Text Retrieval Techniques for RAG out

# %%
import json

with open('documents-with-ids.json', 'rt') as f_in:
    documents = json.load(f_in)

# %%
from elasticsearch import Elasticsearch

es_client = Elasticsearch('http://localhost:9200', request_timeout=60) 

index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "text": {"type": "text"},
            "section": {"type": "text"},
            "question": {"type": "text"},
            "course": {"type": "keyword"},
            "id": {"type": "keyword"},
        }
    }
}

index_name = "course-questions"

# es_client.indices.delete(index=index_name, ignore_unavailable=True)
# es_client.indices.create(index=index_name, body=index_settings)

try:
    # Intenta borrar el índice (ignora si no existe)
    print(f"Intentando borrar el índice '{index_name}' si existe...")
    es_client.indices.delete(index=index_name, ignore_unavailable=True)
    print(f"Índice '{index_name}' borrado o no existía.")

    # Intenta crear el índice
    print(f"Intentando crear el índice '{index_name}'...")
    es_client.indices.create(index=index_name, body=index_settings)
    print(f"¡Índice '{index_name}' creado exitosamente!")
except Exception as e:
    print(f"ERROR: Ocurrió un problema al interactuar con Elasticsearch: {e}")
# Out:
# Intentando borrar el índice 'course-questions' si existe...
# Índice 'course-questions' borrado o no existía.
# Intentando crear el índice 'course-questions'...
# ¡Índice 'course-questions' creado exitosamente!

# %%
from tqdm.auto import tqdm

for doc in tqdm(documents):
    es_client.index(index=index_name, document=doc)
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[4], line 4
#       1 from tqdm.auto import tqdm
#       3 for doc in tqdm(documents):
# ----> 4     es_client.index(index=index_name, document=doc)
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/utils.py:455, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     452         except KeyError:
#     453             pass
# --> 455 return api(*args, **kwargs)
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/__init__.py:3002, in Elasticsearch.index(self, index, document, body, id, error_trace, filter_path, human, if_primary_term, if_seq_no, op_type, pipeline, pretty, refresh, require_alias, routing, timeout, version, version_type, wait_for_active_shards)
#    3000 __body = document if document is not None else body
#    3001 __headers = {"accept": "application/json", "content-type": "application/json"}
# -> 3002 return self.perform_request(  # type: ignore[return-value]
#    3003     __method,
#    3004     __path,
#    3005     params=__query,
#    3006     headers=__headers,
#    3007     body=__body,
#    3008     endpoint_id="index",
#    3009     path_parts=__path_parts,
#    3010 )
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:352, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     349         except (ValueError, KeyError, TypeError):
#     350             pass
# --> 352     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     353         message=message, meta=meta, body=resp_body
#     354     )
#     356 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     357 if not self._verified_elasticsearch:
#     358     # If the header is set we mark the server as verified.
#
# ApiError: ApiError(503, 'unavailable_shards_exception', '[course-questions][0] primary shard is not active Timeout: [1m], request: [BulkShardRequest [[course-questions][0]] containing [index {[course-questions][OuOBOZgBgnecT-cPMzh2], source[{"text":"The purpose of this document is to capture frequently asked technical questions\\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours\'\' live.1\\nSubscribe to course public Google Calendar (it works from Desktop only).\\nRegister before the course starts using this link.\\nJoin the course Telegram channel with announcements.\\nDon’t forget to register in DataTalks.Club\'s Slack and join the channel.","section":"General course-related questions","question":"Course - When will the course start?","course":"data-engineering-zoomcamp","id":"c02e79ef"}]}]]')

# %%
print(type(documents))
documents[0]
# Out:
# <class 'list'>
# {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#  'section': 'General course-related questions',
#  'question': 'Course - When will the course start?',
#  'course': 'data-engineering-zoomcamp',
#  'id': 'c02e79ef'}

# %%
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0,
        "index": {
            "refresh_interval": "30s",  # Reduce la frecuencia de refresh
            "number_of_routing_shards": 1
        }
    },
    "mappings": {
        "properties": {
            "text": {"type": "text"},
            "section": {"type": "text"},
            "question": {"type": "text"},
            "course": {"type": "keyword"},
            "id": {"type": "keyword"},
        }
    }
}

# %%
from elasticsearch import Elasticsearch
from tqdm.auto import tqdm

# Configuración del cliente
es_client = Elasticsearch(
    'http://localhost:9200',
    request_timeout=60
)

# Nombre del índice
index_name = "course-questions"

# Función para indexar documentos con manejo de errores
def index_documents(documents):
    successes = 0
    errors = 0
    
    for doc in tqdm(documents, desc="Indexando documentos"):
        try:
            # Asegúrate que el documento tenga todos los campos requeridos
            required_fields = ['text', 'section', 'question', 'course', 'id']
            if not all(field in doc for field in required_fields):
                print(f"Documento falta campos requeridos: {doc}")
                errors += 1
                continue
                
            # Intenta indexar el documento
            response = es_client.index(
                index=index_name,
                document=doc,
                id=doc['id']  # Usamos el campo 'id' como ID del documento
            )
            
            if response['result'] in ['created', 'updated']:
                successes += 1
            else:
                errors += 1
                print(f"Respuesta inesperada: {response}")
                
        except Exception as e:
            errors += 1
            print(f"Error indexando documento {doc.get('id', 'sin ID')}: {str(e)}")
    
    print(f"\nResumen: {successes} documentos indexados, {errors} errores")

# Ejemplo de uso:
# documents = [
#     {
#         "id": "1",
#         "text": "Texto de ejemplo",
#         "section": "Sección 1",
#         "question": "Pregunta de ejemplo",
#         "course": "matematicas"
#     },
#     # ... más documentos
# ]
# index_documents(documents)

# %%
index_documents(documents)
# Out:
# Indexando documentos:   0%|          | 0/948 [00:00<?, ?it/s]
# Error indexando documento c02e79ef: ApiError(503, 'unavailable_shards_exception', '[course-questions][0] primary shard is not active Timeout: [1m], request: [BulkShardRequest [[course-questions][0]] containing [index {[course-questions][c02e79ef], source[{"text":"The purpose of this document is to capture frequently asked technical questions\\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours\'\' live.1\\nSubscribe to course public Google Calendar (it works from Desktop only).\\nRegister before the course starts using this link.\\nJoin the course Telegram channel with announcements.\\nDon’t forget to register in DataTalks.Club\'s Slack and join the channel.","section":"General course-related questions","question":"Course - When will the course start?","course":"data-engineering-zoomcamp","id":"c02e79ef"}]}]]')
# Error indexando documento 1f6520ca: ApiError(503, 'unavailable_shards_exception', '[course-questions][0] primary shard is not active Timeout: [1m], request: [BulkShardRequest [[course-questions][0]] containing [index {[course-questions][1f6520ca], source[{"text":"GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites","section":"General course-related questions","question":"Course - What are the prerequisites for this course?","course":"data-engineering-zoomcamp","id":"1f6520ca"}]}]]')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 index_documents(documents)
#
# Cell In[8], line 28, in index_documents(documents)
#      25     continue
#      27 # Intenta indexar el documento
# ---> 28 response = es_client.index(
#      29     index=index_name,
#      30     document=doc,
#      31     id=doc['id']  # Usamos el campo 'id' como ID del documento
#      32 )
#      34 if response['result'] in ['created', 'updated']:
#      35     successes += 1
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/utils.py:455, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     452         except KeyError:
#     453             pass
# --> 455 return api(*args, **kwargs)
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/__init__.py:3002, in Elasticsearch.index(self, index, document, body, id, error_trace, filter_path, human, if_primary_term, if_seq_no, op_type, pipeline, pretty, refresh, require_alias, routing, timeout, version, version_type, wait_for_active_shards)
#    3000 __body = document if document is not None else body
#    3001 __headers = {"accept": "application/json", "content-type": "application/json"}
# -> 3002 return self.perform_request(  # type: ignore[return-value]
#    3003     __method,
#    3004     __path,
#    3005     params=__query,
#    3006     headers=__headers,
#    3007     body=__body,
#    3008     endpoint_id="index",
#    3009     path_parts=__path_parts,
#    3010 )
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:316, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     313 else:
#     314     target = path
# --> 316 meta, resp_body = self.transport.perform_request(
#     317     method,
#     318     target,
#     319     headers=request_headers,
#     320     body=body,
#     321     request_timeout=self._request_timeout,
#     322     max_retries=self._max_retries,
#     323     retry_on_status=self._retry_on_status,
#     324     retry_on_timeout=self._retry_on_timeout,
#     325     client_meta=self._client_meta,
#     326     otel_span=otel_span,
#     327 )
#     329 # HEAD with a 404 is returned as a normal response
#     330 # since this is used as an 'exists' functionality.
#     331 if not (method == "HEAD" and meta.status == 404) and (
#     332     not 200 <= meta.status < 299
#     333     and (
#    (...)
#     337     )
#     338 ):
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elastic_transport/_transport.py:342, in Transport.perform_request(self, method, target, body, headers, max_retries, retry_on_status, retry_on_timeout, request_timeout, client_meta, otel_span)
#     340 try:
#     341     otel_span.set_node_metadata(node.host, node.port, node.base_url, target)
# --> 342     resp = node.perform_request(
#     343         method,
#     344         target,
#     345         body=request_body,
#     346         headers=request_headers,
#     347         request_timeout=request_timeout,
#     348     )
#     349     _logger.info(
#     350         "%s %s%s [status:%s duration:%.3fs]"
#     351         % (
#    (...)
#     357         )
#     358     )
#     360     if method != "HEAD":
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elastic_transport/_node/_http_urllib3.py:167, in Urllib3HttpNode.perform_request(self, method, target, body, headers, request_timeout)
#     164 else:
#     165     body_to_send = None
# --> 167 response = self.pool.urlopen(
#     168     method,
#     169     target,
#     170     body=body_to_send,
#     171     retries=Retry(False),
#     172     headers=request_headers,
#     173     **kw,  # type: ignore[arg-type]
#     174 )
#     175 response_headers = HttpHeaders(response.headers)
#     176 data = response.data
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def elastic_search(query, course):
    search_query = {
        "size": 5,
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["question^3", "text", "section"],
                        "type": "best_fields"
                    }
                },
                "filter": {
                    "term": {
                        "course": course
                    }
                }
            }
        }
    }

    response = es_client.search(index=index_name, body=search_query)
    
    result_docs = []
    
    for hit in response['hits']['hits']:
        result_docs.append(hit['_source'])
    
    return result_docs

# %%
elastic_search(
    query="I just discovered the course. Can I still join?",
    course="data-engineering-zoomcamp"
)
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 elastic_search(
#       2     query="I just discovered the course. Can I still join?",
#       3     course="data-engineering-zoomcamp"
#       4 )
#
# Cell In[9], line 22, in elastic_search(query, course)
#       1 def elastic_search(query, course):
#       2     search_query = {
#       3         "size": 5,
#       4         "query": {
#    (...)
#      19         }
#      20     }
# ---> 22     response = es_client.search(index=index_name, body=search_query)
#      24     result_docs = []
#      26     for hit in response['hits']['hits']:
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/utils.py:455, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     452         except KeyError:
#     453             pass
# --> 455 return api(*args, **kwargs)
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/__init__.py:5061, in Elasticsearch.search(self, index, aggregations, aggs, allow_no_indices, allow_partial_search_results, analyze_wildcard, analyzer, batched_reduce_size, ccs_minimize_roundtrips, collapse, default_operator, df, docvalue_fields, error_trace, expand_wildcards, explain, ext, fields, filter_path, force_synthetic_source, from_, highlight, human, ignore_throttled, ignore_unavailable, include_named_queries_score, indices_boost, knn, lenient, max_concurrent_shard_requests, min_compatible_shard_node, min_score, pit, post_filter, pre_filter_shard_size, preference, pretty, profile, q, query, rank, request_cache, rescore, rest_total_hits_as_int, retriever, routing, runtime_mappings, script_fields, scroll, search_after, search_type, seq_no_primary_term, size, slice, sort, source, source_excludes, source_includes, stats, stored_fields, suggest, suggest_field, suggest_mode, suggest_size, suggest_text, terminate_after, timeout, track_scores, track_total_hits, typed_keys, version, body)
#    5059 if __body is not None:
#    5060     __headers["content-type"] = "application/json"
# -> 5061 return self.perform_request(  # type: ignore[return-value]
#    5062     "POST",
#    5063     __path,
#    5064     params=__query,
#    5065     headers=__headers,
#    5066     body=__body,
#    5067     endpoint_id="search",
#    5068     path_parts=__path_parts,
#    5069 )
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File /media/villarreal-fx/Proyectos/llm-zoomcamp/env/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:352, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     349         except (ValueError, KeyError, TypeError):
#     350             pass
# --> 352     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     353         message=message, meta=meta, body=resp_body
#     354     )
#     356 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     357 if not self._verified_elasticsearch:
#     358     # If the header is set we mark the server as verified.
#
# ApiError: ApiError(503, 'search_phase_execution_exception', None)

# %%
df = pd.read_csv('results_fila.csv')
df.head()
# Out:
#                                             c02e79ef  \
# 0  [\n    "What is the exact start date and time ...
#
#                                             1f6520ca  \
# 0  [\n    "What background knowledge or skills do...
#
#                                             7842b56a  \
# 0  ```json\n[\n  "Is it possible to enroll in the...
#
#                                             0bbf41ec  \
# 0  [\n    "If I haven't received a confirmation e...
#
#                                             63394d91  \
# 0  [\n    "What are the recommended preparations ...
#
#                                             2ed9b986  \
# 0  [\n    "How many Zoomcamp sessions are offered...
#
#                                             93e2c8ed  \
# 0  [\n    "How does the current cohort differ fro...
#
#                                             a482086d  \
# 0  [\n    "Will the course materials remain acces...
#
#                                             eb56ae98  \
# 0  [\n    "Is there any support available for stu...
#
#                                             4292531b  ...  \
# 0  [\n    "What is the main YouTube playlist I sh...  ...
#
#                                             dc55657f  \
# 0  ```json\n[\n    "Why does the get-records comm...
#
#                                             f6979915  \
# 0  ```json\n{\n  "questions": [\n    "Why am I ge...
#
#                                             1076a121  \
# 0  [\n    "Why does my Git commit fail with the e...
#
#                                             aa203ca7  \
# 0  [\n    "Why do I get a 'module not found' erro...
#
#                                             8b04605d  \
# 0  [\n    "Why am I getting a 'module not found' ...
#
#                                             a3b9af04  \
# 0  ["Why am I getting a Permission denied error w...
#
#                                             b16aae74  \
# 0  ["How can I efficiently manage and run only sp...
#
#                                             66326a87  \
# 0  ```json\n[\n    "Why are my integration tests ...
#
#                                             fb3c4150  \
# 0  [\n    "Why is the pre-commit command failing ...
#
#                                             886d1617
# 0  [\n    "What steps should I follow to tear dow...
#
# [1 rows x 947 columns]
